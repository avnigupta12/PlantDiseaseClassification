# %%
import os                       # for working with files
import numpy as np              # for numerical computationss
import pandas as pd             # for working with dataframes
import torch                    # Pytorch module 
import matplotlib.pyplot as plt # for plotting informations on graph and images using tensors
import torch.nn as nn           # for creating  neural networks
from torch.utils.data import DataLoader, random_split # for dataloaders 
from PIL import Image           # for checking images
import torch.nn.functional as F # for functions for calculating loss
import torchvision.transforms as transforms   # for transforming images into tensors 
from torchvision.utils import make_grid       # for data checking
from torchvision.datasets import ImageFolder  # for working with classes and images
from tqdm import tqdm
import time
from torchvision import models

# For Confusion Matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
import seaborn as sn

# %%
data_dir = "/kaggle/input/plantdoc6721"
# data_dir = "/content/drive/MyDrive/COMP6721-Project/PlantVillage-Dataset"

diseases = os.listdir(data_dir)

# %%
# printing the disease names
print(diseases)
print("Total disease classes are: {}".format(len(diseases)))
# Out:
# ['Corn leaf blight', 'Tomato leaf', 'Tomato leaf mosaic virus', 'Squash Powdery mildew leaf', 'Potato leaf late blight', 'Soyabean leaf', 'Peach leaf', 'Tomato leaf late blight', 'Apple leaf', 'Tomato mold leaf', 'Corn Gray leaf spot', 'Tomato leaf yellow virus', 'Strawberry leaf', 'Cherry leaf', 'Apple rust leaf', 'Potato leaf early blight', 'grape leaf black rot', 'Apple Scab Leaf', 'Tomato Septoria leaf spot', 'Tomato leaf bacterial spot', 'Blueberry leaf', 'Bell_pepper leaf spot', 'Corn rust leaf', 'Bell_pepper leaf', 'grape leaf', 'Tomato Early blight leaf', 'Raspberry leaf']
# Total disease classes are: 27

# %%
plants = []
for plant in diseases:
    if plant.split(' ')[0] not in plants:
        plants.append(plant.split(' ')[0])

# %%
# Unique plants in the dataset
print("Number of plants: {}".format(len(plants)))
print(f"Unique Plants are: ")
for idx, plant in enumerate(plants):
  print(str(idx + 1) + '. ' + plant)
# Out:
# Number of plants: 13
# Unique Plants are:
# 1. Corn
# 2. Tomato
# 3. Squash
# 4. Potato
# 5. Soyabean
# 6. Peach
# 7. Apple
# 8. Strawberry
# 9. Cherry
# 10. grape
# 11. Blueberry
# 12. Bell_pepper
# 13. Raspberry

# %%
# Number of images for each disease
disease_class_size = {}
for disease in diseases:
    disease_class_size[disease] = len(os.listdir(data_dir + '/' + disease))
    
# converting the disease_class_size dictionary to pandas dataframe passing index as plant name and number of images as column

img_per_class = pd.DataFrame(disease_class_size.values(), index=disease_class_size.keys(), columns=["no. of images"])
img_per_class
# Out:
#                             no. of images
# Corn leaf blight                      187
# Tomato leaf                           186
# Tomato leaf mosaic virus              188
# Squash Powdery mildew leaf            187
# Potato leaf late blight               188
# Soyabean leaf                         185
# Peach leaf                            186
# Tomato leaf late blight               185
# Apple leaf                            187
# Tomato mold leaf                      186
# Corn Gray leaf spot                   186
# Tomato leaf yellow virus              185
# Strawberry leaf                       186
# Cherry leaf                           186
# Apple rust leaf                       186
# Potato leaf early blight              185
# grape leaf black rot                  185
# Apple Scab Leaf                       185
# Tomato Septoria leaf spot             187
# Tomato leaf bacterial spot            185
# Blueberry leaf                        185
# Bell_pepper leaf spot                 186
# Corn rust leaf                        187
# Bell_pepper leaf                      185
# grape leaf                            185
# Tomato Early blight leaf              188
# Raspberry leaf                        186

# %%
# plotting number of images available for each disease
index = [n for n in range(len(disease_class_size.values()))]
plt.figure(figsize=(20, 5))
plt.bar(index, [n for n in disease_class_size.values()], width=0.3)
plt.xlabel('Plants/Diseases', fontsize=10)
plt.ylabel('No of images available', fontsize=10)
plt.xticks(index, diseases, fontsize=5, rotation=90)
plt.title('Images per each class of plant disease')

plt.savefig('/kaggle/working/ClassDistribution_Plantdoc_AfterOfflineAugmentation')

# %%
## Split Train, Test and Validation ##

def get_files_from_folder(path):
    files = os.listdir(path)
    return np.asarray(files)

get_files_from_folder(data_dir)

def load_data(path, validation_split, test_split, batch_size):
    transform_dict = {
        "src": transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.27129, 0.28836, 0.26273], std=[0.09086, 0.12649, 0.08288]),
            transforms.Resize((224, 224))
        ])
    }
    
    dataset = ImageFolder(root=path, transform=transform_dict["src"])
    
    dataset_size = len(dataset)
    validation_size = int(validation_split * dataset_size)
    test_size = int(test_split * dataset_size)
    train_size = dataset_size - (test_size + validation_size)

    # TODO: Split classes into equal sizes?!
    train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size])
    
    return train_dataset, validation_dataset, test_dataset

# %%
train_dataset, validation_dataset, test_dataset = load_data(data_dir, 0.1, 0.2, 200)

# %%
img, label = train_dataset[0]
print(img.shape, label)
# Out:
# torch.Size([3, 224, 224]) 7

# %%
# for checking some images from training dataset
def show_image(image, label):
    # print("Label :" + train_dataset.classes[label] + "(" + str(label) + ")")
    plt.imshow(image.permute(1, 2, 0))

# %%
show_image(*train_dataset[21])

# %%
# setting the batch size
batch_size = 32

# Load data to DataLoaders for training, validation and test
train_dataloader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
validation_dataloader = DataLoader(validation_dataset, batch_size, num_workers=2, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size, num_workers=2, pin_memory=True)

# %%
# helper function to show a batch of training instances
def show_batch(data):
    for images, labels in data:
        fig, ax = plt.subplots(figsize=(30, 30))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dataloader)

# %%
# for calculating the accuracy
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))


# base class for the model
class ImageClassificationBase(nn.Module):
    
    def training_step(self, batch):
        images, labels = batch
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch
        out = self(images)                   # Generate prediction
        loss = F.cross_entropy(out, labels)  # Calculate loss
        acc = accuracy(out, labels)          # Calculate accuracy
        return {"val_loss": loss.detach(), "val_accuracy": acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x["val_loss"] for x in outputs]
        batch_accuracy = [x["val_accuracy"] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()       # Combine loss  
        epoch_accuracy = torch.stack(batch_accuracy).mean()
        return {"val_loss": epoch_loss, "val_accuracy": epoch_accuracy} # Combine accuracies
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_accuracy']))

# %%
# defining the model and moving it to the GPU

model_vgg16 = models.vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
for param in model_vgg16.parameters():
    param.requires_grad = False

num_ftrs = model_vgg16.classifier[6].in_features
model_vgg16.classifier[6] = nn.Linear(num_ftrs, out_features=len(train_dataset.dataset.classes))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))
model_vgg16.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_vgg16.classifier[6].parameters(), lr=0.001)
# Out:
# Device: cuda:0

# %%
accuracy_validation = []
accuracy_train = []
loss_validation = []
loss_train = []

num_epochs = 40
total_steps = len(train_dataloader)
t1 = time.time()

for epoch in range(num_epochs):
    for i, data in enumerate(train_dataloader):
        images, labels = data[0].to(device), data[1].to(device)
        # Forward pass
        outputs = model_vgg16(images)
        loss = criterion(outputs, labels)
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        if (i + 1) % 10 == 0:
            accuracy = ((correct / total) * 100)
            accuracy_train.append(accuracy)
            loss_train.append(loss.item())
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                .format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(), accuracy))
            
            model_vgg16.eval()
            with torch.no_grad():
                correct_validation_labels = 0
                total_validation_labels = 0

                for validation_data in validation_dataloader:
                    validation_images, validation_labels = validation_data[0].to(device), validation_data[1].to(device)
                    predicted_outputs = model_vgg16(validation_images)

                    _, validation_prediction = torch.max(predicted_outputs.data, 1)
                    total_validation_labels += validation_labels.size(0)
                    correct_validation_labels += (validation_prediction == validation_labels).sum().item()
                # print("Correct-> ", correct_validation_labels)
                # print("Total-> ", total_validation_labels)
                # print(correct_validation_labels/total_validation_labels)
                val_loss = criterion(predicted_outputs, validation_labels)
                
                val_accuracy = ((correct_validation_labels / total_validation_labels) * 100)
                
                accuracy_validation.append(val_accuracy)
                loss_validation.append(val_loss.item())
            
                print('Epoch [{}/{}], Loss: {:.4f}, Validation Accuracy: {:.2f}%'
                      .format(epoch + 1, num_epochs, val_loss.item(), val_accuracy))
     
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Epoch [1/40], Step [10/110], Loss: 3.2028, Accuracy: 12.50%
# Epoch [1/40], Loss: 2.8290, Validation Accuracy: 16.93%
# Epoch [1/40], Step [20/110], Loss: 2.3622, Accuracy: 31.25%
# Epoch [1/40], Loss: 2.5613, Validation Accuracy: 23.71%
# Epoch [1/40], Step [30/110], Loss: 2.7098, Accuracy: 15.62%
# Epoch [1/40], Loss: 2.0463, Validation Accuracy: 28.69%
# Epoch [1/40], Step [40/110], Loss: 2.2509, Accuracy: 37.50%
# Epoch [1/40], Loss: 2.2875, Validation Accuracy: 31.27%
# Epoch [1/40], Step [50/110], Loss: 1.9349, Accuracy: 34.38%
# Epoch [1/40], Loss: 1.8972, Validation Accuracy: 35.66%
# Epoch [1/40], Step [60/110], Loss: 1.9155, Accuracy: 43.75%
# Epoch [1/40], Loss: 1.6689, Validation Accuracy: 39.24%
# Epoch [1/40], Step [70/110], Loss: 1.9883, Accuracy: 50.00%
# Epoch [1/40], Loss: 2.0107, Validation Accuracy: 37.65%
# Epoch [1/40], Step [80/110], Loss: 2.0571, Accuracy: 37.50%
# Epoch [1/40], Loss: 1.6639, Validation Accuracy: 46.41%
# Epoch [1/40], Step [90/110], Loss: 1.8213, Accuracy: 46.88%
# Epoch [1/40], Loss: 1.4140, Validation Accuracy: 46.22%
# Epoch [1/40], Step [100/110], Loss: 1.2252, Accuracy: 75.00%
# Epoch [1/40], Loss: 1.3925, Validation Accuracy: 49.60%
# Epoch [1/40], Step [110/110], Loss: 1.1550, Accuracy: 72.41%
# Epoch [1/40], Loss: 1.4890, Validation Accuracy: 51.20%
# Epoch [2/40], Step [10/110], Loss: 1.5158, Accuracy: 59.38%
# Epoch [2/40], Loss: 1.5328, Validation Accuracy: 50.20%
# Epoch [2/40], Step [20/110], Loss: 1.3163, Accuracy: 71.88%
# Epoch [2/40], Loss: 1.5768, Validation Accuracy: 49.60%
# Epoch [2/40], Step [30/110], Loss: 1.0322, Accuracy: 81.25%
# Epoch [2/40], Loss: 1.3675, Validation Accuracy: 54.78%
# Epoch [2/40], Step [40/110], Loss: 1.3023, Accuracy: 59.38%
# Epoch [2/40], Loss: 1.2683, Validation Accuracy: 56.77%
# Epoch [2/40], Step [50/110], Loss: 1.2171, Accuracy: 68.75%
# Epoch [2/40], Loss: 1.4238, Validation Accuracy: 53.98%
# Epoch [2/40], Step [60/110], Loss: 1.2219, Accuracy: 71.88%
# Epoch [2/40], Loss: 1.0856, Validation Accuracy: 54.38%
# Epoch [2/40], Step [70/110], Loss: 1.2827, Accuracy: 75.00%
# Epoch [2/40], Loss: 1.2226, Validation Accuracy: 54.98%
# Epoch [2/40], Step [80/110], Loss: 1.6350, Accuracy: 53.12%
# Epoch [2/40], Loss: 1.2486, Validation Accuracy: 54.58%
# Epoch [2/40], Step [90/110], Loss: 1.0510, Accuracy: 68.75%
# Epoch [2/40], Loss: 1.0934, Validation Accuracy: 56.37%
# Epoch [2/40], Step [100/110], Loss: 1.0087, Accuracy: 75.00%
# Epoch [2/40], Loss: 1.0301, Validation Accuracy: 56.37%
# Epoch [2/40], Step [110/110], Loss: 1.1911, Accuracy: 62.07%
# Epoch [2/40], Loss: 1.2180, Validation Accuracy: 59.16%
# Epoch [3/40], Step [10/110], Loss: 0.8509, Accuracy: 75.00%
# Epoch [3/40], Loss: 1.1598, Validation Accuracy: 55.98%
# Epoch [3/40], Step [20/110], Loss: 0.7995, Accuracy: 81.25%
# Epoch [3/40], Loss: 1.1311, Validation Accuracy: 60.16%
# Epoch [3/40], Step [30/110], Loss: 0.7732, Accuracy: 75.00%
# Epoch [3/40], Loss: 1.0539, Validation Accuracy: 59.36%
# Epoch [3/40], Step [40/110], Loss: 0.9212, Accuracy: 71.88%
# Epoch [3/40], Loss: 1.0142, Validation Accuracy: 56.77%
# Epoch [3/40], Step [50/110], Loss: 1.0173, Accuracy: 71.88%
# Epoch [3/40], Loss: 1.1102, Validation Accuracy: 59.76%
# Epoch [3/40], Step [60/110], Loss: 1.0663, Accuracy: 59.38%
# Epoch [3/40], Loss: 0.9110, Validation Accuracy: 61.35%
# Epoch [3/40], Step [70/110], Loss: 1.1903, Accuracy: 65.62%
# Epoch [3/40], Loss: 0.9970, Validation Accuracy: 58.76%
# Epoch [3/40], Step [80/110], Loss: 0.4249, Accuracy: 93.75%
# Epoch [3/40], Loss: 0.9844, Validation Accuracy: 59.16%
# Epoch [3/40], Step [90/110], Loss: 0.7795, Accuracy: 90.62%
# Epoch [3/40], Loss: 0.8521, Validation Accuracy: 63.55%
# Epoch [3/40], Step [100/110], Loss: 0.9276, Accuracy: 75.00%
# Epoch [3/40], Loss: 0.9519, Validation Accuracy: 62.95%
# Epoch [3/40], Step [110/110], Loss: 1.0275, Accuracy: 72.41%
# Epoch [3/40], Loss: 0.8771, Validation Accuracy: 61.55%
# Epoch [4/40], Step [10/110], Loss: 0.6433, Accuracy: 87.50%
# Epoch [4/40], Loss: 0.9697, Validation Accuracy: 62.95%
# Epoch [4/40], Step [20/110], Loss: 0.6662, Accuracy: 75.00%
# Epoch [4/40], Loss: 1.1052, Validation Accuracy: 63.94%
# Epoch [4/40], Step [30/110], Loss: 0.5378, Accuracy: 84.38%
# Epoch [4/40], Loss: 1.0889, Validation Accuracy: 64.14%
# Epoch [4/40], Step [40/110], Loss: 0.6201, Accuracy: 87.50%
# Epoch [4/40], Loss: 0.8268, Validation Accuracy: 65.54%
# Epoch [4/40], Step [50/110], Loss: 0.9063, Accuracy: 68.75%
# Epoch [4/40], Loss: 0.8548, Validation Accuracy: 62.75%
# Epoch [4/40], Step [60/110], Loss: 0.7138, Accuracy: 75.00%
# Epoch [4/40], Loss: 0.8557, Validation Accuracy: 65.34%
# Epoch [4/40], Step [70/110], Loss: 0.6034, Accuracy: 81.25%
# Epoch [4/40], Loss: 0.9483, Validation Accuracy: 66.14%
# Epoch [4/40], Step [80/110], Loss: 0.5915, Accuracy: 78.12%
# Epoch [4/40], Loss: 0.8954, Validation Accuracy: 65.74%
# Epoch [4/40], Step [90/110], Loss: 0.8717, Accuracy: 75.00%
# Epoch [4/40], Loss: 0.7887, Validation Accuracy: 67.33%
# Epoch [4/40], Step [100/110], Loss: 0.5832, Accuracy: 84.38%
# Epoch [4/40], Loss: 0.8837, Validation Accuracy: 65.94%
# Epoch [4/40], Step [110/110], Loss: 0.7746, Accuracy: 75.86%
# Epoch [4/40], Loss: 0.8903, Validation Accuracy: 63.94%
# Epoch [5/40], Step [10/110], Loss: 0.5206, Accuracy: 90.62%
# Epoch [5/40], Loss: 0.6710, Validation Accuracy: 63.75%
# Epoch [5/40], Step [20/110], Loss: 0.8080, Accuracy: 81.25%
# Epoch [5/40], Loss: 0.8331, Validation Accuracy: 65.54%
# Epoch [5/40], Step [30/110], Loss: 0.4843, Accuracy: 90.62%
# Epoch [5/40], Loss: 0.7849, Validation Accuracy: 65.94%
# Epoch [5/40], Step [40/110], Loss: 0.4365, Accuracy: 96.88%
# Epoch [5/40], Loss: 0.7122, Validation Accuracy: 65.34%
# Epoch [5/40], Step [50/110], Loss: 0.6557, Accuracy: 78.12%
# Epoch [5/40], Loss: 0.7911, Validation Accuracy: 66.93%
# Epoch [5/40], Step [60/110], Loss: 0.3865, Accuracy: 93.75%
# Epoch [5/40], Loss: 1.0045, Validation Accuracy: 62.95%
# Epoch [5/40], Step [70/110], Loss: 0.4174, Accuracy: 87.50%
# Epoch [5/40], Loss: 0.8488, Validation Accuracy: 64.34%
# Epoch [5/40], Step [80/110], Loss: 0.4742, Accuracy: 87.50%
# Epoch [5/40], Loss: 0.8254, Validation Accuracy: 67.13%
# Epoch [5/40], Step [90/110], Loss: 0.4932, Accuracy: 87.50%
# Epoch [5/40], Loss: 0.6772, Validation Accuracy: 65.94%
# Epoch [5/40], Step [100/110], Loss: 0.5106, Accuracy: 93.75%
# Epoch [5/40], Loss: 0.7213, Validation Accuracy: 65.94%
# Epoch [5/40], Step [110/110], Loss: 0.5816, Accuracy: 82.76%
# Epoch [5/40], Loss: 0.5837, Validation Accuracy: 68.33%
# Epoch [6/40], Step [10/110], Loss: 0.5051, Accuracy: 90.62%
# Epoch [6/40], Loss: 0.7185, Validation Accuracy: 67.93%
# Epoch [6/40], Step [20/110], Loss: 0.4295, Accuracy: 96.88%
# Epoch [6/40], Loss: 0.8530, Validation Accuracy: 66.73%
# Epoch [6/40], Step [30/110], Loss: 0.3942, Accuracy: 93.75%
# Epoch [6/40], Loss: 0.7059, Validation Accuracy: 65.94%
# Epoch [6/40], Step [40/110], Loss: 0.2978, Accuracy: 96.88%
# Epoch [6/40], Loss: 0.8453, Validation Accuracy: 67.33%
# Epoch [6/40], Step [50/110], Loss: 0.3659, Accuracy: 90.62%
# Epoch [6/40], Loss: 0.8258, Validation Accuracy: 67.73%
# Epoch [6/40], Step [60/110], Loss: 0.3782, Accuracy: 93.75%
# Epoch [6/40], Loss: 0.6786, Validation Accuracy: 67.93%
# Epoch [6/40], Step [70/110], Loss: 0.2318, Accuracy: 96.88%
# Epoch [6/40], Loss: 0.7761, Validation Accuracy: 67.73%
# Epoch [6/40], Step [80/110], Loss: 0.4410, Accuracy: 90.62%
# Epoch [6/40], Loss: 0.6680, Validation Accuracy: 67.13%
# Epoch [6/40], Step [90/110], Loss: 0.3616, Accuracy: 96.88%
# Epoch [6/40], Loss: 0.6832, Validation Accuracy: 69.12%
# Epoch [6/40], Step [100/110], Loss: 0.3732, Accuracy: 96.88%
# Epoch [6/40], Loss: 0.7971, Validation Accuracy: 67.73%
# Epoch [6/40], Step [110/110], Loss: 0.5708, Accuracy: 86.21%
# Epoch [6/40], Loss: 0.5917, Validation Accuracy: 66.33%
# Epoch [7/40], Step [10/110], Loss: 0.3626, Accuracy: 90.62%
# Epoch [7/40], Loss: 0.4773, Validation Accuracy: 71.51%
# Epoch [7/40], Step [20/110], Loss: 0.6040, Accuracy: 84.38%
# Epoch [7/40], Loss: 0.5851, Validation Accuracy: 68.73%
# Epoch [7/40], Step [30/110], Loss: 0.4346, Accuracy: 93.75%
# Epoch [7/40], Loss: 0.7011, Validation Accuracy: 69.12%
# Epoch [7/40], Step [40/110], Loss: 0.3495, Accuracy: 90.62%
# Epoch [7/40], Loss: 0.6756, Validation Accuracy: 69.32%
# Epoch [7/40], Step [50/110], Loss: 0.3097, Accuracy: 93.75%
# Epoch [7/40], Loss: 0.7652, Validation Accuracy: 70.12%
# Epoch [7/40], Step [60/110], Loss: 0.2775, Accuracy: 93.75%
# Epoch [7/40], Loss: 0.6065, Validation Accuracy: 70.52%
# Epoch [7/40], Step [70/110], Loss: 0.2726, Accuracy: 96.88%
# Epoch [7/40], Loss: 0.7279, Validation Accuracy: 69.32%
# Epoch [7/40], Step [80/110], Loss: 0.4206, Accuracy: 87.50%
# Epoch [7/40], Loss: 0.7030, Validation Accuracy: 68.92%
# Epoch [7/40], Step [90/110], Loss: 0.2935, Accuracy: 93.75%
# Epoch [7/40], Loss: 0.8112, Validation Accuracy: 69.72%
# Epoch [7/40], Step [100/110], Loss: 0.2942, Accuracy: 90.62%
# Epoch [7/40], Loss: 0.6767, Validation Accuracy: 68.33%
# Epoch [7/40], Step [110/110], Loss: 0.3237, Accuracy: 96.55%
# Epoch [7/40], Loss: 0.7768, Validation Accuracy: 69.52%
# Epoch [8/40], Step [10/110], Loss: 0.2134, Accuracy: 96.88%
# Epoch [8/40], Loss: 0.8076, Validation Accuracy: 67.93%
# Epoch [8/40], Step [20/110], Loss: 0.3349, Accuracy: 93.75%
# Epoch [8/40], Loss: 0.5949, Validation Accuracy: 70.52%
# Epoch [8/40], Step [30/110], Loss: 0.3393, Accuracy: 93.75%
# Epoch [8/40], Loss: 0.7995, Validation Accuracy: 67.73%
# Epoch [8/40], Step [40/110], Loss: 0.2470, Accuracy: 96.88%
# Epoch [8/40], Loss: 0.6315, Validation Accuracy: 70.72%
# Epoch [8/40], Step [50/110], Loss: 0.3151, Accuracy: 90.62%
# Epoch [8/40], Loss: 0.5959, Validation Accuracy: 69.12%
# Epoch [8/40], Step [60/110], Loss: 0.1987, Accuracy: 100.00%
# Epoch [8/40], Loss: 0.6802, Validation Accuracy: 69.92%
# Epoch [8/40], Step [70/110], Loss: 0.2179, Accuracy: 100.00%
# Epoch [8/40], Loss: 0.7050, Validation Accuracy: 69.92%
# Epoch [8/40], Step [80/110], Loss: 0.2009, Accuracy: 96.88%
# Epoch [8/40], Loss: 0.7089, Validation Accuracy: 69.52%
# Epoch [8/40], Step [90/110], Loss: 0.2757, Accuracy: 93.75%
# Epoch [8/40], Loss: 0.8294, Validation Accuracy: 68.53%
# Epoch [8/40], Step [100/110], Loss: 0.3109, Accuracy: 96.88%
# Epoch [8/40], Loss: 0.9473, Validation Accuracy: 68.73%
# Epoch [8/40], Step [110/110], Loss: 0.2119, Accuracy: 96.55%
# Epoch [8/40], Loss: 0.7222, Validation Accuracy: 69.72%
# Epoch [9/40], Step [10/110], Loss: 0.2656, Accuracy: 96.88%
# Epoch [9/40], Loss: 0.6874, Validation Accuracy: 70.12%
# Epoch [9/40], Step [20/110], Loss: 0.2993, Accuracy: 90.62%
# Epoch [9/40], Loss: 0.5927, Validation Accuracy: 70.12%
# Epoch [9/40], Step [30/110], Loss: 0.1974, Accuracy: 100.00%
# Epoch [9/40], Loss: 0.6680, Validation Accuracy: 71.31%
# Epoch [9/40], Step [40/110], Loss: 0.2234, Accuracy: 96.88%
# Epoch [9/40], Loss: 0.5365, Validation Accuracy: 71.12%
# Epoch [9/40], Step [50/110], Loss: 0.1567, Accuracy: 100.00%
# Epoch [9/40], Loss: 0.7308, Validation Accuracy: 71.71%
# Epoch [9/40], Step [60/110], Loss: 0.1653, Accuracy: 100.00%
# Epoch [9/40], Loss: 0.6115, Validation Accuracy: 69.52%
# Epoch [9/40], Step [70/110], Loss: 0.2246, Accuracy: 100.00%
# Epoch [9/40], Loss: 0.5615, Validation Accuracy: 70.12%
# Epoch [9/40], Step [80/110], Loss: 0.1787, Accuracy: 96.88%
# Epoch [9/40], Loss: 0.5965, Validation Accuracy: 68.53%
# Epoch [9/40], Step [90/110], Loss: 0.2309, Accuracy: 93.75%
# Epoch [9/40], Loss: 0.5305, Validation Accuracy: 70.72%
# Epoch [9/40], Step [100/110], Loss: 0.2527, Accuracy: 96.88%
# Epoch [9/40], Loss: 0.6023, Validation Accuracy: 70.32%
# Epoch [9/40], Step [110/110], Loss: 0.1957, Accuracy: 96.55%
# Epoch [9/40], Loss: 0.6996, Validation Accuracy: 69.92%
# Epoch [10/40], Step [10/110], Loss: 0.0898, Accuracy: 100.00%
# Epoch [10/40], Loss: 0.5623, Validation Accuracy: 69.92%
# Epoch [10/40], Step [20/110], Loss: 0.2664, Accuracy: 93.75%
# Epoch [10/40], Loss: 0.5302, Validation Accuracy: 69.12%
# Epoch [10/40], Step [30/110], Loss: 0.1942, Accuracy: 100.00%
# Epoch [10/40], Loss: 0.5960, Validation Accuracy: 70.52%
# Epoch [10/40], Step [40/110], Loss: 0.1656, Accuracy: 96.88%
# Epoch [10/40], Loss: 0.6805, Validation Accuracy: 71.12%
# Epoch [10/40], Step [50/110], Loss: 0.1632, Accuracy: 100.00%
# Epoch [10/40], Loss: 0.5633, Validation Accuracy: 70.72%
# Epoch [10/40], Step [60/110], Loss: 0.2993, Accuracy: 96.88%
# Epoch [10/40], Loss: 0.5804, Validation Accuracy: 69.92%
# Epoch [10/40], Step [70/110], Loss: 0.1588, Accuracy: 100.00%
# Epoch [10/40], Loss: 0.6421, Validation Accuracy: 70.12%
# Epoch [10/40], Step [80/110], Loss: 0.2127, Accuracy: 100.00%
# Epoch [10/40], Loss: 0.6514, Validation Accuracy: 70.52%
# Epoch [10/40], Step [90/110], Loss: 0.1098, Accuracy: 100.00%
# Epoch [10/40], Loss: 0.5814, Validation Accuracy: 71.51%
# Epoch [10/40], Step [100/110], Loss: 0.1794, Accuracy: 93.75%
# Epoch [10/40], Loss: 0.4620, Validation Accuracy: 71.71%
# Epoch [10/40], Step [110/110], Loss: 0.1824, Accuracy: 96.55%
# Epoch [10/40], Loss: 0.5593, Validation Accuracy: 71.71%
# Epoch [11/40], Step [10/110], Loss: 0.1471, Accuracy: 100.00%
# Epoch [11/40], Loss: 0.5237, Validation Accuracy: 71.51%
# Epoch [11/40], Step [20/110], Loss: 0.1664, Accuracy: 100.00%
# Epoch [11/40], Loss: 0.7223, Validation Accuracy: 69.12%
# Epoch [11/40], Step [30/110], Loss: 0.1886, Accuracy: 93.75%
# Epoch [11/40], Loss: 0.5773, Validation Accuracy: 72.51%
# Epoch [11/40], Step [40/110], Loss: 0.1412, Accuracy: 96.88%
# Epoch [11/40], Loss: 0.5082, Validation Accuracy: 70.72%
# Epoch [11/40], Step [50/110], Loss: 0.1240, Accuracy: 100.00%
# Epoch [11/40], Loss: 0.5484, Validation Accuracy: 71.91%
# Epoch [11/40], Step [60/110], Loss: 0.1311, Accuracy: 96.88%
# Epoch [11/40], Loss: 0.5568, Validation Accuracy: 69.92%
# Epoch [11/40], Step [70/110], Loss: 0.1690, Accuracy: 100.00%
# Epoch [11/40], Loss: 0.6109, Validation Accuracy: 72.51%
# Epoch [11/40], Step [80/110], Loss: 0.1974, Accuracy: 96.88%
# Epoch [11/40], Loss: 0.5494, Validation Accuracy: 72.31%
# Epoch [11/40], Step [90/110], Loss: 0.1222, Accuracy: 100.00%
# Epoch [11/40], Loss: 0.5422, Validation Accuracy: 70.72%
# Epoch [11/40], Step [100/110], Loss: 0.2137, Accuracy: 96.88%
# Epoch [11/40], Loss: 0.4772, Validation Accuracy: 72.51%
# Epoch [11/40], Step [110/110], Loss: 0.3128, Accuracy: 93.10%
# Epoch [11/40], Loss: 0.3760, Validation Accuracy: 70.32%
# Epoch [12/40], Step [10/110], Loss: 0.3912, Accuracy: 96.88%
# Epoch [12/40], Loss: 0.4438, Validation Accuracy: 71.51%
# Epoch [12/40], Step [20/110], Loss: 0.1156, Accuracy: 100.00%
# Epoch [12/40], Loss: 0.6814, Validation Accuracy: 70.32%
# Epoch [12/40], Step [30/110], Loss: 0.1497, Accuracy: 93.75%
# Epoch [12/40], Loss: 0.5781, Validation Accuracy: 72.31%
# Epoch [12/40], Step [40/110], Loss: 0.1137, Accuracy: 96.88%
# Epoch [12/40], Loss: 0.5120, Validation Accuracy: 71.51%
# Epoch [12/40], Step [50/110], Loss: 0.1861, Accuracy: 100.00%
# Epoch [12/40], Loss: 0.7975, Validation Accuracy: 70.52%
# Epoch [12/40], Step [60/110], Loss: 0.1102, Accuracy: 100.00%
# Epoch [12/40], Loss: 0.5505, Validation Accuracy: 71.31%
# Epoch [12/40], Step [70/110], Loss: 0.0949, Accuracy: 100.00%
# Epoch [12/40], Loss: 0.5351, Validation Accuracy: 72.31%
# Epoch [12/40], Step [80/110], Loss: 0.1615, Accuracy: 96.88%
# Epoch [12/40], Loss: 0.5399, Validation Accuracy: 70.52%
# Epoch [12/40], Step [90/110], Loss: 0.1546, Accuracy: 96.88%
# Epoch [12/40], Loss: 0.5385, Validation Accuracy: 72.91%
# Epoch [12/40], Step [100/110], Loss: 0.1079, Accuracy: 100.00%
# Epoch [12/40], Loss: 0.4353, Validation Accuracy: 72.11%
# Epoch [12/40], Step [110/110], Loss: 0.1145, Accuracy: 100.00%
# Epoch [12/40], Loss: 0.4059, Validation Accuracy: 72.11%
# Epoch [13/40], Step [10/110], Loss: 0.1447, Accuracy: 100.00%
# Epoch [13/40], Loss: 0.6477, Validation Accuracy: 69.92%
# Epoch [13/40], Step [20/110], Loss: 0.1412, Accuracy: 93.75%
# Epoch [13/40], Loss: 0.5160, Validation Accuracy: 71.71%
# Epoch [13/40], Step [30/110], Loss: 0.1076, Accuracy: 100.00%
# Epoch [13/40], Loss: 0.4530, Validation Accuracy: 71.51%
# Epoch [13/40], Step [40/110], Loss: 0.1391, Accuracy: 100.00%
# Epoch [13/40], Loss: 0.3928, Validation Accuracy: 72.91%
# Epoch [13/40], Step [50/110], Loss: 0.0891, Accuracy: 100.00%
# Epoch [13/40], Loss: 0.5248, Validation Accuracy: 71.91%
# Epoch [13/40], Step [60/110], Loss: 0.1521, Accuracy: 96.88%
# Epoch [13/40], Loss: 0.5081, Validation Accuracy: 71.71%
# Epoch [13/40], Step [70/110], Loss: 0.1409, Accuracy: 96.88%
# Epoch [13/40], Loss: 0.6714, Validation Accuracy: 71.12%
# Epoch [13/40], Step [80/110], Loss: 0.0825, Accuracy: 100.00%
# Epoch [13/40], Loss: 0.6863, Validation Accuracy: 71.12%
# Epoch [13/40], Step [90/110], Loss: 0.1288, Accuracy: 96.88%
# Epoch [13/40], Loss: 0.5477, Validation Accuracy: 72.11%
# Epoch [13/40], Step [100/110], Loss: 0.0863, Accuracy: 100.00%
# Epoch [13/40], Loss: 0.4666, Validation Accuracy: 72.31%
# Epoch [13/40], Step [110/110], Loss: 0.0882, Accuracy: 100.00%
# Epoch [13/40], Loss: 0.5868, Validation Accuracy: 71.31%
# Epoch [14/40], Step [10/110], Loss: 0.0889, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.5612, Validation Accuracy: 71.12%
# Epoch [14/40], Step [20/110], Loss: 0.1189, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.5129, Validation Accuracy: 72.71%
# Epoch [14/40], Step [30/110], Loss: 0.0973, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.4329, Validation Accuracy: 71.71%
# Epoch [14/40], Step [40/110], Loss: 0.0704, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.4688, Validation Accuracy: 71.71%
# Epoch [14/40], Step [50/110], Loss: 0.0851, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.4719, Validation Accuracy: 72.91%
# Epoch [14/40], Step [60/110], Loss: 0.1161, Accuracy: 96.88%
# Epoch [14/40], Loss: 0.3560, Validation Accuracy: 72.71%
# Epoch [14/40], Step [70/110], Loss: 0.0853, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.4847, Validation Accuracy: 73.11%
# Epoch [14/40], Step [80/110], Loss: 0.1750, Accuracy: 93.75%
# Epoch [14/40], Loss: 0.6503, Validation Accuracy: 71.31%
# Epoch [14/40], Step [90/110], Loss: 0.0872, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.6776, Validation Accuracy: 71.91%
# Epoch [14/40], Step [100/110], Loss: 0.1228, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.5338, Validation Accuracy: 71.71%
# Epoch [14/40], Step [110/110], Loss: 0.0865, Accuracy: 100.00%
# Epoch [14/40], Loss: 0.6949, Validation Accuracy: 70.52%
# Epoch [15/40], Step [10/110], Loss: 0.0359, Accuracy: 100.00%
# Epoch [15/40], Loss: 0.4388, Validation Accuracy: 71.51%
# Epoch [15/40], Step [20/110], Loss: 0.1242, Accuracy: 100.00%
# Epoch [15/40], Loss: 0.6747, Validation Accuracy: 71.71%
# Epoch [15/40], Step [30/110], Loss: 0.0793, Accuracy: 100.00%
# Epoch [15/40], Loss: 0.5679, Validation Accuracy: 70.52%
# Epoch [15/40], Step [40/110], Loss: 0.0568, Accuracy: 100.00%
# Epoch [15/40], Loss: 0.5507, Validation Accuracy: 73.51%
# Epoch [15/40], Step [50/110], Loss: 0.0635, Accuracy: 100.00%
# Epoch [15/40], Loss: 0.5701, Validation Accuracy: 71.51%
# Epoch [15/40], Step [60/110], Loss: 0.0618, Accuracy: 100.00%
# Epoch [15/40], Loss: 0.4970, Validation Accuracy: 72.11%
# Epoch [15/40], Step [70/110], Loss: 0.1142, Accuracy: 96.88%
# Epoch [15/40], Loss: 0.6085, Validation Accuracy: 72.11%
# Epoch [15/40], Step [80/110], Loss: 0.0819, Accuracy: 100.00%
# Epoch [15/40], Loss: 0.4059, Validation Accuracy: 70.52%
# Epoch [15/40], Step [90/110], Loss: 0.1501, Accuracy: 96.88%
# Epoch [15/40], Loss: 0.5245, Validation Accuracy: 71.31%
# Epoch [15/40], Step [100/110], Loss: 0.0593, Accuracy: 100.00%
# Epoch [15/40], Loss: 0.4765, Validation Accuracy: 72.91%
# Epoch [15/40], Step [110/110], Loss: 0.1127, Accuracy: 96.55%
# Epoch [15/40], Loss: 0.5644, Validation Accuracy: 72.51%
# Epoch [16/40], Step [10/110], Loss: 0.0800, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.4335, Validation Accuracy: 72.11%
# Epoch [16/40], Step [20/110], Loss: 0.0748, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.5572, Validation Accuracy: 72.91%
# Epoch [16/40], Step [30/110], Loss: 0.0735, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.6147, Validation Accuracy: 72.51%
# Epoch [16/40], Step [40/110], Loss: 0.0779, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.5117, Validation Accuracy: 71.71%
# Epoch [16/40], Step [50/110], Loss: 0.0971, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.3445, Validation Accuracy: 71.51%
# Epoch [16/40], Step [60/110], Loss: 0.0933, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.4227, Validation Accuracy: 72.71%
# Epoch [16/40], Step [70/110], Loss: 0.0955, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.4771, Validation Accuracy: 72.51%
# Epoch [16/40], Step [80/110], Loss: 0.0609, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.5196, Validation Accuracy: 73.11%
# Epoch [16/40], Step [90/110], Loss: 0.1330, Accuracy: 96.88%
# Epoch [16/40], Loss: 0.4987, Validation Accuracy: 73.71%
# Epoch [16/40], Step [100/110], Loss: 0.0751, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.5186, Validation Accuracy: 72.71%
# Epoch [16/40], Step [110/110], Loss: 0.1044, Accuracy: 100.00%
# Epoch [16/40], Loss: 0.4401, Validation Accuracy: 71.91%
# Epoch [17/40], Step [10/110], Loss: 0.0539, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.3511, Validation Accuracy: 71.71%
# Epoch [17/40], Step [20/110], Loss: 0.0471, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.3991, Validation Accuracy: 72.11%
# Epoch [17/40], Step [30/110], Loss: 0.0872, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.3302, Validation Accuracy: 71.51%
# Epoch [17/40], Step [40/110], Loss: 0.0558, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.3735, Validation Accuracy: 73.11%
# Epoch [17/40], Step [50/110], Loss: 0.0592, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.4899, Validation Accuracy: 72.71%
# Epoch [17/40], Step [60/110], Loss: 0.0769, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.5317, Validation Accuracy: 72.31%
# Epoch [17/40], Step [70/110], Loss: 0.0704, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.6021, Validation Accuracy: 72.11%
# Epoch [17/40], Step [80/110], Loss: 0.0835, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.5116, Validation Accuracy: 72.51%
# Epoch [17/40], Step [90/110], Loss: 0.0552, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.4383, Validation Accuracy: 72.31%
# Epoch [17/40], Step [100/110], Loss: 0.0758, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.5582, Validation Accuracy: 72.51%
# Epoch [17/40], Step [110/110], Loss: 0.0627, Accuracy: 100.00%
# Epoch [17/40], Loss: 0.5387, Validation Accuracy: 71.71%
# Epoch [18/40], Step [10/110], Loss: 0.0364, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.3934, Validation Accuracy: 71.31%
# Epoch [18/40], Step [20/110], Loss: 0.0566, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.5645, Validation Accuracy: 72.11%
# Epoch [18/40], Step [30/110], Loss: 0.0800, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.5449, Validation Accuracy: 72.11%
# Epoch [18/40], Step [40/110], Loss: 0.0705, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.4684, Validation Accuracy: 72.71%
# Epoch [18/40], Step [50/110], Loss: 0.1433, Accuracy: 93.75%
# Epoch [18/40], Loss: 0.4708, Validation Accuracy: 73.11%
# Epoch [18/40], Step [60/110], Loss: 0.0773, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.5240, Validation Accuracy: 73.11%
# Epoch [18/40], Step [70/110], Loss: 0.0561, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.5916, Validation Accuracy: 72.11%
# Epoch [18/40], Step [80/110], Loss: 0.0670, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.4615, Validation Accuracy: 72.91%
# Epoch [18/40], Step [90/110], Loss: 0.0516, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.3594, Validation Accuracy: 73.11%
# Epoch [18/40], Step [100/110], Loss: 0.0864, Accuracy: 96.88%
# Epoch [18/40], Loss: 0.5290, Validation Accuracy: 72.91%
# Epoch [18/40], Step [110/110], Loss: 0.1094, Accuracy: 100.00%
# Epoch [18/40], Loss: 0.4716, Validation Accuracy: 74.10%
# Epoch [19/40], Step [10/110], Loss: 0.0502, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.4798, Validation Accuracy: 72.51%
# Epoch [19/40], Step [20/110], Loss: 0.0623, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.5328, Validation Accuracy: 72.51%
# Epoch [19/40], Step [30/110], Loss: 0.0758, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.5655, Validation Accuracy: 73.11%
# Epoch [19/40], Step [40/110], Loss: 0.1047, Accuracy: 96.88%
# Epoch [19/40], Loss: 0.6516, Validation Accuracy: 70.92%
# Epoch [19/40], Step [50/110], Loss: 0.0619, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.4841, Validation Accuracy: 71.31%
# Epoch [19/40], Step [60/110], Loss: 0.0983, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.5370, Validation Accuracy: 71.91%
# Epoch [19/40], Step [70/110], Loss: 0.0715, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.4943, Validation Accuracy: 72.11%
# Epoch [19/40], Step [80/110], Loss: 0.0645, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.4786, Validation Accuracy: 71.71%
# Epoch [19/40], Step [90/110], Loss: 0.0519, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.4170, Validation Accuracy: 73.11%
# Epoch [19/40], Step [100/110], Loss: 0.0667, Accuracy: 100.00%
# Epoch [19/40], Loss: 0.4384, Validation Accuracy: 72.11%
# Epoch [19/40], Step [110/110], Loss: 0.1926, Accuracy: 96.55%
# Epoch [19/40], Loss: 0.5762, Validation Accuracy: 71.31%
# Epoch [20/40], Step [10/110], Loss: 0.0415, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.6156, Validation Accuracy: 70.52%
# Epoch [20/40], Step [20/110], Loss: 0.0751, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.5836, Validation Accuracy: 70.92%
# Epoch [20/40], Step [30/110], Loss: 0.0411, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.4273, Validation Accuracy: 72.11%
# Epoch [20/40], Step [40/110], Loss: 0.0363, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.3844, Validation Accuracy: 72.71%
# Epoch [20/40], Step [50/110], Loss: 0.0668, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.5211, Validation Accuracy: 72.91%
# Epoch [20/40], Step [60/110], Loss: 0.0771, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.5143, Validation Accuracy: 74.10%
# Epoch [20/40], Step [70/110], Loss: 0.1293, Accuracy: 96.88%
# Epoch [20/40], Loss: 0.5427, Validation Accuracy: 71.51%
# Epoch [20/40], Step [80/110], Loss: 0.0643, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.5345, Validation Accuracy: 71.91%
# Epoch [20/40], Step [90/110], Loss: 0.0435, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.6730, Validation Accuracy: 70.72%
# Epoch [20/40], Step [100/110], Loss: 0.0765, Accuracy: 100.00%
# Epoch [20/40], Loss: 0.4516, Validation Accuracy: 72.31%
# Epoch [20/40], Step [110/110], Loss: 0.0855, Accuracy: 96.55%
# Epoch [20/40], Loss: 0.4594, Validation Accuracy: 71.91%
# Epoch [21/40], Step [10/110], Loss: 0.0946, Accuracy: 100.00%
# Epoch [21/40], Loss: 0.4990, Validation Accuracy: 69.92%
# Epoch [21/40], Step [20/110], Loss: 0.0812, Accuracy: 96.88%
# Epoch [21/40], Loss: 0.3696, Validation Accuracy: 72.31%
# Epoch [21/40], Step [30/110], Loss: 0.0703, Accuracy: 100.00%
# Epoch [21/40], Loss: 0.5064, Validation Accuracy: 71.91%
# Epoch [21/40], Step [40/110], Loss: 0.0660, Accuracy: 100.00%
# Epoch [21/40], Loss: 0.3873, Validation Accuracy: 73.90%
# Epoch [21/40], Step [50/110], Loss: 0.1447, Accuracy: 96.88%
# Epoch [21/40], Loss: 0.3901, Validation Accuracy: 71.71%
# Epoch [21/40], Step [60/110], Loss: 0.0453, Accuracy: 100.00%
# Epoch [21/40], Loss: 0.3974, Validation Accuracy: 72.51%
# Epoch [21/40], Step [70/110], Loss: 0.1167, Accuracy: 96.88%
# Epoch [21/40], Loss: 0.4382, Validation Accuracy: 70.72%
# Epoch [21/40], Step [80/110], Loss: 0.0249, Accuracy: 100.00%
# Epoch [21/40], Loss: 0.6130, Validation Accuracy: 72.11%
# Epoch [21/40], Step [90/110], Loss: 0.0670, Accuracy: 100.00%
# Epoch [21/40], Loss: 0.5097, Validation Accuracy: 70.72%
# Epoch [21/40], Step [100/110], Loss: 0.1161, Accuracy: 96.88%
# Epoch [21/40], Loss: 0.5257, Validation Accuracy: 72.31%
# Epoch [21/40], Step [110/110], Loss: 0.0745, Accuracy: 100.00%
# Epoch [21/40], Loss: 0.5525, Validation Accuracy: 72.91%
# Epoch [22/40], Step [10/110], Loss: 0.0259, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.5114, Validation Accuracy: 71.71%
# Epoch [22/40], Step [20/110], Loss: 0.0397, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.5616, Validation Accuracy: 72.71%
# Epoch [22/40], Step [30/110], Loss: 0.0362, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.5015, Validation Accuracy: 72.51%
# Epoch [22/40], Step [40/110], Loss: 0.0348, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.5950, Validation Accuracy: 71.12%
# Epoch [22/40], Step [50/110], Loss: 0.0416, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.5161, Validation Accuracy: 73.90%
# Epoch [22/40], Step [60/110], Loss: 0.0388, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.5705, Validation Accuracy: 71.51%
# Epoch [22/40], Step [70/110], Loss: 0.0364, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.3408, Validation Accuracy: 72.51%
# Epoch [22/40], Step [80/110], Loss: 0.0512, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.3816, Validation Accuracy: 72.71%
# Epoch [22/40], Step [90/110], Loss: 0.0478, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.3867, Validation Accuracy: 72.91%
# Epoch [22/40], Step [100/110], Loss: 0.0520, Accuracy: 100.00%
# Epoch [22/40], Loss: 0.5877, Validation Accuracy: 72.71%
# Epoch [22/40], Step [110/110], Loss: 0.0909, Accuracy: 96.55%
# Epoch [22/40], Loss: 0.4392, Validation Accuracy: 72.31%
# Epoch [23/40], Step [10/110], Loss: 0.0566, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.5961, Validation Accuracy: 71.91%
# Epoch [23/40], Step [20/110], Loss: 0.0725, Accuracy: 96.88%
# Epoch [23/40], Loss: 0.6326, Validation Accuracy: 71.91%
# Epoch [23/40], Step [30/110], Loss: 0.0382, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.4602, Validation Accuracy: 72.11%
# Epoch [23/40], Step [40/110], Loss: 0.0318, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.6326, Validation Accuracy: 71.91%
# Epoch [23/40], Step [50/110], Loss: 0.0394, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.4575, Validation Accuracy: 73.11%
# Epoch [23/40], Step [60/110], Loss: 0.0306, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.3724, Validation Accuracy: 72.11%
# Epoch [23/40], Step [70/110], Loss: 0.0486, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.5234, Validation Accuracy: 71.91%
# Epoch [23/40], Step [80/110], Loss: 0.0321, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.5482, Validation Accuracy: 71.91%
# Epoch [23/40], Step [90/110], Loss: 0.0345, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.5685, Validation Accuracy: 72.71%
# Epoch [23/40], Step [100/110], Loss: 0.0379, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.5509, Validation Accuracy: 70.92%
# Epoch [23/40], Step [110/110], Loss: 0.0350, Accuracy: 100.00%
# Epoch [23/40], Loss: 0.4514, Validation Accuracy: 74.30%
# Epoch [24/40], Step [10/110], Loss: 0.0753, Accuracy: 100.00%
# Epoch [24/40], Loss: 0.4943, Validation Accuracy: 72.31%
# Epoch [24/40], Step [20/110], Loss: 0.0380, Accuracy: 100.00%
# Epoch [24/40], Loss: 0.3921, Validation Accuracy: 71.71%
# Epoch [24/40], Step [30/110], Loss: 0.1148, Accuracy: 96.88%
# Epoch [24/40], Loss: 0.4092, Validation Accuracy: 73.31%
# Epoch [24/40], Step [40/110], Loss: 0.0355, Accuracy: 100.00%
# Epoch [24/40], Loss: 0.5298, Validation Accuracy: 71.91%
# Epoch [24/40], Step [50/110], Loss: 0.0527, Accuracy: 100.00%
# Epoch [24/40], Loss: 0.5427, Validation Accuracy: 71.51%
# Epoch [24/40], Step [60/110], Loss: 0.0926, Accuracy: 96.88%
# Epoch [24/40], Loss: 0.6795, Validation Accuracy: 72.11%
# Epoch [24/40], Step [70/110], Loss: 0.0289, Accuracy: 100.00%
# Epoch [24/40], Loss: 0.4623, Validation Accuracy: 72.11%
# Epoch [24/40], Step [80/110], Loss: 0.0254, Accuracy: 100.00%
# Epoch [24/40], Loss: 0.3408, Validation Accuracy: 72.71%
# Epoch [24/40], Step [90/110], Loss: 0.0300, Accuracy: 100.00%
# Epoch [24/40], Loss: 0.3733, Validation Accuracy: 71.51%
# Epoch [24/40], Step [100/110], Loss: 0.0686, Accuracy: 96.88%
# Epoch [24/40], Loss: 0.5308, Validation Accuracy: 72.71%
# Epoch [24/40], Step [110/110], Loss: 0.0271, Accuracy: 100.00%
# Epoch [24/40], Loss: 0.4551, Validation Accuracy: 70.72%
# Epoch [25/40], Step [10/110], Loss: 0.0426, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.4385, Validation Accuracy: 72.51%
# Epoch [25/40], Step [20/110], Loss: 0.0348, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.5385, Validation Accuracy: 71.71%
# Epoch [25/40], Step [30/110], Loss: 0.0221, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.4038, Validation Accuracy: 71.71%
# Epoch [25/40], Step [40/110], Loss: 0.0186, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.4452, Validation Accuracy: 71.91%
# Epoch [25/40], Step [50/110], Loss: 0.0765, Accuracy: 96.88%
# Epoch [25/40], Loss: 0.4896, Validation Accuracy: 71.51%
# Epoch [25/40], Step [60/110], Loss: 0.0788, Accuracy: 96.88%
# Epoch [25/40], Loss: 0.5443, Validation Accuracy: 69.92%
# Epoch [25/40], Step [70/110], Loss: 0.0235, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.4770, Validation Accuracy: 71.91%
# Epoch [25/40], Step [80/110], Loss: 0.0569, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.3425, Validation Accuracy: 72.51%
# Epoch [25/40], Step [90/110], Loss: 0.0331, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.3952, Validation Accuracy: 71.71%
# Epoch [25/40], Step [100/110], Loss: 0.0372, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.5063, Validation Accuracy: 73.31%
# Epoch [25/40], Step [110/110], Loss: 0.0398, Accuracy: 100.00%
# Epoch [25/40], Loss: 0.4078, Validation Accuracy: 72.11%
# Epoch [26/40], Step [10/110], Loss: 0.0243, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.3761, Validation Accuracy: 72.11%
# Epoch [26/40], Step [20/110], Loss: 0.0616, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.3502, Validation Accuracy: 72.91%
# Epoch [26/40], Step [30/110], Loss: 0.0287, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.4541, Validation Accuracy: 72.11%
# Epoch [26/40], Step [40/110], Loss: 0.0408, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.5100, Validation Accuracy: 72.51%
# Epoch [26/40], Step [50/110], Loss: 0.0197, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.3239, Validation Accuracy: 71.51%
# Epoch [26/40], Step [60/110], Loss: 0.0288, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.3665, Validation Accuracy: 71.51%
# Epoch [26/40], Step [70/110], Loss: 0.0557, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.3774, Validation Accuracy: 73.11%
# Epoch [26/40], Step [80/110], Loss: 0.0263, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.4672, Validation Accuracy: 72.31%
# Epoch [26/40], Step [90/110], Loss: 0.2568, Accuracy: 93.75%
# Epoch [26/40], Loss: 0.4156, Validation Accuracy: 71.31%
# Epoch [26/40], Step [100/110], Loss: 0.0462, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.4866, Validation Accuracy: 72.11%
# Epoch [26/40], Step [110/110], Loss: 0.0527, Accuracy: 100.00%
# Epoch [26/40], Loss: 0.3133, Validation Accuracy: 72.11%
# Epoch [27/40], Step [10/110], Loss: 0.0194, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.2814, Validation Accuracy: 71.71%
# Epoch [27/40], Step [20/110], Loss: 0.0359, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.4091, Validation Accuracy: 70.72%
# Epoch [27/40], Step [30/110], Loss: 0.0169, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.2940, Validation Accuracy: 72.91%
# Epoch [27/40], Step [40/110], Loss: 0.1033, Accuracy: 96.88%
# Epoch [27/40], Loss: 0.4941, Validation Accuracy: 72.51%
# Epoch [27/40], Step [50/110], Loss: 0.0363, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.3975, Validation Accuracy: 71.91%
# Epoch [27/40], Step [60/110], Loss: 0.1109, Accuracy: 93.75%
# Epoch [27/40], Loss: 0.4065, Validation Accuracy: 72.11%
# Epoch [27/40], Step [70/110], Loss: 0.0228, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.3746, Validation Accuracy: 72.31%
# Epoch [27/40], Step [80/110], Loss: 0.0316, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.3848, Validation Accuracy: 72.31%
# Epoch [27/40], Step [90/110], Loss: 0.0384, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.5671, Validation Accuracy: 72.11%
# Epoch [27/40], Step [100/110], Loss: 0.0224, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.4522, Validation Accuracy: 72.91%
# Epoch [27/40], Step [110/110], Loss: 0.0201, Accuracy: 100.00%
# Epoch [27/40], Loss: 0.3672, Validation Accuracy: 73.11%
# Epoch [28/40], Step [10/110], Loss: 0.0636, Accuracy: 96.88%
# Epoch [28/40], Loss: 0.3869, Validation Accuracy: 72.31%
# Epoch [28/40], Step [20/110], Loss: 0.0301, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.4584, Validation Accuracy: 72.11%
# Epoch [28/40], Step [30/110], Loss: 0.0295, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.4560, Validation Accuracy: 73.51%
# Epoch [28/40], Step [40/110], Loss: 0.0160, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.4108, Validation Accuracy: 72.91%
# Epoch [28/40], Step [50/110], Loss: 0.1516, Accuracy: 96.88%
# Epoch [28/40], Loss: 0.3877, Validation Accuracy: 73.71%
# Epoch [28/40], Step [60/110], Loss: 0.0146, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.4428, Validation Accuracy: 72.31%
# Epoch [28/40], Step [70/110], Loss: 0.0287, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.3987, Validation Accuracy: 71.91%
# Epoch [28/40], Step [80/110], Loss: 0.0231, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.5745, Validation Accuracy: 71.71%
# Epoch [28/40], Step [90/110], Loss: 0.0259, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.3877, Validation Accuracy: 71.51%
# Epoch [28/40], Step [100/110], Loss: 0.0250, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.3240, Validation Accuracy: 72.51%
# Epoch [28/40], Step [110/110], Loss: 0.0347, Accuracy: 100.00%
# Epoch [28/40], Loss: 0.5030, Validation Accuracy: 72.91%
# Epoch [29/40], Step [10/110], Loss: 0.0157, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.5208, Validation Accuracy: 72.91%
# Epoch [29/40], Step [20/110], Loss: 0.3502, Accuracy: 93.75%
# Epoch [29/40], Loss: 0.4199, Validation Accuracy: 73.11%
# Epoch [29/40], Step [30/110], Loss: 0.0271, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.5122, Validation Accuracy: 72.11%
# Epoch [29/40], Step [40/110], Loss: 0.0162, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.4867, Validation Accuracy: 72.11%
# Epoch [29/40], Step [50/110], Loss: 0.0595, Accuracy: 96.88%
# Epoch [29/40], Loss: 0.5258, Validation Accuracy: 72.91%
# Epoch [29/40], Step [60/110], Loss: 0.0153, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.4387, Validation Accuracy: 72.71%
# Epoch [29/40], Step [70/110], Loss: 0.0286, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.2921, Validation Accuracy: 71.12%
# Epoch [29/40], Step [80/110], Loss: 0.0243, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.3229, Validation Accuracy: 73.11%
# Epoch [29/40], Step [90/110], Loss: 0.0302, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.5204, Validation Accuracy: 72.11%
# Epoch [29/40], Step [100/110], Loss: 0.0411, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.4905, Validation Accuracy: 71.12%
# Epoch [29/40], Step [110/110], Loss: 0.0316, Accuracy: 100.00%
# Epoch [29/40], Loss: 0.3697, Validation Accuracy: 72.31%
# Epoch [30/40], Step [10/110], Loss: 0.0210, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.2555, Validation Accuracy: 72.31%
# Epoch [30/40], Step [20/110], Loss: 0.0204, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.3604, Validation Accuracy: 72.11%
# Epoch [30/40], Step [30/110], Loss: 0.0183, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.3525, Validation Accuracy: 71.31%
# Epoch [30/40], Step [40/110], Loss: 0.0244, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.3928, Validation Accuracy: 72.51%
# Epoch [30/40], Step [50/110], Loss: 0.0156, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.3589, Validation Accuracy: 71.71%
# Epoch [30/40], Step [60/110], Loss: 0.0189, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.3445, Validation Accuracy: 70.92%
# Epoch [30/40], Step [70/110], Loss: 0.1428, Accuracy: 93.75%
# Epoch [30/40], Loss: 0.4530, Validation Accuracy: 72.91%
# Epoch [30/40], Step [80/110], Loss: 0.0332, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.5746, Validation Accuracy: 72.51%
# Epoch [30/40], Step [90/110], Loss: 0.0247, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.4555, Validation Accuracy: 72.71%
# Epoch [30/40], Step [100/110], Loss: 0.1921, Accuracy: 96.88%
# Epoch [30/40], Loss: 0.6808, Validation Accuracy: 71.51%
# Epoch [30/40], Step [110/110], Loss: 0.0295, Accuracy: 100.00%
# Epoch [30/40], Loss: 0.4413, Validation Accuracy: 72.71%
# Epoch [31/40], Step [10/110], Loss: 0.0280, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.6065, Validation Accuracy: 73.90%
# Epoch [31/40], Step [20/110], Loss: 0.2239, Accuracy: 96.88%
# Epoch [31/40], Loss: 0.5875, Validation Accuracy: 72.91%
# Epoch [31/40], Step [30/110], Loss: 0.0247, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.5134, Validation Accuracy: 71.91%
# Epoch [31/40], Step [40/110], Loss: 0.0332, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.4453, Validation Accuracy: 73.51%
# Epoch [31/40], Step [50/110], Loss: 0.0141, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.6325, Validation Accuracy: 71.31%
# Epoch [31/40], Step [60/110], Loss: 0.0319, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.4366, Validation Accuracy: 73.11%
# Epoch [31/40], Step [70/110], Loss: 0.0174, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.6125, Validation Accuracy: 71.31%
# Epoch [31/40], Step [80/110], Loss: 0.0163, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.3322, Validation Accuracy: 71.91%
# Epoch [31/40], Step [90/110], Loss: 0.0258, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.4053, Validation Accuracy: 73.11%
# Epoch [31/40], Step [100/110], Loss: 0.0336, Accuracy: 100.00%
# Epoch [31/40], Loss: 0.4492, Validation Accuracy: 71.71%
# Epoch [31/40], Step [110/110], Loss: 0.3580, Accuracy: 89.66%
# Epoch [31/40], Loss: 0.6056, Validation Accuracy: 74.30%
# Epoch [32/40], Step [10/110], Loss: 0.0353, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.5068, Validation Accuracy: 70.72%
# Epoch [32/40], Step [20/110], Loss: 0.0161, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.4923, Validation Accuracy: 72.51%
# Epoch [32/40], Step [30/110], Loss: 0.0413, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.3886, Validation Accuracy: 72.11%
# Epoch [32/40], Step [40/110], Loss: 0.0283, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.4555, Validation Accuracy: 72.11%
# Epoch [32/40], Step [50/110], Loss: 0.0121, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.4996, Validation Accuracy: 72.31%
# Epoch [32/40], Step [60/110], Loss: 0.0129, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.3963, Validation Accuracy: 73.51%
# Epoch [32/40], Step [70/110], Loss: 0.0271, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.5621, Validation Accuracy: 72.91%
# Epoch [32/40], Step [80/110], Loss: 0.2060, Accuracy: 96.88%
# Epoch [32/40], Loss: 0.5719, Validation Accuracy: 71.91%
# Epoch [32/40], Step [90/110], Loss: 0.0293, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.5458, Validation Accuracy: 72.11%
# Epoch [32/40], Step [100/110], Loss: 0.0700, Accuracy: 100.00%
# Epoch [32/40], Loss: 0.5641, Validation Accuracy: 71.51%
# Epoch [32/40], Step [110/110], Loss: 0.1104, Accuracy: 96.55%
# Epoch [32/40], Loss: 0.4158, Validation Accuracy: 72.11%
# Epoch [33/40], Step [10/110], Loss: 0.0517, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.6802, Validation Accuracy: 71.12%
# Epoch [33/40], Step [20/110], Loss: 0.0150, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.4841, Validation Accuracy: 72.51%
# Epoch [33/40], Step [30/110], Loss: 0.0384, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.3570, Validation Accuracy: 72.71%
# Epoch [33/40], Step [40/110], Loss: 0.0134, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.4621, Validation Accuracy: 72.71%
# Epoch [33/40], Step [50/110], Loss: 0.0405, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.5873, Validation Accuracy: 73.90%
# Epoch [33/40], Step [60/110], Loss: 0.1327, Accuracy: 96.88%
# Epoch [33/40], Loss: 0.4421, Validation Accuracy: 72.91%
# Epoch [33/40], Step [70/110], Loss: 0.0619, Accuracy: 96.88%
# Epoch [33/40], Loss: 0.3475, Validation Accuracy: 70.92%
# Epoch [33/40], Step [80/110], Loss: 0.0313, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.4038, Validation Accuracy: 73.31%
# Epoch [33/40], Step [90/110], Loss: 0.0260, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.5507, Validation Accuracy: 73.90%
# Epoch [33/40], Step [100/110], Loss: 0.0168, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.3484, Validation Accuracy: 71.71%
# Epoch [33/40], Step [110/110], Loss: 0.0118, Accuracy: 100.00%
# Epoch [33/40], Loss: 0.2815, Validation Accuracy: 71.31%
# Epoch [34/40], Step [10/110], Loss: 0.0164, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.3750, Validation Accuracy: 71.51%
# Epoch [34/40], Step [20/110], Loss: 0.0338, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.4388, Validation Accuracy: 72.31%
# Epoch [34/40], Step [30/110], Loss: 0.0211, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.3773, Validation Accuracy: 73.11%
# Epoch [34/40], Step [40/110], Loss: 0.0161, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.4039, Validation Accuracy: 74.70%
# Epoch [34/40], Step [50/110], Loss: 0.0132, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.3964, Validation Accuracy: 72.71%
# Epoch [34/40], Step [60/110], Loss: 0.0128, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.4148, Validation Accuracy: 72.11%
# Epoch [34/40], Step [70/110], Loss: 0.0226, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.2304, Validation Accuracy: 72.91%
# Epoch [34/40], Step [80/110], Loss: 0.0227, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.5136, Validation Accuracy: 72.51%
# Epoch [34/40], Step [90/110], Loss: 0.0106, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.2820, Validation Accuracy: 74.70%
# Epoch [34/40], Step [100/110], Loss: 0.0171, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.3986, Validation Accuracy: 72.91%
# Epoch [34/40], Step [110/110], Loss: 0.0345, Accuracy: 100.00%
# Epoch [34/40], Loss: 0.4392, Validation Accuracy: 73.51%
# Epoch [35/40], Step [10/110], Loss: 0.0159, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.3613, Validation Accuracy: 72.51%
# Epoch [35/40], Step [20/110], Loss: 0.0090, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.4526, Validation Accuracy: 72.31%
# Epoch [35/40], Step [30/110], Loss: 0.0160, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.2738, Validation Accuracy: 71.51%
# Epoch [35/40], Step [40/110], Loss: 0.0178, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.4358, Validation Accuracy: 70.92%
# Epoch [35/40], Step [50/110], Loss: 0.0167, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.3244, Validation Accuracy: 71.91%
# Epoch [35/40], Step [60/110], Loss: 0.0425, Accuracy: 96.88%
# Epoch [35/40], Loss: 0.3253, Validation Accuracy: 70.92%
# Epoch [35/40], Step [70/110], Loss: 0.0227, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.4087, Validation Accuracy: 73.51%
# Epoch [35/40], Step [80/110], Loss: 0.0582, Accuracy: 96.88%
# Epoch [35/40], Loss: 0.2615, Validation Accuracy: 73.31%
# Epoch [35/40], Step [90/110], Loss: 0.0122, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.3362, Validation Accuracy: 72.11%
# Epoch [35/40], Step [100/110], Loss: 0.0167, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.5003, Validation Accuracy: 72.71%
# Epoch [35/40], Step [110/110], Loss: 0.0415, Accuracy: 100.00%
# Epoch [35/40], Loss: 0.4513, Validation Accuracy: 73.90%
# Epoch [36/40], Step [10/110], Loss: 0.0204, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.5145, Validation Accuracy: 70.32%
# Epoch [36/40], Step [20/110], Loss: 0.0166, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.5993, Validation Accuracy: 70.12%
# Epoch [36/40], Step [30/110], Loss: 0.0455, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.3507, Validation Accuracy: 72.11%
# Epoch [36/40], Step [40/110], Loss: 0.0317, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.3666, Validation Accuracy: 72.91%
# Epoch [36/40], Step [50/110], Loss: 0.0228, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.4356, Validation Accuracy: 72.91%
# Epoch [36/40], Step [60/110], Loss: 0.0335, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.4851, Validation Accuracy: 72.91%
# Epoch [36/40], Step [70/110], Loss: 0.0282, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.4678, Validation Accuracy: 71.31%
# Epoch [36/40], Step [80/110], Loss: 0.0152, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.4711, Validation Accuracy: 72.11%
# Epoch [36/40], Step [90/110], Loss: 0.0364, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.5531, Validation Accuracy: 72.51%
# Epoch [36/40], Step [100/110], Loss: 0.1824, Accuracy: 96.88%
# Epoch [36/40], Loss: 0.5752, Validation Accuracy: 71.91%
# Epoch [36/40], Step [110/110], Loss: 0.0198, Accuracy: 100.00%
# Epoch [36/40], Loss: 0.4531, Validation Accuracy: 70.92%
# Epoch [37/40], Step [10/110], Loss: 0.0078, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.4833, Validation Accuracy: 71.71%
# Epoch [37/40], Step [20/110], Loss: 0.0435, Accuracy: 96.88%
# Epoch [37/40], Loss: 0.4074, Validation Accuracy: 73.11%
# Epoch [37/40], Step [30/110], Loss: 0.0105, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.4154, Validation Accuracy: 70.32%
# Epoch [37/40], Step [40/110], Loss: 0.0120, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.4256, Validation Accuracy: 72.51%
# Epoch [37/40], Step [50/110], Loss: 0.0081, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.2406, Validation Accuracy: 72.31%
# Epoch [37/40], Step [60/110], Loss: 0.0107, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.4395, Validation Accuracy: 73.71%
# Epoch [37/40], Step [70/110], Loss: 0.0634, Accuracy: 96.88%
# Epoch [37/40], Loss: 0.4449, Validation Accuracy: 72.91%
# Epoch [37/40], Step [80/110], Loss: 0.0273, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.3596, Validation Accuracy: 72.51%
# Epoch [37/40], Step [90/110], Loss: 0.0122, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.4216, Validation Accuracy: 71.51%
# Epoch [37/40], Step [100/110], Loss: 0.0545, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.3907, Validation Accuracy: 71.71%
# Epoch [37/40], Step [110/110], Loss: 0.0105, Accuracy: 100.00%
# Epoch [37/40], Loss: 0.2906, Validation Accuracy: 72.91%
# Epoch [38/40], Step [10/110], Loss: 0.0108, Accuracy: 100.00%
# Epoch [38/40], Loss: 0.4295, Validation Accuracy: 72.91%
# Epoch [38/40], Step [20/110], Loss: 0.0153, Accuracy: 100.00%
# Epoch [38/40], Loss: 0.4268, Validation Accuracy: 71.31%
# Epoch [38/40], Step [30/110], Loss: 0.1111, Accuracy: 96.88%
# Epoch [38/40], Loss: 0.5903, Validation Accuracy: 71.51%
# Epoch [38/40], Step [40/110], Loss: 0.0142, Accuracy: 100.00%
# Epoch [38/40], Loss: 0.7428, Validation Accuracy: 70.72%
# Epoch [38/40], Step [50/110], Loss: 0.2582, Accuracy: 93.75%
# Epoch [38/40], Loss: 0.4803, Validation Accuracy: 72.11%
# Epoch [38/40], Step [60/110], Loss: 0.1842, Accuracy: 96.88%
# Epoch [38/40], Loss: 0.3963, Validation Accuracy: 72.91%
# Epoch [38/40], Step [70/110], Loss: 0.0128, Accuracy: 100.00%
# Epoch [38/40], Loss: 0.3896, Validation Accuracy: 72.91%
# Epoch [38/40], Step [80/110], Loss: 0.0101, Accuracy: 100.00%
# Epoch [38/40], Loss: 0.3156, Validation Accuracy: 71.91%
# Epoch [38/40], Step [90/110], Loss: 0.0466, Accuracy: 100.00%
# Epoch [38/40], Loss: 0.4345, Validation Accuracy: 73.11%
# Epoch [38/40], Step [100/110], Loss: 0.0222, Accuracy: 100.00%
# Epoch [38/40], Loss: 0.3885, Validation Accuracy: 74.30%
# Epoch [38/40], Step [110/110], Loss: 0.0126, Accuracy: 100.00%
# Epoch [38/40], Loss: 0.3003, Validation Accuracy: 73.11%
# Epoch [39/40], Step [10/110], Loss: 0.0066, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.3584, Validation Accuracy: 72.31%
# Epoch [39/40], Step [20/110], Loss: 0.0108, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.3131, Validation Accuracy: 71.12%
# Epoch [39/40], Step [30/110], Loss: 0.0085, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.4105, Validation Accuracy: 70.72%
# Epoch [39/40], Step [40/110], Loss: 0.0283, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.5395, Validation Accuracy: 71.91%
# Epoch [39/40], Step [50/110], Loss: 0.0142, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.4110, Validation Accuracy: 72.31%
# Epoch [39/40], Step [60/110], Loss: 0.0486, Accuracy: 96.88%
# Epoch [39/40], Loss: 0.4218, Validation Accuracy: 74.10%
# Epoch [39/40], Step [70/110], Loss: 0.0107, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.3557, Validation Accuracy: 70.92%
# Epoch [39/40], Step [80/110], Loss: 0.0090, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.4817, Validation Accuracy: 72.11%
# Epoch [39/40], Step [90/110], Loss: 0.0252, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.4159, Validation Accuracy: 72.11%
# Epoch [39/40], Step [100/110], Loss: 0.0111, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.5074, Validation Accuracy: 72.11%
# Epoch [39/40], Step [110/110], Loss: 0.0164, Accuracy: 100.00%
# Epoch [39/40], Loss: 0.3913, Validation Accuracy: 70.92%
# Epoch [40/40], Step [10/110], Loss: 0.0118, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.4198, Validation Accuracy: 71.91%
# Epoch [40/40], Step [20/110], Loss: 0.0113, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.4250, Validation Accuracy: 70.72%
# Epoch [40/40], Step [30/110], Loss: 0.0195, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.4133, Validation Accuracy: 70.72%
# Epoch [40/40], Step [40/110], Loss: 0.0161, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.4336, Validation Accuracy: 72.51%
# Epoch [40/40], Step [50/110], Loss: 0.0400, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.4996, Validation Accuracy: 72.31%
# Epoch [40/40], Step [60/110], Loss: 0.0134, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.4161, Validation Accuracy: 72.91%
# Epoch [40/40], Step [70/110], Loss: 0.0184, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.2772, Validation Accuracy: 72.91%
# Epoch [40/40], Step [80/110], Loss: 0.0805, Accuracy: 93.75%
# Epoch [40/40], Loss: 0.4983, Validation Accuracy: 72.11%
# Epoch [40/40], Step [90/110], Loss: 0.0088, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.5029, Validation Accuracy: 72.71%
# Epoch [40/40], Step [100/110], Loss: 0.0712, Accuracy: 96.88%
# Epoch [40/40], Loss: 0.2641, Validation Accuracy: 71.91%
# Epoch [40/40], Step [110/110], Loss: 0.0140, Accuracy: 100.00%
# Epoch [40/40], Loss: 0.3092, Validation Accuracy: 71.51%
# ######## Training Finished in 22956.748487472534 seconds ###########

# %%
torch.save(model_vgg16, '/kaggle/working/Model_Plantdoc-Vgg16.pth')

# model = torch.load('model.pth')

# %%
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('steps')
plt.plot(accuracy_train, label="Train Accuracy")
plt.plot(accuracy_validation, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.savefig('/kaggle/working/Accurary_Plot_Plantdoc-Vgg16')
plt.show()

# %%
str(accuracy_train)
# Out:
# '[12.5, 31.25, 15.625, 37.5, 34.375, 43.75, 50.0, 37.5, 46.875, 75.0, 72.41379310344827, 59.375, 71.875, 81.25, 59.375, 68.75, 71.875, 75.0, 53.125, 68.75, 75.0, 62.06896551724138, 75.0, 81.25, 75.0, 71.875, 71.875, 59.375, 65.625, 93.75, 90.625, 75.0, 72.41379310344827, 87.5, 75.0, 84.375, 87.5, 68.75, 75.0, 81.25, 78.125, 75.0, 84.375, 75.86206896551724, 90.625, 81.25, 90.625, 96.875, 78.125, 93.75, 87.5, 87.5, 87.5, 93.75, 82.75862068965517, 90.625, 96.875, 93.75, 96.875, 90.625, 93.75, 96.875, 90.625, 96.875, 96.875, 86.20689655172413, 90.625, 84.375, 93.75, 90.625, 93.75, 93.75, 96.875, 87.5, 93.75, 90.625, 96.55172413793103, 96.875, 93.75, 93.75, 96.875, 90.625, 100.0, 100.0, 96.875, 93.75, 96.875, 96.55172413793103, 96.875, 90.625, 100.0, 96.875, 100.0, 100.0, 100.0, 96.875, 93.75, 96.875, 96.55172413793103, 100.0, 93.75, 100.0, 96.875, 100.0, 96.875, 100.0, 100.0, 100.0, 93.75, 96.55172413793103, 100.0, 100.0, 93.75, 96.875, 100.0, 96.875, 100.0, 96.875, 100.0, 96.875, 93.10344827586206, 96.875, 100.0, 93.75, 96.875, 100.0, 100.0, 100.0, 96.875, 96.875, 100.0, 100.0, 100.0, 93.75, 100.0, 100.0, 100.0, 96.875, 96.875, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 93.75, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 96.875, 100.0, 96.55172413793103, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 93.75, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.55172413793103, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 96.55172413793103, 100.0, 96.875, 100.0, 100.0, 96.875, 100.0, 96.875, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.55172413793103, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 93.75, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 93.75, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 93.75, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 93.75, 100.0, 100.0, 96.875, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 89.65517241379311, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 96.55172413793103, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 93.75, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 96.875, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 100.0, 93.75, 100.0, 96.875, 100.0]'

# %%
str(accuracy_validation)
# Out:
# '[16.93227091633466, 23.705179282868528, 28.68525896414343, 31.274900398406373, 35.657370517928285, 39.243027888446214, 37.64940239043825, 46.41434262948207, 46.21513944223107, 49.60159362549801, 51.19521912350598, 50.199203187250994, 49.60159362549801, 54.7808764940239, 56.77290836653387, 53.98406374501992, 54.38247011952191, 54.980079681274894, 54.581673306772906, 56.37450199203188, 56.37450199203188, 59.16334661354582, 55.97609561752988, 60.1593625498008, 59.36254980079681, 56.77290836653387, 59.76095617529881, 61.354581673306775, 58.76494023904383, 59.16334661354582, 63.54581673306773, 62.94820717131474, 61.55378486055777, 62.94820717131474, 63.94422310756972, 64.14342629482071, 65.5378486055777, 62.74900398406375, 65.33864541832669, 66.13545816733067, 65.73705179282868, 67.33067729083665, 65.93625498007968, 63.94422310756972, 63.745019920318725, 65.5378486055777, 65.93625498007968, 65.33864541832669, 66.93227091633466, 62.94820717131474, 64.34262948207171, 67.13147410358566, 65.93625498007968, 65.93625498007968, 68.32669322709162, 67.92828685258964, 66.73306772908366, 65.93625498007968, 67.33067729083665, 67.72908366533864, 67.92828685258964, 67.72908366533864, 67.13147410358566, 69.12350597609563, 67.72908366533864, 66.33466135458167, 71.51394422310757, 68.72509960159363, 69.12350597609563, 69.32270916334662, 70.1195219123506, 70.5179282868526, 69.32270916334662, 68.92430278884463, 69.7211155378486, 68.32669322709162, 69.52191235059762, 67.92828685258964, 70.5179282868526, 67.72908366533864, 70.7171314741036, 69.12350597609563, 69.9203187250996, 69.9203187250996, 69.52191235059762, 68.52589641434263, 68.72509960159363, 69.7211155378486, 70.1195219123506, 70.1195219123506, 71.31474103585657, 71.11553784860558, 71.71314741035857, 69.52191235059762, 70.1195219123506, 68.52589641434263, 70.7171314741036, 70.3187250996016, 69.9203187250996, 69.9203187250996, 69.12350597609563, 70.5179282868526, 71.11553784860558, 70.7171314741036, 69.9203187250996, 70.1195219123506, 70.5179282868526, 71.51394422310757, 71.71314741035857, 71.71314741035857, 71.51394422310757, 69.12350597609563, 72.50996015936255, 70.7171314741036, 71.91235059760956, 69.9203187250996, 72.50996015936255, 72.31075697211156, 70.7171314741036, 72.50996015936255, 70.3187250996016, 71.51394422310757, 70.3187250996016, 72.31075697211156, 71.51394422310757, 70.5179282868526, 71.31474103585657, 72.31075697211156, 70.5179282868526, 72.90836653386454, 72.11155378486056, 72.11155378486056, 69.9203187250996, 71.71314741035857, 71.51394422310757, 72.90836653386454, 71.91235059760956, 71.71314741035857, 71.11553784860558, 71.11553784860558, 72.11155378486056, 72.31075697211156, 71.31474103585657, 71.11553784860558, 72.70916334661355, 71.71314741035857, 71.71314741035857, 72.90836653386454, 72.70916334661355, 73.10756972111554, 71.31474103585657, 71.91235059760956, 71.71314741035857, 70.5179282868526, 71.51394422310757, 71.71314741035857, 70.5179282868526, 73.50597609561753, 71.51394422310757, 72.11155378486056, 72.11155378486056, 70.5179282868526, 71.31474103585657, 72.90836653386454, 72.50996015936255, 72.11155378486056, 72.90836653386454, 72.50996015936255, 71.71314741035857, 71.51394422310757, 72.70916334661355, 72.50996015936255, 73.10756972111554, 73.70517928286853, 72.70916334661355, 71.91235059760956, 71.71314741035857, 72.11155378486056, 71.51394422310757, 73.10756972111554, 72.70916334661355, 72.31075697211156, 72.11155378486056, 72.50996015936255, 72.31075697211156, 72.50996015936255, 71.71314741035857, 71.31474103585657, 72.11155378486056, 72.11155378486056, 72.70916334661355, 73.10756972111554, 73.10756972111554, 72.11155378486056, 72.90836653386454, 73.10756972111554, 72.90836653386454, 74.10358565737052, 72.50996015936255, 72.50996015936255, 73.10756972111554, 70.91633466135458, 71.31474103585657, 71.91235059760956, 72.11155378486056, 71.71314741035857, 73.10756972111554, 72.11155378486056, 71.31474103585657, 70.5179282868526, 70.91633466135458, 72.1115537848605 ...

# %%
plt.title('model Loss')
plt.ylabel('loss')
plt.xlabel('steps')
plt.plot(loss_train, label="Train Loss")
plt.plot(loss_validation, label="Validation Loss")
plt.legend(loc="upper right")
plt.savefig('/kaggle/working/Loss_Plot_Plantdoc-Vgg16')
plt.show()

# %%
str(loss_train)
# Out:
# '[3.2027885913848877, 2.3621647357940674, 2.7098352909088135, 2.2508509159088135, 1.934941053390503, 1.9155210256576538, 1.988295078277588, 2.0570833683013916, 1.821303129196167, 1.225180745124817, 1.154950499534607, 1.5158194303512573, 1.3163362741470337, 1.0321565866470337, 1.3022676706314087, 1.217115044593811, 1.2219399213790894, 1.2826800346374512, 1.6350386142730713, 1.0509674549102783, 1.008707880973816, 1.191057562828064, 0.8508578538894653, 0.7994865775108337, 0.7731531858444214, 0.9212021827697754, 1.0173180103302002, 1.066253900527954, 1.1902616024017334, 0.4248979985713959, 0.7795491814613342, 0.9276390671730042, 1.0274745225906372, 0.6433369517326355, 0.6662485599517822, 0.5378245115280151, 0.6201419830322266, 0.906345009803772, 0.713837206363678, 0.6034033298492432, 0.5915176272392273, 0.8717203736305237, 0.5832220911979675, 0.774625837802887, 0.5205913782119751, 0.8080095648765564, 0.48434293270111084, 0.43649837374687195, 0.6557373404502869, 0.38648417592048645, 0.4173862636089325, 0.4742032289505005, 0.49317696690559387, 0.5105727314949036, 0.5815524458885193, 0.5050668716430664, 0.4294813871383667, 0.3942086398601532, 0.29778873920440674, 0.3658886253833771, 0.3782195448875427, 0.2317747175693512, 0.44099751114845276, 0.36164847016334534, 0.37315207719802856, 0.57075035572052, 0.36264386773109436, 0.6039952635765076, 0.4346194863319397, 0.34949150681495667, 0.3096795976161957, 0.2774840295314789, 0.27257752418518066, 0.4206087291240692, 0.2935076653957367, 0.29420074820518494, 0.32366129755973816, 0.21342962980270386, 0.3348946273326874, 0.3393442928791046, 0.24701343476772308, 0.3151122033596039, 0.19870881736278534, 0.21792307496070862, 0.20085278153419495, 0.2757238745689392, 0.31092944741249084, 0.21191640198230743, 0.26561403274536133, 0.29931673407554626, 0.19738125801086426, 0.22340869903564453, 0.15674522519111633, 0.16525444388389587, 0.22456786036491394, 0.17868630588054657, 0.23086124658584595, 0.252718985080719, 0.1956905871629715, 0.08975495398044586, 0.26636025309562683, 0.19416598975658417, 0.1656445413827896, 0.16317957639694214, 0.2992667853832245, 0.1587514579296112, 0.2127484828233719, 0.10979848355054855, 0.17943337559700012, 0.18240100145339966, 0.14713317155838013, 0.1664474606513977, 0.18855904042720795, 0.14115160703659058, 0.12396314740180969, 0.13108748197555542, 0.16897571086883545, 0.197432279586792, 0.12217571586370468, 0.21365176141262054, 0.3127955198287964, 0.39117875695228577, 0.11564017832279205, 0.149699866771698, 0.11372380703687668, 0.18605966866016388, 0.11024533212184906, 0.09494414925575256, 0.16149002313613892, 0.15460145473480225, 0.10786379128694534, 0.11452788859605789, 0.14474113285541534, 0.14124509692192078, 0.1075880229473114, 0.139052152633667, 0.08907651156187057, 0.15214259922504425, 0.14088894426822662, 0.0824780985713005, 0.12884624302387238, 0.08629099279642105, 0.08820304274559021, 0.08889899402856827, 0.11885080486536026, 0.09734230488538742, 0.07038074731826782, 0.085060253739357, 0.1161356121301651, 0.08530893921852112, 0.17496514320373535, 0.0871894359588623, 0.12279609590768814, 0.08649593591690063, 0.03593079000711441, 0.12421681731939316, 0.07933244109153748, 0.056826140731573105, 0.06351639330387115, 0.061818964779376984, 0.1142289936542511, 0.08193381875753403, 0.15013964474201202, 0.059313151985406876, 0.11271048337221146, 0.08001334965229034, 0.07477995753288269, 0.07354895770549774, 0.07791387289762497, 0.09707165509462357, 0.09327682107686996, 0.09546398371458054, 0.06088225916028023, 0.1329878866672516, 0.07511060684919357, 0.10436582565307617, 0.05392559990286827, 0.04706835001707077, 0.08718985319137573, 0.05578940361738205, 0.059184007346630096, 0.07690395414829254, 0.07044155150651932, 0.0834972932934761, 0.05522998794913292, 0.07576847821474075, 0.0626983568072319, 0.03638400137424469, 0.05657808482646942, 0.07996087521314621, 0.07052106410264969, 0.14331893622875214, 0.07726651430130005, 0.05611659586429596, 0.06704948097467422, 0.0516 ...

# %%
str(loss_validation)
# Out:
# '[2.829000473022461, 2.5613327026367188, 2.0463316440582275, 2.2875139713287354, 1.897243857383728, 1.6689224243164062, 2.010690689086914, 1.6639083623886108, 1.414018154144287, 1.392549991607666, 1.489022135734558, 1.5328483581542969, 1.5768208503723145, 1.3674893379211426, 1.268338680267334, 1.423758864402771, 1.0856066942214966, 1.2225922346115112, 1.2485922574996948, 1.0933908224105835, 1.0301353931427002, 1.2179765701293945, 1.1598466634750366, 1.1310547590255737, 1.0539093017578125, 1.0141562223434448, 1.110180139541626, 0.9110298752784729, 0.9970300793647766, 0.9843783974647522, 0.8520717620849609, 0.951885461807251, 0.877144992351532, 0.9696573615074158, 1.1051781177520752, 1.0889440774917603, 0.8267631530761719, 0.8548474907875061, 0.8556859493255615, 0.9482908248901367, 0.8954309225082397, 0.7887429594993591, 0.883664071559906, 0.8903003334999084, 0.6710358262062073, 0.8330762386322021, 0.7849389910697937, 0.7121947407722473, 0.7911209464073181, 1.0044608116149902, 0.8488223552703857, 0.8254281878471375, 0.6772019863128662, 0.7213289141654968, 0.5836565494537354, 0.7184529900550842, 0.852986752986908, 0.7059019207954407, 0.8452625870704651, 0.8258138298988342, 0.6785905957221985, 0.7761027812957764, 0.6680004596710205, 0.6831589341163635, 0.7971417903900146, 0.5917387008666992, 0.47728803753852844, 0.5851471424102783, 0.701120913028717, 0.6756492257118225, 0.7652284502983093, 0.6064570546150208, 0.7278817892074585, 0.7029891610145569, 0.8112316131591797, 0.6767083406448364, 0.7768035531044006, 0.8076326847076416, 0.594935953617096, 0.7994558811187744, 0.6315498948097229, 0.5959053635597229, 0.6802296042442322, 0.7049503922462463, 0.7088715434074402, 0.8294389247894287, 0.9472925662994385, 0.7221853733062744, 0.6873682737350464, 0.5927218794822693, 0.6680165529251099, 0.5364626049995422, 0.7308489084243774, 0.6115383505821228, 0.5615282654762268, 0.5964685678482056, 0.530548632144928, 0.6023083329200745, 0.6995713710784912, 0.5623422265052795, 0.5301768779754639, 0.5960320234298706, 0.6804755330085754, 0.5633493661880493, 0.5804134607315063, 0.6421343088150024, 0.6514125466346741, 0.581411600112915, 0.46203377842903137, 0.559258222579956, 0.5236778855323792, 0.7223102450370789, 0.5772691369056702, 0.5081617832183838, 0.5483874678611755, 0.5567693710327148, 0.6108517050743103, 0.5494234561920166, 0.5421850681304932, 0.4771621525287628, 0.3759649991989136, 0.4437512457370758, 0.6813971996307373, 0.5780818462371826, 0.5119674205780029, 0.79746413230896, 0.5504872798919678, 0.5351064205169678, 0.5398959517478943, 0.53849196434021, 0.43526947498321533, 0.40591123700141907, 0.6476569771766663, 0.5159555077552795, 0.45299309492111206, 0.3927973806858063, 0.5248078107833862, 0.5080604553222656, 0.6713674068450928, 0.6863417029380798, 0.5477473735809326, 0.4666283428668976, 0.5868006348609924, 0.5612440705299377, 0.5128766894340515, 0.4328579604625702, 0.4687938690185547, 0.4719420373439789, 0.356026291847229, 0.4847385287284851, 0.6502715945243835, 0.6776320934295654, 0.5338186025619507, 0.6948723196983337, 0.4388107359409332, 0.6746854186058044, 0.5678586959838867, 0.5506901144981384, 0.5700938701629639, 0.4969998598098755, 0.6084755659103394, 0.4058944880962372, 0.524505615234375, 0.4765242636203766, 0.5643768906593323, 0.4335329830646515, 0.5572164058685303, 0.6147464513778687, 0.5117166042327881, 0.3444739580154419, 0.4226599931716919, 0.47713175415992737, 0.5195744037628174, 0.4986686706542969, 0.5186451077461243, 0.44005486369132996, 0.351065993309021, 0.399100124835968, 0.33024975657463074, 0.37347885966300964, 0.4898681640625, 0.5317199230194092, 0.6021291613578796, 0.5115740299224854, 0.43826285004615784, 0.558189868927002, 0.53870689868927, 0.39336541295051575, 0.5645207762718201, 0.5449070334434509, 0.4684184193611145, 0.4707731008529663, 0.5240237712860107, 0.591624915599823, 0.4615127742290497, 0.3594400882720947, 0.5289717316627502, 0.4716012179851532, 0.47980108857154846, 0.5327673554420471, 0.5655390024185181, ...

# %%
model_vgg16.eval()
with torch.no_grad():
    correct_test_labels = 0
    total_test_labels = 0

    for test_data in validation_dataloader:
        test_images, test_labels = test_data[0].to(device), test_data[1].to(device)
        predicted_outputs = model_vgg16(test_images)

        _, test_prediction = torch.max(predicted_outputs.data, 1)
        total_test_labels += test_labels.size(0)
        correct_test_labels += (test_prediction == test_labels).sum().item()

    test_accuracy = ((correct_test_labels / total_test_labels) * 100)
    print("Accuracy on Validation Set: {:.2f}%".format(test_accuracy))
# Out:
# Accuracy on Validation Set: 71.71%

# %%
y_pred = []
y_true = []
features_tsne = None

model_vgg16.eval()
with torch.no_grad():
    correct_test_labels = 0
    total_test_labels = 0

    for test_data in test_dataloader:
        test_images, test_labels = test_data[0].to(device), test_data[1].to(device)
        predicted_outputs = model_vgg16(test_images)

        _, test_prediction = torch.max(predicted_outputs.data, 1)
        total_test_labels += test_labels.size(0)
        correct_test_labels += (test_prediction == test_labels).sum().item()
        
        prediction_result = test_prediction.data.cpu().numpy()
        gt_label = test_labels.data.cpu().numpy()
        
        y_pred.extend(prediction_result) # Save Prediction
        y_true.extend(gt_label) # Save Truth
        
        # For t-SNE
        curr_f = predicted_outputs.cpu().numpy()
        if features_tsne is not None:
            features_tsne = np.concatenate((features_tsne, curr_f))
        else:
            features_tsne = curr_f
        
    test_accuracy = ((correct_test_labels / total_test_labels) * 100)
    print("Accuracy on Test Set: {:.2f}%".format(test_accuracy))
# Out:
# Accuracy on Test Set: 71.81%

# %%
str(y_pred)
# Out:
# '[18, 8, 8, 7, 20, 19, 4, 10, 12, 19, 4, 9, 26, 9, 18, 3, 14, 21, 23, 19, 9, 11, 4, 16, 22, 0, 11, 6, 13, 23, 14, 13, 1, 5, 10, 18, 23, 21, 14, 24, 7, 24, 5, 22, 24, 24, 0, 5, 18, 23, 4, 9, 15, 8, 18, 15, 12, 7, 19, 15, 12, 21, 22, 9, 4, 1, 16, 19, 16, 7, 24, 25, 13, 17, 15, 19, 13, 11, 4, 8, 21, 14, 1, 11, 3, 8, 19, 22, 15, 1, 11, 11, 14, 15, 9, 6, 7, 12, 11, 0, 0, 21, 16, 1, 4, 9, 9, 4, 16, 15, 17, 24, 11, 14, 18, 26, 0, 1, 24, 17, 6, 8, 13, 24, 2, 10, 3, 15, 21, 19, 13, 1, 24, 0, 8, 24, 4, 3, 16, 19, 11, 0, 9, 10, 19, 21, 9, 3, 9, 3, 11, 7, 10, 9, 11, 23, 4, 11, 23, 23, 1, 14, 6, 23, 3, 0, 5, 21, 5, 3, 24, 20, 24, 15, 19, 1, 21, 20, 13, 2, 0, 9, 10, 19, 24, 10, 19, 26, 2, 16, 22, 0, 18, 22, 26, 16, 16, 2, 18, 25, 9, 24, 14, 10, 1, 9, 6, 3, 21, 22, 11, 17, 18, 17, 21, 5, 20, 14, 16, 17, 23, 8, 8, 18, 5, 7, 9, 15, 11, 17, 24, 7, 3, 25, 3, 7, 9, 2, 24, 6, 13, 4, 23, 19, 13, 4, 1, 9, 14, 20, 15, 4, 10, 4, 22, 12, 18, 9, 3, 4, 17, 15, 26, 12, 6, 16, 4, 21, 8, 10, 0, 22, 24, 17, 24, 10, 23, 18, 9, 9, 9, 23, 25, 13, 11, 20, 10, 16, 4, 6, 7, 7, 3, 4, 23, 15, 22, 4, 10, 22, 20, 2, 25, 26, 13, 14, 19, 18, 16, 26, 14, 12, 12, 10, 3, 9, 3, 11, 19, 21, 14, 4, 21, 18, 15, 26, 7, 25, 18, 3, 3, 21, 8, 9, 25, 12, 16, 13, 18, 8, 26, 2, 11, 13, 21, 8, 23, 16, 4, 17, 7, 14, 26, 6, 4, 0, 18, 11, 24, 9, 6, 6, 16, 20, 23, 19, 10, 21, 17, 18, 24, 26, 23, 8, 6, 20, 16, 14, 18, 17, 7, 3, 8, 8, 5, 20, 26, 21, 11, 13, 14, 20, 3, 10, 1, 3, 15, 7, 10, 1, 2, 3, 1, 25, 5, 1, 7, 26, 26, 2, 3, 5, 11, 2, 26, 19, 7, 21, 11, 8, 25, 13, 16, 7, 23, 12, 10, 26, 22, 21, 9, 21, 11, 18, 1, 15, 11, 24, 14, 16, 16, 18, 26, 3, 20, 19, 11, 22, 17, 15, 19, 8, 22, 1, 6, 14, 19, 25, 6, 7, 7, 20, 18, 1, 5, 0, 26, 11, 8, 11, 9, 26, 12, 25, 20, 21, 20, 19, 3, 2, 10, 23, 12, 6, 21, 11, 8, 2, 21, 2, 13, 7, 5, 23, 21, 24, 21, 26, 23, 4, 12, 23, 19, 23, 4, 11, 25, 1, 24, 9, 13, 8, 6, 13, 9, 21, 24, 10, 24, 9, 10, 0, 0, 16, 6, 13, 23, 2, 24, 10, 26, 5, 11, 10, 6, 4, 4, 11, 11, 0, 25, 3, 17, 4, 17, 4, 9, 20, 5, 5, 7, 6, 20, 21, 7, 14, 15, 15, 2, 5, 6, 25, 20, 10, 1, 21, 11, 24, 18, 16, 3, 15, 19, 15, 16, 26, 26, 26, 1, 0, 26, 21, 16, 6, 8, 23, 18, 22, 18, 7, 25, 0, 17, 26, 22, 3, 11, 4, 11, 18, 25, 0, 11, 13, 1, 13, 2, 12, 15, 12, 6, 22, 7, 1, 9, 26, 1, 24, 21, 2, 14, 2, 17, 14, 12, 14, 1, 17, 17, 3, 21, 24, 25, 25, 14, 16, 15, 6, 23, 12, 14, 7, 8, 17, 23, 24, 22, 14, 11, 5, 11, 14, 10, 13, 9, 11, 1, 23, 20, 13, 15, 20, 21, 3, 5, 7, 1, 21, 16, 26, 2, 19, 24, 3, 21, 6, 24, 7, 26, 1, 6, 12, 8, 6, 19, 25, 14, 26, 6, 13, 3, 2, 12, 22, 16, 5, 10, 11, 18, 9, 26, 21, 15, 23, 0, 18, 12, 12, 12, 1, 14, 21, 10, 23, 14, 21, 9, 8, 2, 3, 13, 16, 19, 20, 19, 12, 26, 4, 9, 11, 2, 11, 18, 8, 5, 5, 24, 0, 22, 4, 7, 6, 21, 0, 13, 22, 3, 11, 3, 18, 26, 13, 17, 11, 13, 12, 17, 26, 18, 23, 21, 19, 0, 20, 1, 18, 21, 0, 11, 23, 20, 14, 3, 0, 21, 16, 23, 8, 12, 11, 25, 24, 24, 4, 7, 0, 14, 26, 22, 11, 1, 8, 25, 24, 9, 1, 10, 4, 0, 26, 25, 7, 0, 14, 3, 23, 8, 21, 4, 16, 2, 19, 4, 13, 9, 20, 2, 9, 3, 3, 25, 0, 3, 3, 25, 22, 18, 1, 24, 5, 15, 6, 7, 18, 17, 8, 11, 17, 7, 12, 10, 4, 24, 15, 25, 21, 0, 23, 5, 3, 14, 11, 21, 10, 7, 16, 2, 11, 13, 23, 25, 8, 20, 0, 6, 0, 20, 18, 26, 23, 23, 7, 25, 18, 24, 2, 13, 20, 15, 15, 5, 6, 26, 6, 20, 18, 22, 0, 18, 11, 20, 3, 13, 17, 20, 1, 0, 16, 19, 17, 3, 21, 21, 1, 4, 6, 0, 15, 10, 1, 15, 9, 7, 14, 3, 10, 25, 16, 26, 6, 13, 1, 1, 25, 2, 16, 4, 11, 9, 17, 8, 3, 6, 16, 18, 15, 14, 3, 21, 22, 11, 20, 13, 25, 14, 23, 14, 24, 7, 19, 7, 6, 6, 7, 20, 17, 10, 13, 25, 13, 6, 1, 11, 11, 7, 1, 11, 22, 13, 13, 23, 26, 20, 22, 26, 12, 16, 21, 2, 22, 14, 19, 3, 20, 5, 22, 10, 6, 2, 19, 26, 3, 12, 19, 24, 12, 24, 12, 14, 11, 0, 3, 24, 13]'

# %%
str(y_true)
# Out:
# '[20, 8, 8, 8, 20, 19, 6, 10, 21, 19, 4, 9, 26, 9, 2, 4, 14, 21, 23, 19, 9, 21, 4, 16, 22, 0, 13, 6, 10, 19, 14, 16, 1, 5, 10, 18, 23, 21, 14, 24, 7, 15, 5, 22, 24, 24, 0, 5, 0, 18, 4, 9, 15, 8, 20, 15, 12, 7, 25, 15, 12, 12, 22, 9, 4, 1, 25, 19, 16, 8, 24, 26, 13, 17, 15, 19, 13, 12, 24, 8, 21, 14, 1, 18, 3, 8, 19, 22, 15, 1, 18, 3, 2, 15, 9, 6, 8, 18, 4, 0, 15, 22, 16, 6, 18, 9, 9, 4, 3, 15, 17, 18, 11, 14, 18, 26, 16, 1, 20, 11, 6, 8, 13, 24, 2, 6, 3, 24, 17, 19, 0, 1, 24, 0, 7, 15, 4, 3, 16, 19, 11, 2, 9, 10, 20, 21, 8, 13, 9, 3, 17, 7, 10, 9, 20, 23, 17, 12, 23, 26, 1, 14, 6, 23, 4, 4, 10, 21, 12, 3, 22, 20, 4, 25, 19, 1, 13, 20, 13, 2, 1, 9, 10, 19, 24, 10, 19, 26, 2, 16, 22, 0, 12, 22, 26, 16, 16, 2, 18, 25, 8, 3, 14, 10, 10, 9, 6, 3, 21, 22, 4, 17, 17, 11, 21, 5, 18, 14, 16, 17, 23, 8, 7, 18, 5, 7, 9, 15, 11, 17, 26, 7, 3, 25, 4, 7, 9, 2, 24, 1, 13, 4, 23, 19, 13, 4, 1, 9, 14, 4, 15, 4, 10, 4, 23, 12, 18, 9, 3, 12, 20, 20, 2, 11, 6, 13, 4, 11, 7, 6, 14, 22, 23, 17, 20, 10, 20, 20, 7, 9, 9, 22, 25, 13, 11, 20, 10, 16, 2, 6, 7, 9, 3, 4, 23, 15, 22, 4, 10, 22, 4, 2, 25, 26, 16, 14, 16, 18, 16, 26, 14, 12, 12, 10, 4, 9, 22, 6, 19, 21, 13, 4, 21, 18, 15, 20, 7, 25, 20, 3, 3, 21, 8, 9, 25, 12, 13, 0, 18, 8, 26, 2, 11, 13, 0, 8, 23, 16, 4, 17, 8, 5, 26, 6, 4, 0, 18, 12, 24, 9, 6, 6, 16, 18, 23, 19, 10, 12, 17, 17, 20, 26, 22, 9, 6, 18, 16, 14, 21, 17, 7, 3, 8, 8, 5, 20, 26, 26, 11, 13, 14, 20, 1, 13, 1, 3, 15, 7, 10, 1, 2, 3, 5, 25, 5, 0, 7, 26, 26, 2, 3, 11, 20, 2, 26, 5, 8, 12, 20, 8, 25, 26, 25, 7, 23, 12, 10, 26, 22, 21, 9, 10, 17, 20, 1, 15, 17, 21, 14, 16, 16, 25, 26, 3, 0, 19, 24, 22, 17, 20, 19, 8, 22, 1, 6, 14, 19, 25, 0, 7, 7, 20, 18, 1, 11, 0, 26, 11, 8, 24, 9, 5, 24, 25, 20, 21, 20, 22, 3, 2, 10, 23, 11, 6, 24, 11, 7, 2, 4, 2, 13, 0, 2, 20, 21, 24, 17, 26, 23, 4, 12, 23, 19, 5, 4, 0, 25, 1, 24, 9, 13, 8, 6, 13, 9, 18, 24, 20, 24, 9, 10, 0, 0, 16, 6, 13, 23, 2, 24, 10, 24, 5, 11, 10, 6, 24, 4, 17, 11, 0, 25, 3, 17, 4, 2, 4, 9, 20, 5, 5, 7, 6, 20, 21, 7, 14, 23, 15, 2, 5, 6, 26, 20, 10, 1, 21, 24, 20, 13, 16, 4, 15, 19, 15, 16, 26, 26, 26, 1, 17, 16, 12, 16, 6, 8, 23, 18, 22, 22, 7, 13, 0, 11, 26, 22, 3, 21, 4, 11, 18, 25, 0, 11, 13, 1, 13, 2, 12, 24, 12, 6, 22, 7, 5, 9, 26, 1, 18, 21, 2, 14, 2, 17, 4, 12, 14, 1, 17, 17, 3, 21, 24, 25, 25, 14, 16, 15, 6, 23, 4, 14, 9, 9, 11, 23, 24, 22, 14, 19, 1, 12, 14, 10, 13, 9, 13, 1, 23, 20, 13, 15, 22, 21, 3, 5, 7, 1, 21, 16, 26, 7, 19, 24, 3, 21, 6, 24, 7, 26, 0, 6, 12, 8, 6, 19, 25, 14, 26, 6, 13, 8, 6, 12, 22, 16, 5, 10, 19, 23, 9, 26, 21, 15, 23, 17, 20, 12, 12, 24, 1, 14, 12, 10, 23, 5, 21, 9, 9, 2, 3, 13, 13, 17, 20, 19, 21, 26, 3, 9, 12, 2, 11, 18, 7, 5, 5, 24, 0, 22, 17, 7, 6, 3, 20, 13, 22, 10, 21, 3, 18, 26, 2, 17, 24, 13, 11, 17, 26, 17, 23, 21, 14, 0, 20, 1, 26, 21, 1, 21, 12, 18, 14, 3, 0, 24, 13, 23, 7, 12, 11, 25, 24, 24, 20, 7, 0, 14, 26, 22, 12, 1, 8, 25, 24, 9, 1, 10, 4, 24, 26, 23, 0, 15, 14, 3, 23, 8, 11, 4, 16, 20, 19, 4, 13, 9, 20, 2, 8, 3, 21, 25, 0, 6, 3, 25, 22, 18, 1, 8, 5, 15, 6, 7, 18, 17, 8, 20, 17, 7, 12, 10, 4, 4, 15, 25, 12, 0, 23, 5, 1, 14, 17, 12, 10, 7, 16, 2, 15, 13, 18, 25, 7, 20, 0, 6, 0, 18, 20, 26, 23, 23, 7, 25, 18, 24, 2, 13, 20, 15, 15, 13, 6, 1, 10, 18, 20, 22, 0, 18, 11, 17, 3, 13, 17, 20, 1, 0, 16, 5, 17, 3, 21, 4, 1, 11, 6, 0, 15, 10, 10, 15, 9, 7, 14, 3, 10, 25, 1, 26, 6, 13, 1, 1, 26, 26, 16, 4, 17, 8, 17, 9, 3, 5, 13, 0, 15, 14, 3, 21, 22, 21, 20, 13, 25, 14, 23, 14, 3, 9, 19, 7, 6, 6, 7, 20, 17, 10, 13, 25, 13, 6, 1, 0, 5, 8, 1, 11, 22, 13, 13, 18, 2, 20, 22, 26, 12, 16, 17, 2, 22, 14, 12, 4, 18, 5, 22, 10, 6, 20, 19, 26, 3, 0, 19, 24, 12, 21, 12, 14, 4, 0, 3, 23, 26]'

# %%
# Create Confusion Matrix
confusion_matrix = confusion_matrix(y_true, y_pred)

df_cm = pd.DataFrame(confusion_matrix,
                     index = [i for i in diseases],
                     columns = [i for i in diseases])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)
plt.savefig('/kaggle/working/Confusion_Matrix_Plantdoc-Vgg16.png')

# %%
# (True Positive + True Negative) / Total Predictions
accuracy = accuracy_score(y_true, y_pred)

# True Positive / (True Positive + False Positive)
precision = precision_score(y_true, y_pred, average='weighted')

# True Positive / (True Positive + False Negative)
sensitivity_recall = recall_score(y_true, y_pred, average='weighted')

# True Negative / (True Negative + False Positive)
specificity = recall_score(y_true, y_pred, average='weighted')

# 2 * ((Precision * Sensitivity) / (Precision + Sensitivity))
f1_score = f1_score(y_true, y_pred, average='weighted')
      
print("Accuracy: {:.2f}%".format(accuracy*100))
print("Precision: {:.2f}%".format(precision*100))
print("Sensitivity_recall: {:.2f}%".format(sensitivity_recall*100))
print("Specificity: {:.2f}%".format(specificity*100))
print("F1 Score: {:.2f}%".format(f1_score*100))
# Out:
# Accuracy: 71.81%
# Precision: 73.69%
# Sensitivity_recall: 71.81%
# Specificity: 71.81%
# F1 Score: 72.16%

# %%
## TSNE ##

from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, learning_rate= 'auto', init='random').fit_transform(features_tsne)

# scale and move the coordinates so they fit [0; 1] range
def scale_to_01_range(x):
    # compute the distribution range
    value_range = (np.max(x) - np.min(x))

    # move the distribution so that it starts from zero
    # by extracting the minimal value from all its values
    starts_from_zero = x - np.min(x)

    # make the distribution fit [0; 1] by dividing by its range
    return starts_from_zero / value_range


def visualize_both_tsne_points(diseases, tx1, ty1, labels1, tx2, ty2, labels2, title1, title2):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (18, 8))
    
    for disease_index in range(len(diseases)):
        ax1.title.set_text(title1)
        indices = [i for i, l in enumerate(labels1) if l == disease_index]
        current_tx = np.take(tx1, indices)
        current_ty = np.take(ty1, indices)
        ax1.scatter(current_tx, current_ty, label=diseases[disease_index])

    for disease_index in range(len(diseases)):
        ax2.title.set_text(title2)
        indices = [i for i, l in enumerate(labels2) if l == disease_index]
        current_tx = np.take(tx2, indices)
        current_ty = np.take(ty2, indices)
        ax2.scatter(current_tx, current_ty, label=diseases[disease_index])
    
    ax2.legend(bbox_to_anchor=(1, 1.01))
    plt.savefig('/kaggle/working/TNSE_Plot_Plantdoc-vgg16.png')
    plt.show()

# %%
# extract x and y coordinates representing the positions of the images on T-SNE plot
tx_gt = tsne[:, 0]
ty_gt = tsne[:, 1]

# scale and move the coordinates so they fit [0; 1] range
tx_gt = scale_to_01_range(tx_gt)
ty_gt = scale_to_01_range(ty_gt)


# extract x and y coordinates representing the positions of the images on T-SNE plot
tx_pred = tsne[:, 0]
ty_pred = tsne[:, 1]

# scale and move the coordinates so they fit [0; 1] range
tx_pred = scale_to_01_range(tx_pred)
ty_pred = scale_to_01_range(ty_pred)


# visualize the plot
visualize_both_tsne_points(diseases, tx_gt, ty_gt, y_true, tx_pred, ty_pred, y_pred, 'TSNE - Class Distribution for Ground Truth', 'TSNE - Class Distribution for Predicted Values')
