# %%
import os                       # for working with files
import numpy as np              # for numerical computationss
import pandas as pd             # for working with dataframes
import torch                    # Pytorch module 
import matplotlib.pyplot as plt # for plotting informations on graph and images using tensors
import torch.nn as nn           # for creating  neural networks
from torch.utils.data import DataLoader, random_split # for dataloaders 
from PIL import Image           # for checking images
import torch.nn.functional as F # for functions for calculating loss
import torchvision.transforms as transforms   # for transforming images into tensors 
from torchvision.utils import make_grid       # for data checking
from torchvision.datasets import ImageFolder  # for working with classes and images
from tqdm import tqdm
import time
from torchvision import models

# %%
data_dir = "../input/plantdoc6721"
# data_dir = "/content/drive/MyDrive/COMP6721-Project/PlantVillage-Dataset"

diseases = os.listdir(data_dir)

# %%
# printing the disease names
print(diseases)
print("Total disease classes are: {}".format(len(diseases)))
# Out:
# ['Corn leaf blight', 'Tomato leaf', 'Tomato leaf mosaic virus', 'Squash Powdery mildew leaf', 'Potato leaf late blight', 'Soyabean leaf', 'Peach leaf', 'Tomato leaf late blight', 'Apple leaf', 'Tomato mold leaf', 'Corn Gray leaf spot', 'Tomato leaf yellow virus', 'Strawberry leaf', 'Cherry leaf', 'Apple rust leaf', 'Potato leaf early blight', 'grape leaf black rot', 'Apple Scab Leaf', 'Tomato Septoria leaf spot', 'Tomato leaf bacterial spot', 'Blueberry leaf', 'Bell_pepper leaf spot', 'Corn rust leaf', 'Bell_pepper leaf', 'grape leaf', 'Tomato Early blight leaf', 'Raspberry leaf']
# Total disease classes are: 27

# %%
plants = []
for plant in diseases:
    if plant.split(' ')[0] not in plants:
        plants.append(plant.split(' ')[0])

# %%
# Unique plants in the dataset
print("Number of Classes: {}".format(len(plants)))
print(f"Unique Plants are: ")
for idx, plant in enumerate(plants):
  print(str(idx + 1) + '. ' + plant)
# Out:
# Number of Classes: 13
# Unique Plants are:
# 1. Corn
# 2. Tomato
# 3. Squash
# 4. Potato
# 5. Soyabean
# 6. Peach
# 7. Apple
# 8. Strawberry
# 9. Cherry
# 10. grape
# 11. Blueberry
# 12. Bell_pepper
# 13. Raspberry

# %%
# Number of images for each disease
disease_class_size = {}
for disease in diseases:
    disease_class_size[disease] = len(os.listdir(data_dir + '/' + disease))
    
# converting the disease_class_size dictionary to pandas dataframe passing index as plant name and number of images as column

img_per_class = pd.DataFrame(disease_class_size.values(), index=disease_class_size.keys(), columns=["no. of images"])
img_per_class
# Out:
#                             no. of images
# Corn leaf blight                      192
# Tomato leaf                            63
# Tomato leaf mosaic virus               53
# Squash Powdery mildew leaf            128
# Potato leaf late blight               105
# Soyabean leaf                          65
# Peach leaf                            112
# Tomato leaf late blight               111
# Apple leaf                             90
# Tomato mold leaf                       91
# Corn Gray leaf spot                    68
# Tomato leaf yellow virus               75
# Strawberry leaf                        95
# Cherry leaf                            56
# Apple rust leaf                        89
# Potato leaf early blight              117
# grape leaf black rot                   64
# Apple Scab Leaf                        93
# Tomato Septoria leaf spot             151
# Tomato leaf bacterial spot            109
# Blueberry leaf                        116
# Bell_pepper leaf spot                  71
# Corn rust leaf                        116
# Bell_pepper leaf                       61
# grape leaf                             68
# Tomato Early blight leaf               88
# Raspberry leaf                        119

# %%
# plotting number of images available for each disease
index = [n for n in range(len(disease_class_size.values()))]
plt.figure(figsize=(20, 5))
plt.bar(index, [n for n in disease_class_size.values()], width=0.3)
plt.xlabel('Plants/Diseases', fontsize=10)
plt.ylabel('No of images available', fontsize=10)
plt.xticks(index, diseases, fontsize=5, rotation=90)
plt.title('Images per each class of plant disease')
# Out:
# Text(0.5, 1.0, 'Images per each class of plant disease')

# %%
## Split Train, Test and Validation ##

def get_files_from_folder(path):
    files = os.listdir(path)
    return np.asarray(files)

get_files_from_folder(data_dir)

def load_data(path, validation_split, test_split, batch_size):
    transform_dict = {
        "src": transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.225, 0.225, 0.225]),
            transforms.Resize((224, 224))
        ])
    }
    
    dataset = ImageFolder(root=path, transform=transform_dict["src"])
    
    dataset_size = len(dataset)
    validation_size = int(validation_split * dataset_size)
    test_size = int(test_split * dataset_size)
    train_size = dataset_size - (test_size + validation_size)

    train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size])
    
    return train_dataset, validation_dataset, test_dataset

# %%
train_dataset, validation_dataset, test_dataset = load_data(data_dir, 0.1, 0.2, 200)

# %%
len(train_dataset.dataset.imgs)
# Out:
# 2566

# %%
img, label = train_dataset[0]
print(img.shape, label)
# Out:
# torch.Size([3, 224, 224]) 17

# %%
# for checking some images from training dataset
def show_image(image, label):
    # print("Label :" + train_dataset.classes[label] + "(" + str(label) + ")")
    plt.imshow(image.permute(1, 2, 0))

# %%
show_image(*train_dataset[21])

# %%
# setting the batch size
batch_size = 32

# Load data to DataLoaders for training, validation and test
train_dataloader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
validation_dataloader = DataLoader(validation_dataset, batch_size, num_workers=2, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size, num_workers=2, pin_memory=True)

# %%
#len(train_dataset)
# Out:
# 1797

# %%
# helper function to show a batch of training instances
def show_batch(data):
    for images, labels in data:
        fig, ax = plt.subplots(figsize=(30, 30))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dataloader)

# %%
# for calculating the accuracy
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))


# base class for the model
class ImageClassificationBase(nn.Module):
    
    def training_step(self, batch):
        images, labels = batch
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch
        out = self(images)                   # Generate prediction
        loss = F.cross_entropy(out, labels)  # Calculate loss
        acc = accuracy(out, labels)          # Calculate accuracy
        return {"val_loss": loss.detach(), "val_accuracy": acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x["val_loss"] for x in outputs]
        batch_accuracy = [x["val_accuracy"] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()       # Combine loss  
        epoch_accuracy = torch.stack(batch_accuracy).mean()
        return {"val_loss": epoch_loss, "val_accuracy": epoch_accuracy} # Combine accuracies
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_accuracy']))

# %%
# defining the model

model_vgg16 = models.vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
for param in model_vgg16.parameters():
    param.requires_grad = False

num_ftrs = model_vgg16.classifier[6].in_features
model_vgg16.classifier[6] = nn.Linear(num_ftrs, out_features=len(train_dataset.dataset.classes))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))
model_vgg16.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_vgg16.classifier[6].parameters(), lr=0.001)
# Out:
# Device: cuda:0

# %%
accuracy_validation = []
accuracy_train = []
loss_validation = []
loss_train = []

num_epochs = 20
total_steps = len(train_dataloader)
t1 = time.time()

for epoch in range(num_epochs):
    for i, data in enumerate(train_dataloader):
        images, labels = data[0].to(device), data[1].to(device)
        # Forward pass
        outputs = model_vgg16(images)
        loss = criterion(outputs, labels)
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        if (i + 1) % 10 == 0:
            accuracy = ((correct / total) * 100)
            accuracy_train.append(accuracy)
            loss_train.append(loss.item())
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                .format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(), accuracy))
            
            model_vgg16.eval()
            with torch.no_grad():
                correct_validation_labels = 0
                total_validation_labels = 0

                for validation_data in validation_dataloader:
                    validation_images, validation_labels = validation_data[0].to(device), validation_data[1].to(device)
                    predicted_outputs = model_vgg16(validation_images)

                    _, validation_prediction = torch.max(predicted_outputs.data, 1)
                    total_validation_labels += validation_labels.size(0)
                    correct_validation_labels += (validation_prediction == validation_labels).sum().item()
                # print("Correct-> ", correct_validation_labels)
                # print("Total-> ", total_validation_labels)
                # print(correct_validation_labels/total_validation_labels)
                val_loss = criterion(predicted_outputs, validation_labels)
                
                val_accuracy = ((correct_validation_labels / total_validation_labels) * 100)
                
                accuracy_validation.append(val_accuracy)
                loss_validation.append(val_loss.item())
            
                print('Epoch [{}/{}], Loss: {:.4f}, Validation Accuracy: {:.2f}%'
                      .format(epoch + 1, num_epochs, val_loss.item(), val_accuracy))
     
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Epoch [1/20], Step [10/57], Loss: 3.0597, Accuracy: 12.50%
# Epoch [1/20], Loss: 2.9101, Validation Accuracy: 19.14%
# Epoch [1/20], Step [20/57], Loss: 2.4766, Accuracy: 25.00%
# Epoch [1/20], Loss: 2.7275, Validation Accuracy: 34.38%
# Epoch [1/20], Step [30/57], Loss: 2.1518, Accuracy: 34.38%
# Epoch [1/20], Loss: 2.3194, Validation Accuracy: 37.11%
# Epoch [1/20], Step [40/57], Loss: 1.7457, Accuracy: 53.12%
# Epoch [1/20], Loss: 2.1596, Validation Accuracy: 46.88%
# Epoch [1/20], Step [50/57], Loss: 1.9684, Accuracy: 46.88%
# Epoch [1/20], Loss: 2.2400, Validation Accuracy: 42.19%
# Epoch [2/20], Step [10/57], Loss: 1.5059, Accuracy: 56.25%
# Epoch [2/20], Loss: 1.9630, Validation Accuracy: 45.70%
# Epoch [2/20], Step [20/57], Loss: 1.1307, Accuracy: 65.62%
# Epoch [2/20], Loss: 1.8906, Validation Accuracy: 48.05%
# Epoch [2/20], Step [30/57], Loss: 1.3724, Accuracy: 53.12%
# Epoch [2/20], Loss: 1.9196, Validation Accuracy: 48.83%
# Epoch [2/20], Step [40/57], Loss: 1.1439, Accuracy: 71.88%
# Epoch [2/20], Loss: 1.8635, Validation Accuracy: 46.48%
# Epoch [2/20], Step [50/57], Loss: 1.2569, Accuracy: 68.75%
# Epoch [2/20], Loss: 1.9263, Validation Accuracy: 49.61%
# Epoch [3/20], Step [10/57], Loss: 0.9573, Accuracy: 75.00%
# Epoch [3/20], Loss: 1.9705, Validation Accuracy: 45.31%
# Epoch [3/20], Step [20/57], Loss: 1.0520, Accuracy: 65.62%
# Epoch [3/20], Loss: 1.9043, Validation Accuracy: 51.17%
# Epoch [3/20], Step [30/57], Loss: 0.9025, Accuracy: 71.88%
# Epoch [3/20], Loss: 1.8664, Validation Accuracy: 50.00%
# Epoch [3/20], Step [40/57], Loss: 1.1923, Accuracy: 59.38%
# Epoch [3/20], Loss: 1.9023, Validation Accuracy: 50.00%
# Epoch [3/20], Step [50/57], Loss: 0.8670, Accuracy: 65.62%
# Epoch [3/20], Loss: 1.6983, Validation Accuracy: 47.66%
# Epoch [4/20], Step [10/57], Loss: 0.8399, Accuracy: 71.88%
# Epoch [4/20], Loss: 1.8308, Validation Accuracy: 51.56%
# Epoch [4/20], Step [20/57], Loss: 0.4939, Accuracy: 90.62%
# Epoch [4/20], Loss: 1.8712, Validation Accuracy: 46.88%
# Epoch [4/20], Step [30/57], Loss: 0.5483, Accuracy: 81.25%
# Epoch [4/20], Loss: 1.8173, Validation Accuracy: 49.61%
# Epoch [4/20], Step [40/57], Loss: 0.9301, Accuracy: 84.38%
# Epoch [4/20], Loss: 1.9156, Validation Accuracy: 46.88%
# Epoch [4/20], Step [50/57], Loss: 0.8125, Accuracy: 75.00%
# Epoch [4/20], Loss: 1.9989, Validation Accuracy: 49.61%
# Epoch [5/20], Step [10/57], Loss: 0.7065, Accuracy: 84.38%
# Epoch [5/20], Loss: 1.9153, Validation Accuracy: 48.83%
# Epoch [5/20], Step [20/57], Loss: 0.7716, Accuracy: 84.38%
# Epoch [5/20], Loss: 1.8976, Validation Accuracy: 51.17%
# Epoch [5/20], Step [30/57], Loss: 0.6164, Accuracy: 84.38%
# Epoch [5/20], Loss: 1.9586, Validation Accuracy: 50.78%
# Epoch [5/20], Step [40/57], Loss: 0.7852, Accuracy: 75.00%
# Epoch [5/20], Loss: 1.8351, Validation Accuracy: 51.56%
# Epoch [5/20], Step [50/57], Loss: 0.5657, Accuracy: 93.75%
# Epoch [5/20], Loss: 1.7822, Validation Accuracy: 51.56%
# Epoch [6/20], Step [10/57], Loss: 0.4241, Accuracy: 93.75%
# Epoch [6/20], Loss: 1.8238, Validation Accuracy: 52.73%
# Epoch [6/20], Step [20/57], Loss: 0.4318, Accuracy: 93.75%
# Epoch [6/20], Loss: 1.7934, Validation Accuracy: 56.25%
# Epoch [6/20], Step [30/57], Loss: 0.6230, Accuracy: 87.50%
# Epoch [6/20], Loss: 1.9725, Validation Accuracy: 49.61%
# Epoch [6/20], Step [40/57], Loss: 0.6482, Accuracy: 84.38%
# Epoch [6/20], Loss: 1.8508, Validation Accuracy: 48.83%
# Epoch [6/20], Step [50/57], Loss: 0.5620, Accuracy: 90.62%
# Epoch [6/20], Loss: 1.8003, Validation Accuracy: 51.95%
# Epoch [7/20], Step [10/57], Loss: 0.3783, Accuracy: 93.75%
# Epoch [7/20], Loss: 1.7498, Validation Accuracy: 52.73%
# Epoch [7/20], Step [20/57], Loss: 0.4212, Accuracy: 84.38%
# Epoch [7/20], Loss: 1.7981, Validation Accuracy: 51.17%
# Epoch [7/20], Step [30/57], Loss: 0.4894, Accuracy: 87.50%
# Epoch [7/20], Loss: 1.8898, Validation Accuracy: 51.56%
# Epoch [7/20], Step [40/57], Loss: 0.4726, Accuracy: 90.62%
# Epoch [7/20], Loss: 1.7963, Validation Accuracy: 51.17%
# Epoch [7/20], Step [50/57], Loss: 0.6277, Accuracy: 84.38%
# Epoch [7/20], Loss: 1.8618, Validation Accuracy: 51.95%
# Epoch [8/20], Step [10/57], Loss: 0.4320, Accuracy: 93.75%
# Epoch [8/20], Loss: 1.7874, Validation Accuracy: 53.12%
# Epoch [8/20], Step [20/57], Loss: 0.3719, Accuracy: 90.62%
# Epoch [8/20], Loss: 1.8894, Validation Accuracy: 49.22%
# Epoch [8/20], Step [30/57], Loss: 0.4813, Accuracy: 81.25%
# Epoch [8/20], Loss: 1.8418, Validation Accuracy: 53.52%
# Epoch [8/20], Step [40/57], Loss: 0.4639, Accuracy: 87.50%
# Epoch [8/20], Loss: 1.6993, Validation Accuracy: 54.69%
# Epoch [8/20], Step [50/57], Loss: 0.6760, Accuracy: 84.38%
# Epoch [8/20], Loss: 1.8421, Validation Accuracy: 54.69%
# Epoch [9/20], Step [10/57], Loss: 0.3399, Accuracy: 90.62%
# Epoch [9/20], Loss: 1.9049, Validation Accuracy: 51.95%
# Epoch [9/20], Step [20/57], Loss: 0.5190, Accuracy: 90.62%
# Epoch [9/20], Loss: 1.7793, Validation Accuracy: 52.34%
# Epoch [9/20], Step [30/57], Loss: 0.3880, Accuracy: 87.50%
# Epoch [9/20], Loss: 1.8256, Validation Accuracy: 51.56%
# Epoch [9/20], Step [40/57], Loss: 0.5043, Accuracy: 87.50%
# Epoch [9/20], Loss: 1.8865, Validation Accuracy: 53.12%
# Epoch [9/20], Step [50/57], Loss: 0.2439, Accuracy: 96.88%
# Epoch [9/20], Loss: 1.9090, Validation Accuracy: 49.61%
# Epoch [10/20], Step [10/57], Loss: 0.1973, Accuracy: 96.88%
# Epoch [10/20], Loss: 1.8567, Validation Accuracy: 53.91%
# Epoch [10/20], Step [20/57], Loss: 0.3370, Accuracy: 93.75%
# Epoch [10/20], Loss: 1.8244, Validation Accuracy: 50.39%
# Epoch [10/20], Step [30/57], Loss: 0.2805, Accuracy: 96.88%
# Epoch [10/20], Loss: 1.7724, Validation Accuracy: 52.73%
# Epoch [10/20], Step [40/57], Loss: 0.2781, Accuracy: 93.75%
# Epoch [10/20], Loss: 1.9682, Validation Accuracy: 52.34%
# Epoch [10/20], Step [50/57], Loss: 0.4497, Accuracy: 81.25%
# Epoch [10/20], Loss: 1.8739, Validation Accuracy: 54.30%
# Epoch [11/20], Step [10/57], Loss: 0.3124, Accuracy: 90.62%
# Epoch [11/20], Loss: 1.7985, Validation Accuracy: 51.17%
# Epoch [11/20], Step [20/57], Loss: 0.3251, Accuracy: 90.62%
# Epoch [11/20], Loss: 1.8788, Validation Accuracy: 51.56%
# Epoch [11/20], Step [30/57], Loss: 0.2094, Accuracy: 96.88%
# Epoch [11/20], Loss: 1.8683, Validation Accuracy: 51.56%
# Epoch [11/20], Step [40/57], Loss: 0.2672, Accuracy: 100.00%
# Epoch [11/20], Loss: 1.8372, Validation Accuracy: 49.61%
# Epoch [11/20], Step [50/57], Loss: 0.2152, Accuracy: 100.00%
# Epoch [11/20], Loss: 1.8228, Validation Accuracy: 53.52%
# Epoch [12/20], Step [10/57], Loss: 0.1875, Accuracy: 96.88%
# Epoch [12/20], Loss: 1.8672, Validation Accuracy: 55.08%
# Epoch [12/20], Step [20/57], Loss: 0.1942, Accuracy: 96.88%
# Epoch [12/20], Loss: 1.8473, Validation Accuracy: 51.95%
# Epoch [12/20], Step [30/57], Loss: 0.2291, Accuracy: 96.88%
# Epoch [12/20], Loss: 1.8336, Validation Accuracy: 53.12%
# Epoch [12/20], Step [40/57], Loss: 0.3526, Accuracy: 90.62%
# Epoch [12/20], Loss: 1.7441, Validation Accuracy: 53.12%
# Epoch [12/20], Step [50/57], Loss: 0.2000, Accuracy: 100.00%
# Epoch [12/20], Loss: 1.7731, Validation Accuracy: 53.52%
# Epoch [13/20], Step [10/57], Loss: 0.1776, Accuracy: 96.88%
# Epoch [13/20], Loss: 1.9801, Validation Accuracy: 54.30%
# Epoch [13/20], Step [20/57], Loss: 0.2791, Accuracy: 96.88%
# Epoch [13/20], Loss: 1.7627, Validation Accuracy: 52.73%
# Epoch [13/20], Step [30/57], Loss: 0.2651, Accuracy: 93.75%
# Epoch [13/20], Loss: 1.8369, Validation Accuracy: 51.17%
# Epoch [13/20], Step [40/57], Loss: 0.1305, Accuracy: 100.00%
# Epoch [13/20], Loss: 2.0235, Validation Accuracy: 48.44%
# Epoch [13/20], Step [50/57], Loss: 0.1530, Accuracy: 96.88%
# Epoch [13/20], Loss: 1.9162, Validation Accuracy: 51.95%
# Epoch [14/20], Step [10/57], Loss: 0.2044, Accuracy: 96.88%
# Epoch [14/20], Loss: 1.7005, Validation Accuracy: 51.56%
# Epoch [14/20], Step [20/57], Loss: 0.2246, Accuracy: 96.88%
# Epoch [14/20], Loss: 1.8727, Validation Accuracy: 53.12%
# Epoch [14/20], Step [30/57], Loss: 0.2313, Accuracy: 93.75%
# Epoch [14/20], Loss: 1.7760, Validation Accuracy: 52.34%
# Epoch [14/20], Step [40/57], Loss: 0.3056, Accuracy: 93.75%
# Epoch [14/20], Loss: 2.1073, Validation Accuracy: 52.73%
# Epoch [14/20], Step [50/57], Loss: 0.2447, Accuracy: 93.75%
# Epoch [14/20], Loss: 1.9088, Validation Accuracy: 54.69%
# Epoch [15/20], Step [10/57], Loss: 0.2515, Accuracy: 90.62%
# Epoch [15/20], Loss: 1.8731, Validation Accuracy: 54.69%
# Epoch [15/20], Step [20/57], Loss: 0.1860, Accuracy: 93.75%
# Epoch [15/20], Loss: 1.9126, Validation Accuracy: 51.95%
# Epoch [15/20], Step [30/57], Loss: 0.1458, Accuracy: 96.88%
# Epoch [15/20], Loss: 1.8647, Validation Accuracy: 51.95%
# Epoch [15/20], Step [40/57], Loss: 0.1679, Accuracy: 100.00%
# Epoch [15/20], Loss: 1.9531, Validation Accuracy: 54.69%
# Epoch [15/20], Step [50/57], Loss: 0.1491, Accuracy: 100.00%
# Epoch [15/20], Loss: 1.8531, Validation Accuracy: 51.56%
# Epoch [16/20], Step [10/57], Loss: 0.1980, Accuracy: 93.75%
# Epoch [16/20], Loss: 1.8903, Validation Accuracy: 51.17%
# Epoch [16/20], Step [20/57], Loss: 0.1257, Accuracy: 96.88%
# Epoch [16/20], Loss: 1.9124, Validation Accuracy: 52.73%
# Epoch [16/20], Step [30/57], Loss: 0.1097, Accuracy: 100.00%
# Epoch [16/20], Loss: 1.9746, Validation Accuracy: 54.30%
# Epoch [16/20], Step [40/57], Loss: 0.2229, Accuracy: 100.00%
# Epoch [16/20], Loss: 1.8297, Validation Accuracy: 54.69%
# Epoch [16/20], Step [50/57], Loss: 0.2037, Accuracy: 93.75%
# Epoch [16/20], Loss: 1.7260, Validation Accuracy: 53.91%
# Epoch [17/20], Step [10/57], Loss: 0.1010, Accuracy: 100.00%
# Epoch [17/20], Loss: 1.9145, Validation Accuracy: 52.73%
# Epoch [17/20], Step [20/57], Loss: 0.2336, Accuracy: 93.75%
# Epoch [17/20], Loss: 2.0125, Validation Accuracy: 53.91%
# Epoch [17/20], Step [30/57], Loss: 0.1291, Accuracy: 100.00%
# Epoch [17/20], Loss: 1.9109, Validation Accuracy: 51.17%
# Epoch [17/20], Step [40/57], Loss: 0.1600, Accuracy: 100.00%
# Epoch [17/20], Loss: 1.7733, Validation Accuracy: 51.95%
# Epoch [17/20], Step [50/57], Loss: 0.2077, Accuracy: 96.88%
# Epoch [17/20], Loss: 1.9168, Validation Accuracy: 51.95%
# Epoch [18/20], Step [10/57], Loss: 0.1606, Accuracy: 96.88%
# Epoch [18/20], Loss: 1.8602, Validation Accuracy: 50.39%
# Epoch [18/20], Step [20/57], Loss: 0.1224, Accuracy: 100.00%
# Epoch [18/20], Loss: 1.8709, Validation Accuracy: 53.91%
# Epoch [18/20], Step [30/57], Loss: 0.1487, Accuracy: 100.00%
# Epoch [18/20], Loss: 1.8732, Validation Accuracy: 53.12%
# Epoch [18/20], Step [40/57], Loss: 0.1219, Accuracy: 100.00%
# Epoch [18/20], Loss: 1.8753, Validation Accuracy: 53.12%
# Epoch [18/20], Step [50/57], Loss: 0.0791, Accuracy: 100.00%
# Epoch [18/20], Loss: 1.8158, Validation Accuracy: 56.25%
# Epoch [19/20], Step [10/57], Loss: 0.1518, Accuracy: 96.88%
# Epoch [19/20], Loss: 1.8756, Validation Accuracy: 49.61%
# Epoch [19/20], Step [20/57], Loss: 0.1168, Accuracy: 100.00%
# Epoch [19/20], Loss: 1.8607, Validation Accuracy: 53.91%
# Epoch [19/20], Step [30/57], Loss: 0.1202, Accuracy: 96.88%
# Epoch [19/20], Loss: 1.8831, Validation Accuracy: 56.64%
# Epoch [19/20], Step [40/57], Loss: 0.2098, Accuracy: 96.88%
# Epoch [19/20], Loss: 1.9306, Validation Accuracy: 55.08%
# Epoch [19/20], Step [50/57], Loss: 0.0935, Accuracy: 100.00%
# Epoch [19/20], Loss: 2.0753, Validation Accuracy: 52.73%
# Epoch [20/20], Step [10/57], Loss: 0.1693, Accuracy: 100.00%
# Epoch [20/20], Loss: 1.9540, Validation Accuracy: 53.52%
# Epoch [20/20], Step [20/57], Loss: 0.0527, Accuracy: 100.00%
# Epoch [20/20], Loss: 1.9616, Validation Accuracy: 51.17%
# Epoch [20/20], Step [30/57], Loss: 0.0877, Accuracy: 100.00%
# Epoch [20/20], Loss: 1.8925, Validation Accuracy: 53.52%
# Epoch [20/20], Step [40/57], Loss: 0.0818, Accuracy: 100.00%
# Epoch [20/20], Loss: 1.9394, Validation Accuracy: 52.73%
# Epoch [20/20], Step [50/57], Loss: 0.0978, Accuracy: 100.00%
# Epoch [20/20], Loss: 1.8439, Validation Accuracy: 50.39%
# ######## Training Finished in 3701.9110333919525 seconds ###########

# %%
for i, data in enumerate(train_dataloader):
    len(data)

# %%
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('steps')
plt.plot(accuracy_train, label="Train Accuracy")
plt.plot(accuracy_validation, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.show()

# %%
####### plot the the training accuracies here #########
num_epochs = 20

epochs = [i for i in range(num_epochs)]
plt.figure()
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')
plt.plot(accuracy_train, label="Train Accuracy")
plt.plot(accuracy_validation, label="Validation Accuracy")
plt.legend()
plt.show()

# %%
plt.title('model Loss')
plt.ylabel('loss')
plt.xlabel('steps')
plt.plot(loss_train, label="Train Loss")
plt.plot(loss_validation, label="Validation Loss")
plt.legend(loc="upper right")
plt.show()
