# %%
import os                       # for working with files
import numpy as np              # for numerical computationss
import pandas as pd             # for working with dataframes
import torch                    # Pytorch module 
import matplotlib.pyplot as plt # for plotting informations on graph and images using tensors
import torch.nn as nn           # for creating  neural networks
from torch.utils.data import DataLoader, random_split # for dataloaders 
from PIL import Image           # for checking images
import torch.nn.functional as F # for functions for calculating loss
import torchvision.transforms as transforms   # for transforming images into tensors 
from torchvision.utils import make_grid       # for data checking
from torchvision.datasets import ImageFolder  # for working with classes and images
from tqdm import tqdm
import time
from torchvision import models

# %%
data_dir = "../input/plantdoc6721"
# data_dir = "/content/drive/MyDrive/COMP6721-Project/PlantVillage-Dataset"

diseases = os.listdir(data_dir)

# %%
# printing the disease names
print(diseases)
print("Total disease classes are: {}".format(len(diseases)))
# Out:
# ['Corn leaf blight', 'Tomato leaf', 'Tomato leaf mosaic virus', 'Squash Powdery mildew leaf', 'Potato leaf late blight', 'Soyabean leaf', 'Peach leaf', 'Tomato leaf late blight', 'Apple leaf', 'Tomato mold leaf', 'Corn Gray leaf spot', 'Tomato leaf yellow virus', 'Strawberry leaf', 'Cherry leaf', 'Apple rust leaf', 'Potato leaf early blight', 'grape leaf black rot', 'Apple Scab Leaf', 'Tomato Septoria leaf spot', 'Tomato leaf bacterial spot', 'Blueberry leaf', 'Bell_pepper leaf spot', 'Corn rust leaf', 'Bell_pepper leaf', 'grape leaf', 'Tomato Early blight leaf', 'Raspberry leaf']
# Total disease classes are: 27

# %%
plants = []
for plant in diseases:
    if plant.split(' ')[0] not in plants:
        plants.append(plant.split(' ')[0])

# %%
# Unique plants in the dataset
print("Number of Classes: {}".format(len(plants)))
print(f"Unique Plants are: ")
for idx, plant in enumerate(plants):
  print(str(idx + 1) + '. ' + plant)
# Out:
# Number of Classes: 13
# Unique Plants are:
# 1. Corn
# 2. Tomato
# 3. Squash
# 4. Potato
# 5. Soyabean
# 6. Peach
# 7. Apple
# 8. Strawberry
# 9. Cherry
# 10. grape
# 11. Blueberry
# 12. Bell_pepper
# 13. Raspberry

# %%
# Number of images for each disease
disease_class_size = {}
for disease in diseases:
    disease_class_size[disease] = len(os.listdir(data_dir + '/' + disease))
    
# converting the disease_class_size dictionary to pandas dataframe passing index as plant name and number of images as column

img_per_class = pd.DataFrame(disease_class_size.values(), index=disease_class_size.keys(), columns=["no. of images"])
img_per_class
# Out:
#                             no. of images
# Corn leaf blight                      192
# Tomato leaf                            63
# Tomato leaf mosaic virus               53
# Squash Powdery mildew leaf            128
# Potato leaf late blight               105
# Soyabean leaf                          65
# Peach leaf                            112
# Tomato leaf late blight               111
# Apple leaf                             90
# Tomato mold leaf                       91
# Corn Gray leaf spot                    68
# Tomato leaf yellow virus               75
# Strawberry leaf                        95
# Cherry leaf                            56
# Apple rust leaf                        89
# Potato leaf early blight              117
# grape leaf black rot                   64
# Apple Scab Leaf                        93
# Tomato Septoria leaf spot             151
# Tomato leaf bacterial spot            109
# Blueberry leaf                        116
# Bell_pepper leaf spot                  71
# Corn rust leaf                        116
# Bell_pepper leaf                       61
# grape leaf                             68
# Tomato Early blight leaf               88
# Raspberry leaf                        119

# %%
# plotting number of images available for each disease
index = [n for n in range(len(disease_class_size.values()))]
plt.figure(figsize=(20, 5))
plt.bar(index, [n for n in disease_class_size.values()], width=0.3)
plt.xlabel('Plants/Diseases', fontsize=10)
plt.ylabel('No of images available', fontsize=10)
plt.xticks(index, diseases, fontsize=5, rotation=90)
plt.title('Images per each class of plant disease')
# Out:
# Text(0.5, 1.0, 'Images per each class of plant disease')

# %%
## Split Train, Test and Validation ##

def get_files_from_folder(path):
    files = os.listdir(path)
    return np.asarray(files)

get_files_from_folder(data_dir)

def load_data(path, validation_split, test_split, batch_size):
    transform_dict = {
        "src": transforms.Compose([
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.225, 0.225, 0.225]),
            transforms.Resize((224, 224))
        ])
    }
    
    dataset = ImageFolder(root=path, transform=transform_dict["src"])
    
    dataset_size = len(dataset)
    validation_size = int(validation_split * dataset_size)
    test_size = int(test_split * dataset_size)
    train_size = dataset_size - (test_size + validation_size)

    train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size])
    
    return train_dataset, validation_dataset, test_dataset

# %%
train_dataset, validation_dataset, test_dataset = load_data(data_dir, 0.1, 0.2, 200)

# %%
len(train_dataset.dataset.imgs)
# Out:
# 2566

# %%
img, label = train_dataset[0]
print(img.shape, label)
# Out:
# torch.Size([3, 224, 224]) 21

# %%
# for checking some images from training dataset
def show_image(image, label):
    # print("Label :" + train_dataset.classes[label] + "(" + str(label) + ")")
    plt.imshow(image.permute(1, 2, 0))

# %%
show_image(*train_dataset[21])

# %%
# setting the batch size
batch_size = 32

# Load data to DataLoaders for training, validation and test
train_dataloader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
validation_dataloader = DataLoader(validation_dataset, batch_size, num_workers=2, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size, num_workers=2, pin_memory=True)

# %%
# helper function to show a batch of training instances
def show_batch(data):
    for images, labels in data:
        fig, ax = plt.subplots(figsize=(30, 30))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dataloader)

# %%
# for calculating the accuracy
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))


# base class for the model
class ImageClassificationBase(nn.Module):
    
    def training_step(self, batch):
        images, labels = batch
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch
        out = self(images)                   # Generate prediction
        loss = F.cross_entropy(out, labels)  # Calculate loss
        acc = accuracy(out, labels)          # Calculate accuracy
        return {"val_loss": loss.detach(), "val_accuracy": acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x["val_loss"] for x in outputs]
        batch_accuracy = [x["val_accuracy"] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()       # Combine loss  
        epoch_accuracy = torch.stack(batch_accuracy).mean()
        return {"val_loss": epoch_loss, "val_accuracy": epoch_accuracy} # Combine accuracies
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_accuracy']))

# %%
# defining the model

model_resnet50 = models.resnet50(pretrained=True)

# %%
for param in model_resnet50.parameters():
    param.requires_grad = False

num_ftrs = model_resnet50.fc.in_features
model_resnet50.fc = nn.Linear(num_ftrs, out_features=len(train_dataset.dataset.classes))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))
model_resnet50.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_resnet50.fc.parameters(), lr=0.001)
# Out:
# Device: cuda:0

# %%
accuracy_validation = []
accuracy_train = []
loss_validation = []
loss_train = []

num_epochs = 20
total_steps = len(train_dataloader)
t1 = time.time()

for epoch in range(num_epochs):
    for i, data in enumerate(train_dataloader):
        images, labels = data[0].to(device), data[1].to(device)
        # Forward pass
        outputs = model_resnet50(images)
        loss = criterion(outputs, labels)
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        if (i + 1) % 10 == 0:
            accuracy = ((correct / total) * 100)
            accuracy_train.append(accuracy)
            loss_train.append(loss.item())
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                .format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(), accuracy))
            
            model_resnet50.eval()
            with torch.no_grad():
                correct_validation_labels = 0
                total_validation_labels = 0

                for validation_data in validation_dataloader:
                    validation_images, validation_labels = validation_data[0].to(device), validation_data[1].to(device)
                    predicted_outputs = model_resnet50(validation_images)

                    _, validation_prediction = torch.max(predicted_outputs.data, 1)
                    total_validation_labels += validation_labels.size(0)
                    correct_validation_labels += (validation_prediction == validation_labels).sum().item()
                # print("Correct-> ", correct_validation_labels)
                # print("Total-> ", total_validation_labels)
                # print(correct_validation_labels/total_validation_labels)
                val_loss = criterion(predicted_outputs, validation_labels)
                
                val_accuracy = ((correct_validation_labels / total_validation_labels) * 100)
                
                accuracy_validation.append(val_accuracy)
                loss_validation.append(val_loss.item())
            
                print('Epoch [{}/{}], Loss: {:.4f}, Validation Accuracy: {:.2f}%'
                      .format(epoch + 1, num_epochs, val_loss.item(), val_accuracy))
     
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Epoch [1/20], Step [10/57], Loss: 2.9552, Accuracy: 15.62%
# Epoch [1/20], Loss: 3.0960, Validation Accuracy: 17.58%
# Epoch [1/20], Step [20/57], Loss: 2.7464, Accuracy: 15.62%
# Epoch [1/20], Loss: 2.7870, Validation Accuracy: 23.83%
# Epoch [1/20], Step [30/57], Loss: 2.5906, Accuracy: 25.00%
# Epoch [1/20], Loss: 2.0941, Validation Accuracy: 28.91%
# Epoch [1/20], Step [40/57], Loss: 2.2515, Accuracy: 34.38%
# Epoch [1/20], Loss: 2.0052, Validation Accuracy: 37.89%
# Epoch [1/20], Step [50/57], Loss: 2.2737, Accuracy: 34.38%
# Epoch [1/20], Loss: 1.8562, Validation Accuracy: 41.41%
# Epoch [2/20], Step [10/57], Loss: 1.6681, Accuracy: 59.38%
# Epoch [2/20], Loss: 1.5857, Validation Accuracy: 45.70%
# Epoch [2/20], Step [20/57], Loss: 1.7189, Accuracy: 53.12%
# Epoch [2/20], Loss: 1.5547, Validation Accuracy: 39.84%
# Epoch [2/20], Step [30/57], Loss: 1.6788, Accuracy: 50.00%
# Epoch [2/20], Loss: 1.5886, Validation Accuracy: 46.88%
# Epoch [2/20], Step [40/57], Loss: 1.9246, Accuracy: 40.62%
# Epoch [2/20], Loss: 1.4254, Validation Accuracy: 48.05%
# Epoch [2/20], Step [50/57], Loss: 1.3601, Accuracy: 56.25%
# Epoch [2/20], Loss: 1.2980, Validation Accuracy: 48.05%
# Epoch [3/20], Step [10/57], Loss: 1.6452, Accuracy: 46.88%
# Epoch [3/20], Loss: 1.4688, Validation Accuracy: 45.70%
# Epoch [3/20], Step [20/57], Loss: 1.5649, Accuracy: 40.62%
# Epoch [3/20], Loss: 1.1842, Validation Accuracy: 49.22%
# Epoch [3/20], Step [30/57], Loss: 1.0750, Accuracy: 71.88%
# Epoch [3/20], Loss: 1.5057, Validation Accuracy: 50.78%
# Epoch [3/20], Step [40/57], Loss: 1.4359, Accuracy: 59.38%
# Epoch [3/20], Loss: 1.2723, Validation Accuracy: 48.05%
# Epoch [3/20], Step [50/57], Loss: 1.4112, Accuracy: 65.62%
# Epoch [3/20], Loss: 1.2904, Validation Accuracy: 48.44%
# Epoch [4/20], Step [10/57], Loss: 1.2398, Accuracy: 65.62%
# Epoch [4/20], Loss: 1.1435, Validation Accuracy: 50.00%
# Epoch [4/20], Step [20/57], Loss: 1.4010, Accuracy: 65.62%
# Epoch [4/20], Loss: 1.3110, Validation Accuracy: 50.39%
# Epoch [4/20], Step [30/57], Loss: 1.0279, Accuracy: 65.62%
# Epoch [4/20], Loss: 1.1998, Validation Accuracy: 48.83%
# Epoch [4/20], Step [40/57], Loss: 0.8201, Accuracy: 81.25%
# Epoch [4/20], Loss: 1.2135, Validation Accuracy: 51.17%
# Epoch [4/20], Step [50/57], Loss: 1.0773, Accuracy: 78.12%
# Epoch [4/20], Loss: 1.1478, Validation Accuracy: 49.61%
# Epoch [5/20], Step [10/57], Loss: 0.8354, Accuracy: 75.00%
# Epoch [5/20], Loss: 1.0899, Validation Accuracy: 55.86%
# Epoch [5/20], Step [20/57], Loss: 0.9942, Accuracy: 71.88%
# Epoch [5/20], Loss: 1.0810, Validation Accuracy: 49.22%
# Epoch [5/20], Step [30/57], Loss: 0.9895, Accuracy: 65.62%
# Epoch [5/20], Loss: 1.1911, Validation Accuracy: 48.83%
# Epoch [5/20], Step [40/57], Loss: 1.2648, Accuracy: 56.25%
# Epoch [5/20], Loss: 1.1262, Validation Accuracy: 50.78%
# Epoch [5/20], Step [50/57], Loss: 0.9686, Accuracy: 78.12%
# Epoch [5/20], Loss: 1.1833, Validation Accuracy: 51.17%
# Epoch [6/20], Step [10/57], Loss: 1.0033, Accuracy: 81.25%
# Epoch [6/20], Loss: 1.2059, Validation Accuracy: 51.95%
# Epoch [6/20], Step [20/57], Loss: 1.0922, Accuracy: 65.62%
# Epoch [6/20], Loss: 1.0661, Validation Accuracy: 52.34%
# Epoch [6/20], Step [30/57], Loss: 0.9327, Accuracy: 75.00%
# Epoch [6/20], Loss: 1.1269, Validation Accuracy: 52.73%
# Epoch [6/20], Step [40/57], Loss: 0.8749, Accuracy: 65.62%
# Epoch [6/20], Loss: 1.1935, Validation Accuracy: 50.39%
# Epoch [6/20], Step [50/57], Loss: 1.0736, Accuracy: 75.00%
# Epoch [6/20], Loss: 1.0668, Validation Accuracy: 54.69%
# Epoch [7/20], Step [10/57], Loss: 0.8596, Accuracy: 78.12%
# Epoch [7/20], Loss: 1.0600, Validation Accuracy: 50.39%
# Epoch [7/20], Step [20/57], Loss: 1.0190, Accuracy: 65.62%
# Epoch [7/20], Loss: 1.1940, Validation Accuracy: 55.08%
# Epoch [7/20], Step [30/57], Loss: 0.8747, Accuracy: 78.12%
# Epoch [7/20], Loss: 1.0534, Validation Accuracy: 52.73%
# Epoch [7/20], Step [40/57], Loss: 1.0599, Accuracy: 68.75%
# Epoch [7/20], Loss: 1.0948, Validation Accuracy: 53.91%
# Epoch [7/20], Step [50/57], Loss: 0.7700, Accuracy: 75.00%
# Epoch [7/20], Loss: 1.2918, Validation Accuracy: 50.78%
# Epoch [8/20], Step [10/57], Loss: 0.6439, Accuracy: 81.25%
# Epoch [8/20], Loss: 1.1340, Validation Accuracy: 54.30%
# Epoch [8/20], Step [20/57], Loss: 0.5193, Accuracy: 96.88%
# Epoch [8/20], Loss: 1.1622, Validation Accuracy: 53.12%
# Epoch [8/20], Step [30/57], Loss: 0.7289, Accuracy: 84.38%
# Epoch [8/20], Loss: 1.1064, Validation Accuracy: 53.91%
# Epoch [8/20], Step [40/57], Loss: 0.7771, Accuracy: 78.12%
# Epoch [8/20], Loss: 1.0414, Validation Accuracy: 50.39%
# Epoch [8/20], Step [50/57], Loss: 0.5849, Accuracy: 84.38%
# Epoch [8/20], Loss: 1.0396, Validation Accuracy: 53.12%
# Epoch [9/20], Step [10/57], Loss: 0.8158, Accuracy: 84.38%
# Epoch [9/20], Loss: 1.0622, Validation Accuracy: 51.95%
# Epoch [9/20], Step [20/57], Loss: 0.8637, Accuracy: 75.00%
# Epoch [9/20], Loss: 1.1793, Validation Accuracy: 48.83%
# Epoch [9/20], Step [30/57], Loss: 0.8783, Accuracy: 81.25%
# Epoch [9/20], Loss: 1.1634, Validation Accuracy: 54.30%
# Epoch [9/20], Step [40/57], Loss: 0.8952, Accuracy: 75.00%
# Epoch [9/20], Loss: 1.1333, Validation Accuracy: 53.12%
# Epoch [9/20], Step [50/57], Loss: 0.8094, Accuracy: 81.25%
# Epoch [9/20], Loss: 1.2166, Validation Accuracy: 49.22%
# Epoch [10/20], Step [10/57], Loss: 0.7061, Accuracy: 81.25%
# Epoch [10/20], Loss: 1.1217, Validation Accuracy: 53.12%
# Epoch [10/20], Step [20/57], Loss: 0.6139, Accuracy: 78.12%
# Epoch [10/20], Loss: 1.1392, Validation Accuracy: 53.52%
# Epoch [10/20], Step [30/57], Loss: 0.5877, Accuracy: 84.38%
# Epoch [10/20], Loss: 1.1712, Validation Accuracy: 53.52%
# Epoch [10/20], Step [40/57], Loss: 0.6347, Accuracy: 84.38%
# Epoch [10/20], Loss: 1.2392, Validation Accuracy: 51.56%
# Epoch [10/20], Step [50/57], Loss: 0.5736, Accuracy: 84.38%
# Epoch [10/20], Loss: 1.0774, Validation Accuracy: 54.30%
# Epoch [11/20], Step [10/57], Loss: 0.7153, Accuracy: 75.00%
# Epoch [11/20], Loss: 1.2777, Validation Accuracy: 50.39%
# Epoch [11/20], Step [20/57], Loss: 0.7080, Accuracy: 81.25%
# Epoch [11/20], Loss: 1.1368, Validation Accuracy: 54.69%
# Epoch [11/20], Step [30/57], Loss: 0.6659, Accuracy: 78.12%
# Epoch [11/20], Loss: 1.1139, Validation Accuracy: 51.95%
# Epoch [11/20], Step [40/57], Loss: 0.9004, Accuracy: 71.88%
# Epoch [11/20], Loss: 1.1868, Validation Accuracy: 52.73%
# Epoch [11/20], Step [50/57], Loss: 0.5670, Accuracy: 84.38%
# Epoch [11/20], Loss: 1.2601, Validation Accuracy: 50.39%
# Epoch [12/20], Step [10/57], Loss: 0.5359, Accuracy: 90.62%
# Epoch [12/20], Loss: 1.2725, Validation Accuracy: 53.91%
# Epoch [12/20], Step [20/57], Loss: 0.6227, Accuracy: 87.50%
# Epoch [12/20], Loss: 1.0748, Validation Accuracy: 51.17%
# Epoch [12/20], Step [30/57], Loss: 0.4568, Accuracy: 90.62%
# Epoch [12/20], Loss: 1.1963, Validation Accuracy: 53.52%
# Epoch [12/20], Step [40/57], Loss: 0.5955, Accuracy: 87.50%
# Epoch [12/20], Loss: 1.2855, Validation Accuracy: 51.95%
# Epoch [12/20], Step [50/57], Loss: 0.7406, Accuracy: 78.12%
# Epoch [12/20], Loss: 1.1187, Validation Accuracy: 55.47%
# Epoch [13/20], Step [10/57], Loss: 0.4889, Accuracy: 87.50%
# Epoch [13/20], Loss: 1.0688, Validation Accuracy: 52.34%
# Epoch [13/20], Step [20/57], Loss: 0.4039, Accuracy: 84.38%
# Epoch [13/20], Loss: 1.1956, Validation Accuracy: 52.73%
# Epoch [13/20], Step [30/57], Loss: 0.4166, Accuracy: 96.88%
# Epoch [13/20], Loss: 1.2456, Validation Accuracy: 51.17%
# Epoch [13/20], Step [40/57], Loss: 0.6029, Accuracy: 81.25%
# Epoch [13/20], Loss: 1.1581, Validation Accuracy: 55.47%
# Epoch [13/20], Step [50/57], Loss: 0.2453, Accuracy: 100.00%
# Epoch [13/20], Loss: 1.1649, Validation Accuracy: 49.22%
# Epoch [14/20], Step [10/57], Loss: 0.6446, Accuracy: 81.25%
# Epoch [14/20], Loss: 1.2095, Validation Accuracy: 55.47%
# Epoch [14/20], Step [20/57], Loss: 0.3915, Accuracy: 90.62%
# Epoch [14/20], Loss: 1.2116, Validation Accuracy: 50.78%
# Epoch [14/20], Step [30/57], Loss: 0.4224, Accuracy: 90.62%
# Epoch [14/20], Loss: 1.2658, Validation Accuracy: 54.69%
# Epoch [14/20], Step [40/57], Loss: 0.6482, Accuracy: 84.38%
# Epoch [14/20], Loss: 1.1940, Validation Accuracy: 51.17%
# Epoch [14/20], Step [50/57], Loss: 0.7039, Accuracy: 81.25%
# Epoch [14/20], Loss: 1.1722, Validation Accuracy: 51.95%
# Epoch [15/20], Step [10/57], Loss: 0.4914, Accuracy: 87.50%
# Epoch [15/20], Loss: 1.2397, Validation Accuracy: 54.69%
# Epoch [15/20], Step [20/57], Loss: 0.7120, Accuracy: 75.00%
# Epoch [15/20], Loss: 1.1871, Validation Accuracy: 55.86%
# Epoch [15/20], Step [30/57], Loss: 0.4694, Accuracy: 81.25%
# Epoch [15/20], Loss: 1.0804, Validation Accuracy: 53.91%
# Epoch [15/20], Step [40/57], Loss: 0.5455, Accuracy: 81.25%
# Epoch [15/20], Loss: 1.2318, Validation Accuracy: 52.34%
# Epoch [15/20], Step [50/57], Loss: 0.3616, Accuracy: 87.50%
# Epoch [15/20], Loss: 1.2091, Validation Accuracy: 50.00%
# Epoch [16/20], Step [10/57], Loss: 0.3418, Accuracy: 90.62%
# Epoch [16/20], Loss: 1.1569, Validation Accuracy: 53.91%
# Epoch [16/20], Step [20/57], Loss: 0.4653, Accuracy: 87.50%
# Epoch [16/20], Loss: 1.2114, Validation Accuracy: 55.47%
# Epoch [16/20], Step [30/57], Loss: 0.3326, Accuracy: 93.75%
# Epoch [16/20], Loss: 1.2184, Validation Accuracy: 52.73%
# Epoch [16/20], Step [40/57], Loss: 0.5203, Accuracy: 87.50%
# Epoch [16/20], Loss: 1.1969, Validation Accuracy: 52.34%
# Epoch [16/20], Step [50/57], Loss: 0.5146, Accuracy: 93.75%
# Epoch [16/20], Loss: 1.1810, Validation Accuracy: 51.95%
# Epoch [17/20], Step [10/57], Loss: 0.5289, Accuracy: 78.12%
# Epoch [17/20], Loss: 1.0379, Validation Accuracy: 52.73%
# Epoch [17/20], Step [20/57], Loss: 0.4579, Accuracy: 87.50%
# Epoch [17/20], Loss: 1.2218, Validation Accuracy: 51.56%
# Epoch [17/20], Step [30/57], Loss: 0.6221, Accuracy: 71.88%
# Epoch [17/20], Loss: 1.2260, Validation Accuracy: 55.86%
# Epoch [17/20], Step [40/57], Loss: 0.3927, Accuracy: 96.88%
# Epoch [17/20], Loss: 1.1369, Validation Accuracy: 52.34%
# Epoch [17/20], Step [50/57], Loss: 0.2779, Accuracy: 96.88%
# Epoch [17/20], Loss: 1.1737, Validation Accuracy: 51.17%
# Epoch [18/20], Step [10/57], Loss: 0.3668, Accuracy: 96.88%
# Epoch [18/20], Loss: 1.1795, Validation Accuracy: 54.69%
# Epoch [18/20], Step [20/57], Loss: 0.4862, Accuracy: 84.38%
# Epoch [18/20], Loss: 1.1026, Validation Accuracy: 52.73%
# Epoch [18/20], Step [30/57], Loss: 0.2970, Accuracy: 96.88%
# Epoch [18/20], Loss: 1.2417, Validation Accuracy: 51.56%
# Epoch [18/20], Step [40/57], Loss: 0.4536, Accuracy: 84.38%
# Epoch [18/20], Loss: 1.2628, Validation Accuracy: 56.64%
# Epoch [18/20], Step [50/57], Loss: 0.3527, Accuracy: 90.62%
# Epoch [18/20], Loss: 1.1516, Validation Accuracy: 53.52%
# Epoch [19/20], Step [10/57], Loss: 0.8200, Accuracy: 68.75%
# Epoch [19/20], Loss: 1.0096, Validation Accuracy: 53.91%
# Epoch [19/20], Step [20/57], Loss: 0.3311, Accuracy: 93.75%
# Epoch [19/20], Loss: 1.2946, Validation Accuracy: 50.00%
# Epoch [19/20], Step [30/57], Loss: 0.5103, Accuracy: 87.50%
# Epoch [19/20], Loss: 1.1200, Validation Accuracy: 55.47%
# Epoch [19/20], Step [40/57], Loss: 0.2381, Accuracy: 96.88%
# Epoch [19/20], Loss: 1.0654, Validation Accuracy: 53.12%
# Epoch [19/20], Step [50/57], Loss: 0.3128, Accuracy: 90.62%
# Epoch [19/20], Loss: 1.2576, Validation Accuracy: 49.22%
# Epoch [20/20], Step [10/57], Loss: 0.3395, Accuracy: 93.75%
# Epoch [20/20], Loss: 1.0379, Validation Accuracy: 52.34%
# Epoch [20/20], Step [20/57], Loss: 0.2891, Accuracy: 96.88%
# Epoch [20/20], Loss: 1.1053, Validation Accuracy: 53.52%
# Epoch [20/20], Step [30/57], Loss: 0.2860, Accuracy: 93.75%
# Epoch [20/20], Loss: 1.2501, Validation Accuracy: 52.73%
# Epoch [20/20], Step [40/57], Loss: 0.3089, Accuracy: 96.88%
# Epoch [20/20], Loss: 1.2259, Validation Accuracy: 50.39%
# Epoch [20/20], Step [50/57], Loss: 0.3269, Accuracy: 93.75%
# Epoch [20/20], Loss: 1.3230, Validation Accuracy: 53.12%
# ######## Training Finished in 3788.7295794487 seconds ###########

# %%
for i, data in enumerate(train_dataloader):
    len(data)

# %%
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('steps')
plt.plot(accuracy_train, label="Train Accuracy")
plt.plot(accuracy_validation, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.show()

# %%
####### plot the the training accuracies here #########
num_epochs = 20

epochs = [i for i in range(num_epochs)]
plt.figure()
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')
plt.plot(accuracy_train, label="Train Accuracy")
plt.plot(accuracy_validation, label="Validation Accuracy")
plt.legend()
plt.show()

# %%
plt.title('model Loss')
plt.ylabel('loss')
plt.xlabel('steps')
plt.plot(loss_train, label="Train Loss")
plt.plot(loss_validation, label="Validation Loss")
plt.legend(loc="upper right")
plt.show()
