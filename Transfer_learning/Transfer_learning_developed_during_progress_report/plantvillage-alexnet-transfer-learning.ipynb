# %%
import os                       # for working with files
import numpy as np              # for numerical computationss
import pandas as pd             # for working with dataframes
import torch                    # Pytorch module 
import matplotlib.pyplot as plt # for plotting informations on graph and images using tensors
import torch.nn as nn           # for creating  neural networks
from torch.utils.data import DataLoader, random_split # for dataloaders 
from PIL import Image           # for checking images
import torch.nn.functional as F # for functions for calculating loss
import torchvision.transforms as transforms   # for transforming images into tensors 
from torchvision.utils import make_grid       # for data checking
from torchvision.datasets import ImageFolder  # for working with classes and images
from tqdm import tqdm
import time
from torchvision import models

# %%
data_dir = "../input/original-dataset/Original dataset"
# data_dir = "/content/drive/MyDrive/COMP6721-Project/PlantVillage-Dataset"

diseases = os.listdir(data_dir)

# %%
# printing the disease names
print(diseases)
print("Total disease classes are: {}".format(len(diseases)))
# Out:
# ['Tomato___Late_blight', 'Tomato___healthy', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Potato___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Early_blight', 'Tomato___Septoria_leaf_spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Strawberry___Leaf_scorch', 'Peach___healthy', 'Apple___Apple_scab', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Bacterial_spot', 'Apple___Black_rot', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Peach___Bacterial_spot', 'Apple___Cedar_apple_rust', 'Tomato___Target_Spot', 'Pepper,_bell___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Potato___Late_blight', 'Tomato___Tomato_mosaic_virus', 'Strawberry___healthy', 'Apple___healthy', 'Grape___Black_rot', 'Potato___Early_blight', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Common_rust_', 'Grape___Esca_(Black_Measles)', 'Raspberry___healthy', 'Tomato___Leaf_Mold', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___healthy']
# Total disease classes are: 38

# %%
plants = []
NumberOfDiseases = 0
for plant in diseases:
    if plant.split('___')[0] not in plants:
        plants.append(plant.split('___')[0])
    if plant.split('___')[1] != 'healthy':
        NumberOfDiseases += 1

# %%
# Unique plants in the dataset
print("Number of plants: {}".format(len(plants)))
print(f"Unique Plants are: ")
for idx, plant in enumerate(plants):
  print(str(idx + 1) + '. ' + plant)
# Out:
# Number of plants: 14
# Unique Plants are:
# 1. Tomato
# 2. Grape
# 3. Orange
# 4. Soybean
# 5. Squash
# 6. Potato
# 7. Corn_(maize)
# 8. Strawberry
# 9. Peach
# 10. Apple
# 11. Blueberry
# 12. Cherry_(including_sour)
# 13. Pepper,_bell
# 14. Raspberry

# %%
# number of unique diseases
print("Total number of diseases: {}".format(NumberOfDiseases))
# Out:
# Total number of diseases: 26

# %%
# Number of images for each disease
disease_class_size = {}
for disease in diseases:
    disease_class_size[disease] = len(os.listdir(data_dir + '/' + disease))
    
# converting the disease_class_size dictionary to pandas dataframe passing index as plant name and number of images as column

img_per_class = pd.DataFrame(disease_class_size.values(), index=disease_class_size.keys(), columns=["no. of images"])
img_per_class
# Out:
#                                                     no. of images
# Tomato___Late_blight                                         1909
# Tomato___healthy                                             1591
# Grape___healthy                                               423
# Orange___Haunglongbing_(Citrus_greening)                     5507
# Soybean___healthy                                            5090
# Squash___Powdery_mildew                                      1835
# Potato___healthy                                              152
# Corn_(maize)___Northern_Leaf_Blight                           985
# Tomato___Early_blight                                        1000
# Tomato___Septoria_leaf_spot                                  1771
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot            513
# Strawberry___Leaf_scorch                                     1109
# Peach___healthy                                               360
# Apple___Apple_scab                                            630
# Tomato___Tomato_Yellow_Leaf_Curl_Virus                       5357
# Tomato___Bacterial_spot                                      2127
# Apple___Black_rot                                             621
# Blueberry___healthy                                          1502
# Cherry_(including_sour)___Powdery_mildew                     1052
# Peach___Bacterial_spot                                       2297
# Apple___Cedar_apple_rust                                      275
# Tomato___Target_Spot                                         1404
# Pepper,_bell___healthy                                       1478
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot)                   1076
# Potato___Late_blight                                         1000
# Tomato___Tomato_mosaic_virus                                  373
# Strawberry___healthy                                          456
# Apple___healthy                                              1645
# Grape___Black_rot                                            1180
# Potato___Early_blight                                        1000
# Cherry_(including_sour)___healthy                             854
# Corn_(maize)___Common_rust_                                  1192
# Grape___Esca_(Black_Measles)                                 1383
# Raspberry___healthy                                           371
# Tomato___Leaf_Mold                                            952
# Tomato___Spider_mites Two-spotted_spider_mite                1676
# Pepper,_bell___Bacterial_spot                                 997
# Corn_(maize)___healthy                                       1162

# %%
# plotting number of images available for each disease
index = [n for n in range(38)]
plt.figure(figsize=(20, 5))
plt.bar(index, [n for n in disease_class_size.values()], width=0.3)
plt.xlabel('Plants/Diseases', fontsize=10)
plt.ylabel('No of images available', fontsize=10)
plt.xticks(index, diseases, fontsize=5, rotation=90)
plt.title('Images per each class of plant disease')
# Out:
# Text(0.5, 1.0, 'Images per each class of plant disease')

# %%
## Split Train, Test and Validation ##

def get_files_from_folder(path):
    files = os.listdir(path)
    return np.asarray(files)

get_files_from_folder(data_dir)

def load_data(path, validation_split, test_split, batch_size):
    transform_dict = {
        "src": transforms.Compose([
            # transforms.Resize(input_size),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.225, 0.225, 0.225]),
            transforms.Resize(224)
        ])
    }
    
    dataset = ImageFolder(root=path, transform=transform_dict["src"])
    
    dataset_size = len(dataset)
    validation_size = int(validation_split * dataset_size)
    test_size = int(test_split * dataset_size)
    train_size = dataset_size - (test_size + validation_size)

    # TODO: Split classes into equal sizes?!
    train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size])
    
    return train_dataset, validation_dataset, test_dataset

# %%
train_dataset, validation_dataset, test_dataset = load_data(data_dir, 0.1, 0.2, 200)

# %%
img, label = train_dataset[0]
print(img.shape, label)
# Out:
# torch.Size([3, 224, 224]) 32

# %%
# for checking some images from training dataset
def show_image(image, label):
    # print("Label :" + train_dataset.classes[label] + "(" + str(label) + ")")
    plt.imshow(image.permute(1, 2, 0))

# %%
show_image(*train_dataset[21])

# %%
# setting the batch size
batch_size = 32

# Load data to DataLoaders for training, validation and test
train_dataloader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
validation_dataloader = DataLoader(validation_dataset, batch_size, num_workers=2, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size, num_workers=2, pin_memory=True)

# %%
# helper function to show a batch of training instances
def show_batch(data):
    for images, labels in data:
        fig, ax = plt.subplots(figsize=(30, 30))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dataloader)

# %%
# for calculating the accuracy
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))


# base class for the model
class ImageClassificationBase(nn.Module):
    
    def training_step(self, batch):
        images, labels = batch
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch
        out = self(images)                   # Generate prediction
        loss = F.cross_entropy(out, labels)  # Calculate loss
        acc = accuracy(out, labels)          # Calculate accuracy
        return {"val_loss": loss.detach(), "val_accuracy": acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x["val_loss"] for x in outputs]
        batch_accuracy = [x["val_accuracy"] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()       # Combine loss  
        epoch_accuracy = torch.stack(batch_accuracy).mean()
        return {"val_loss": epoch_loss, "val_accuracy": epoch_accuracy} # Combine accuracies
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_accuracy']))

# %%
# defining the model and moving it to the GPU

model_alexnet = models.alexnet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
#   0%|          | 0.00/233M [00:00<?, ?B/s]

# %%
for param in model_alexnet.parameters():
    param.requires_grad = False

num_ftrs = model_alexnet.classifier[6].in_features
model_alexnet.classifier[6] = nn.Linear(num_ftrs, out_features=len(train_dataset.dataset.classes))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))
model_alexnet.to(device)
#model_vgg16 = model_vgg16.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_alexnet.classifier[6].parameters(), lr=0.001)
#exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
# Out:
# Device: cuda:0

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))
model_alexnet.to(device)

accuracy_validation = []
accuracy_train = []
loss_validation = []
loss_train = []


num_epochs = 20
total_steps = len(train_dataloader)
t1 = time.time()

k =0
for epoch in range(num_epochs):
    for i, data in enumerate(train_dataloader):
        images, labels = data[0].to(device), data[1].to(device)
        # Forward pass
        outputs = model_alexnet(images)
        loss = criterion(outputs, labels)
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        if (i + 1) % 100 == 0:
            accuracy = ((correct / total) * 100)
            accuracy_train.append(accuracy)
            loss_train.append(loss.item())
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                .format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(), accuracy))
            
            model_alexnet.eval()
            with torch.no_grad():
                correct_validation_labels = 0
                total_validation_labels = 0

                for validation_data in validation_dataloader:
                    validation_images, validation_labels = validation_data[0].to(device), validation_data[1].to(device)
                    predicted_outputs = model_alexnet(validation_images)

                    _, validation_prediction = torch.max(predicted_outputs.data, 1)
                    total_validation_labels += validation_labels.size(0)
                    correct_validation_labels += (validation_prediction == validation_labels).sum().item()
#                 print("Correct-> ", correct_validation_labels)
#                 print("Total-> ", total_validation_labels)
#                 print(correct_validation_labels/total_validation_labels)
                val_loss = criterion(predicted_outputs, validation_labels)
                
                val_accuracy = ((correct_validation_labels / total_validation_labels) * 100)
                
                accuracy_validation.append(val_accuracy)
                loss_validation.append(val_loss.item())
            
                print('Epoch [{}/{}], Loss: {:.4f}, Validation Accuracy: {:.2f}%'
                      .format(epoch + 1, num_epochs, val_loss.item(), val_accuracy))
     
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Device: cuda:0
# Epoch [1/20], Step [100/1188], Loss: 0.6909, Accuracy: 78.12%
# Epoch [1/20], Loss: 0.5173, Validation Accuracy: 85.64%
# Epoch [1/20], Step [200/1188], Loss: 0.4926, Accuracy: 84.38%
# Epoch [1/20], Loss: 0.3693, Validation Accuracy: 89.91%
# Epoch [1/20], Step [300/1188], Loss: 0.2291, Accuracy: 90.62%
# Epoch [1/20], Loss: 0.3860, Validation Accuracy: 92.30%
# Epoch [1/20], Step [400/1188], Loss: 0.2234, Accuracy: 90.62%
# Epoch [1/20], Loss: 0.3025, Validation Accuracy: 91.16%
# Epoch [1/20], Step [500/1188], Loss: 0.4460, Accuracy: 81.25%
# Epoch [1/20], Loss: 0.3295, Validation Accuracy: 92.85%
# Epoch [1/20], Step [600/1188], Loss: 0.4291, Accuracy: 90.62%
# Epoch [1/20], Loss: 0.4628, Validation Accuracy: 92.93%
# Epoch [1/20], Step [700/1188], Loss: 0.4446, Accuracy: 84.38%
# Epoch [1/20], Loss: 0.3270, Validation Accuracy: 92.91%
# Epoch [1/20], Step [800/1188], Loss: 0.3004, Accuracy: 90.62%
# Epoch [1/20], Loss: 0.1447, Validation Accuracy: 90.88%
# Epoch [1/20], Step [900/1188], Loss: 0.0732, Accuracy: 100.00%
# Epoch [1/20], Loss: 0.4220, Validation Accuracy: 93.78%
# Epoch [1/20], Step [1000/1188], Loss: 0.0785, Accuracy: 96.88%
# Epoch [1/20], Loss: 0.3098, Validation Accuracy: 93.55%
# Epoch [1/20], Step [1100/1188], Loss: 0.4326, Accuracy: 84.38%
# Epoch [1/20], Loss: 0.1187, Validation Accuracy: 94.00%
# Epoch [2/20], Step [100/1188], Loss: 0.0426, Accuracy: 100.00%
# Epoch [2/20], Loss: 0.2234, Validation Accuracy: 94.68%
# Epoch [2/20], Step [200/1188], Loss: 0.0300, Accuracy: 100.00%
# Epoch [2/20], Loss: 0.2905, Validation Accuracy: 93.41%
# Epoch [2/20], Step [300/1188], Loss: 0.0856, Accuracy: 96.88%
# Epoch [2/20], Loss: 0.3127, Validation Accuracy: 94.42%
# Epoch [2/20], Step [400/1188], Loss: 0.1997, Accuracy: 96.88%
# Epoch [2/20], Loss: 0.1346, Validation Accuracy: 94.66%
# Epoch [2/20], Step [500/1188], Loss: 0.0453, Accuracy: 96.88%
# Epoch [2/20], Loss: 0.3192, Validation Accuracy: 94.42%
# Epoch [2/20], Step [600/1188], Loss: 0.1812, Accuracy: 93.75%
# Epoch [2/20], Loss: 0.1420, Validation Accuracy: 94.94%
# Epoch [2/20], Step [700/1188], Loss: 0.0594, Accuracy: 100.00%
# Epoch [2/20], Loss: 0.2192, Validation Accuracy: 94.84%
# Epoch [2/20], Step [800/1188], Loss: 0.2451, Accuracy: 87.50%
# Epoch [2/20], Loss: 0.1200, Validation Accuracy: 95.06%
# Epoch [2/20], Step [900/1188], Loss: 0.2263, Accuracy: 93.75%
# Epoch [2/20], Loss: 0.2184, Validation Accuracy: 95.12%
# Epoch [2/20], Step [1000/1188], Loss: 0.0386, Accuracy: 100.00%
# Epoch [2/20], Loss: 0.4588, Validation Accuracy: 93.96%
# Epoch [2/20], Step [1100/1188], Loss: 0.1762, Accuracy: 96.88%
# Epoch [2/20], Loss: 0.2854, Validation Accuracy: 95.29%
# Epoch [3/20], Step [100/1188], Loss: 0.0431, Accuracy: 100.00%
# Epoch [3/20], Loss: 0.3234, Validation Accuracy: 95.23%
# Epoch [3/20], Step [200/1188], Loss: 0.1000, Accuracy: 93.75%
# Epoch [3/20], Loss: 0.3487, Validation Accuracy: 94.88%
# Epoch [3/20], Step [300/1188], Loss: 0.0126, Accuracy: 100.00%
# Epoch [3/20], Loss: 0.1238, Validation Accuracy: 95.27%
# Epoch [3/20], Step [400/1188], Loss: 0.1524, Accuracy: 93.75%
# Epoch [3/20], Loss: 0.1870, Validation Accuracy: 95.21%
# Epoch [3/20], Step [500/1188], Loss: 0.0429, Accuracy: 100.00%
# Epoch [3/20], Loss: 0.2870, Validation Accuracy: 94.40%
# Epoch [3/20], Step [600/1188], Loss: 0.0896, Accuracy: 96.88%
# Epoch [3/20], Loss: 0.2777, Validation Accuracy: 94.81%
# Epoch [3/20], Step [700/1188], Loss: 0.0785, Accuracy: 96.88%
# Epoch [3/20], Loss: 0.1835, Validation Accuracy: 95.58%
# Epoch [3/20], Step [800/1188], Loss: 0.1002, Accuracy: 93.75%
# Epoch [3/20], Loss: 0.2478, Validation Accuracy: 95.03%
# Epoch [3/20], Step [900/1188], Loss: 0.0805, Accuracy: 96.88%
# Epoch [3/20], Loss: 0.2034, Validation Accuracy: 96.11%
# Epoch [3/20], Step [1000/1188], Loss: 0.1757, Accuracy: 93.75%
# Epoch [3/20], Loss: 0.2285, Validation Accuracy: 95.12%
# Epoch [3/20], Step [1100/1188], Loss: 0.0569, Accuracy: 96.88%
# Epoch [3/20], Loss: 0.1779, Validation Accuracy: 95.16%
# Epoch [4/20], Step [100/1188], Loss: 0.0680, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.1900, Validation Accuracy: 96.21%
# Epoch [4/20], Step [200/1188], Loss: 0.0380, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.0806, Validation Accuracy: 95.43%
# Epoch [4/20], Step [300/1188], Loss: 0.1005, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.2587, Validation Accuracy: 95.43%
# Epoch [4/20], Step [400/1188], Loss: 0.0651, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.4105, Validation Accuracy: 95.56%
# Epoch [4/20], Step [500/1188], Loss: 0.0542, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.5425, Validation Accuracy: 95.40%
# Epoch [4/20], Step [600/1188], Loss: 0.0953, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.4127, Validation Accuracy: 95.38%
# Epoch [4/20], Step [700/1188], Loss: 0.1110, Accuracy: 93.75%
# Epoch [4/20], Loss: 0.3358, Validation Accuracy: 94.75%
# Epoch [4/20], Step [800/1188], Loss: 0.0293, Accuracy: 100.00%
# Epoch [4/20], Loss: 0.3848, Validation Accuracy: 95.82%
# Epoch [4/20], Step [900/1188], Loss: 0.0022, Accuracy: 100.00%
# Epoch [4/20], Loss: 0.2222, Validation Accuracy: 95.38%
# Epoch [4/20], Step [1000/1188], Loss: 0.1122, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.2365, Validation Accuracy: 95.36%
# Epoch [4/20], Step [1100/1188], Loss: 0.1998, Accuracy: 93.75%
# Epoch [4/20], Loss: 0.2895, Validation Accuracy: 95.17%
# Epoch [5/20], Step [100/1188], Loss: 0.1235, Accuracy: 96.88%
# Epoch [5/20], Loss: 0.3301, Validation Accuracy: 95.64%
# Epoch [5/20], Step [200/1188], Loss: 0.0167, Accuracy: 100.00%
# Epoch [5/20], Loss: 0.3456, Validation Accuracy: 96.00%
# Epoch [5/20], Step [300/1188], Loss: 0.0063, Accuracy: 100.00%
# Epoch [5/20], Loss: 0.2929, Validation Accuracy: 93.81%
# Epoch [5/20], Step [400/1188], Loss: 0.0928, Accuracy: 96.88%
# Epoch [5/20], Loss: 0.4314, Validation Accuracy: 95.10%
# Epoch [5/20], Step [500/1188], Loss: 0.0150, Accuracy: 100.00%
# Epoch [5/20], Loss: 0.5988, Validation Accuracy: 95.65%
# Epoch [5/20], Step [600/1188], Loss: 0.0031, Accuracy: 100.00%
# Epoch [5/20], Loss: 0.4991, Validation Accuracy: 95.45%
# Epoch [5/20], Step [700/1188], Loss: 0.0112, Accuracy: 100.00%
# Epoch [5/20], Loss: 0.2789, Validation Accuracy: 95.41%
# Epoch [5/20], Step [800/1188], Loss: 0.0526, Accuracy: 96.88%
# Epoch [5/20], Loss: 0.4048, Validation Accuracy: 95.60%
# Epoch [5/20], Step [900/1188], Loss: 0.0009, Accuracy: 100.00%
# Epoch [5/20], Loss: 0.3040, Validation Accuracy: 95.16%
# Epoch [5/20], Step [1000/1188], Loss: 0.1162, Accuracy: 93.75%
# Epoch [5/20], Loss: 0.1915, Validation Accuracy: 95.78%
# Epoch [5/20], Step [1100/1188], Loss: 0.0623, Accuracy: 96.88%
# Epoch [5/20], Loss: 0.3772, Validation Accuracy: 95.06%
# Epoch [6/20], Step [100/1188], Loss: 0.0243, Accuracy: 100.00%
# Epoch [6/20], Loss: 0.2690, Validation Accuracy: 96.37%
# Epoch [6/20], Step [200/1188], Loss: 0.0044, Accuracy: 100.00%
# Epoch [6/20], Loss: 0.5518, Validation Accuracy: 95.69%
# Epoch [6/20], Step [300/1188], Loss: 0.0146, Accuracy: 100.00%
# Epoch [6/20], Loss: 0.2045, Validation Accuracy: 96.32%
# Epoch [6/20], Step [400/1188], Loss: 0.0068, Accuracy: 100.00%
# Epoch [6/20], Loss: 0.2486, Validation Accuracy: 95.41%
# Epoch [6/20], Step [500/1188], Loss: 0.1760, Accuracy: 93.75%
# Epoch [6/20], Loss: 0.1945, Validation Accuracy: 95.78%
# Epoch [6/20], Step [600/1188], Loss: 0.1830, Accuracy: 93.75%
# Epoch [6/20], Loss: 0.2336, Validation Accuracy: 95.84%
# Epoch [6/20], Step [700/1188], Loss: 0.0927, Accuracy: 96.88%
# Epoch [6/20], Loss: 0.2032, Validation Accuracy: 95.71%
# Epoch [6/20], Step [800/1188], Loss: 0.0077, Accuracy: 100.00%
# Epoch [6/20], Loss: 0.1775, Validation Accuracy: 96.10%
# Epoch [6/20], Step [900/1188], Loss: 0.1508, Accuracy: 93.75%
# Epoch [6/20], Loss: 0.0926, Validation Accuracy: 95.65%
# Epoch [6/20], Step [1000/1188], Loss: 0.2755, Accuracy: 93.75%
# Epoch [6/20], Loss: 0.2718, Validation Accuracy: 96.10%
# Epoch [6/20], Step [1100/1188], Loss: 0.0256, Accuracy: 100.00%
# Epoch [6/20], Loss: 0.4485, Validation Accuracy: 95.05%
# Epoch [7/20], Step [100/1188], Loss: 0.1480, Accuracy: 90.62%
# Epoch [7/20], Loss: 0.2952, Validation Accuracy: 95.19%
# Epoch [7/20], Step [200/1188], Loss: 0.0061, Accuracy: 100.00%
# Epoch [7/20], Loss: 0.3553, Validation Accuracy: 95.67%
# Epoch [7/20], Step [300/1188], Loss: 0.0850, Accuracy: 96.88%
# Epoch [7/20], Loss: 0.1014, Validation Accuracy: 96.02%
# Epoch [7/20], Step [400/1188], Loss: 0.0123, Accuracy: 100.00%
# Epoch [7/20], Loss: 0.4765, Validation Accuracy: 95.56%
# Epoch [7/20], Step [500/1188], Loss: 0.0328, Accuracy: 96.88%
# Epoch [7/20], Loss: 0.0623, Validation Accuracy: 95.05%
# Epoch [7/20], Step [600/1188], Loss: 0.1623, Accuracy: 96.88%
# Epoch [7/20], Loss: 0.3413, Validation Accuracy: 95.95%
# Epoch [7/20], Step [700/1188], Loss: 0.0208, Accuracy: 100.00%
# Epoch [7/20], Loss: 0.3194, Validation Accuracy: 95.87%
# Epoch [7/20], Step [800/1188], Loss: 0.0128, Accuracy: 100.00%
# Epoch [7/20], Loss: 0.2619, Validation Accuracy: 96.26%
# Epoch [7/20], Step [900/1188], Loss: 0.0110, Accuracy: 100.00%
# Epoch [7/20], Loss: 0.3819, Validation Accuracy: 96.15%
# Epoch [7/20], Step [1000/1188], Loss: 0.0289, Accuracy: 96.88%
# Epoch [7/20], Loss: 0.2573, Validation Accuracy: 96.57%
# Epoch [7/20], Step [1100/1188], Loss: 0.0884, Accuracy: 96.88%
# Epoch [7/20], Loss: 0.2344, Validation Accuracy: 95.60%
# Epoch [8/20], Step [100/1188], Loss: 0.0049, Accuracy: 100.00%
# Epoch [8/20], Loss: 0.2271, Validation Accuracy: 96.32%
# Epoch [8/20], Step [200/1188], Loss: 0.0124, Accuracy: 100.00%
# Epoch [8/20], Loss: 0.3086, Validation Accuracy: 96.02%
# Epoch [8/20], Step [300/1188], Loss: 0.0006, Accuracy: 100.00%
# Epoch [8/20], Loss: 0.4692, Validation Accuracy: 95.86%
# Epoch [8/20], Step [400/1188], Loss: 0.0361, Accuracy: 96.88%
# Epoch [8/20], Loss: 0.5805, Validation Accuracy: 96.13%
# Epoch [8/20], Step [500/1188], Loss: 0.0366, Accuracy: 96.88%
# Epoch [8/20], Loss: 0.3526, Validation Accuracy: 95.58%
# Epoch [8/20], Step [600/1188], Loss: 0.1024, Accuracy: 96.88%
# Epoch [8/20], Loss: 0.2446, Validation Accuracy: 95.67%
# Epoch [8/20], Step [700/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [8/20], Loss: 0.2753, Validation Accuracy: 95.49%
# Epoch [8/20], Step [800/1188], Loss: 0.0456, Accuracy: 96.88%
# Epoch [8/20], Loss: 0.1092, Validation Accuracy: 95.54%
# Epoch [8/20], Step [900/1188], Loss: 0.0038, Accuracy: 100.00%
# Epoch [8/20], Loss: 0.1629, Validation Accuracy: 95.87%
# Epoch [8/20], Step [1000/1188], Loss: 0.0223, Accuracy: 100.00%
# Epoch [8/20], Loss: 0.3320, Validation Accuracy: 95.82%
# Epoch [8/20], Step [1100/1188], Loss: 0.0535, Accuracy: 96.88%
# Epoch [8/20], Loss: 0.0300, Validation Accuracy: 96.17%
# Epoch [9/20], Step [100/1188], Loss: 0.0403, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.1140, Validation Accuracy: 96.32%
# Epoch [9/20], Step [200/1188], Loss: 0.0255, Accuracy: 100.00%
# Epoch [9/20], Loss: 0.0723, Validation Accuracy: 96.34%
# Epoch [9/20], Step [300/1188], Loss: 0.0330, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.0122, Validation Accuracy: 96.63%
# Epoch [9/20], Step [400/1188], Loss: 0.0029, Accuracy: 100.00%
# Epoch [9/20], Loss: 0.0307, Validation Accuracy: 96.13%
# Epoch [9/20], Step [500/1188], Loss: 0.0808, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.1103, Validation Accuracy: 96.00%
# Epoch [9/20], Step [600/1188], Loss: 0.0038, Accuracy: 100.00%
# Epoch [9/20], Loss: 0.1424, Validation Accuracy: 96.54%
# Epoch [9/20], Step [700/1188], Loss: 0.0307, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.1448, Validation Accuracy: 96.08%
# Epoch [9/20], Step [800/1188], Loss: 0.1432, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.2933, Validation Accuracy: 96.17%
# Epoch [9/20], Step [900/1188], Loss: 0.0133, Accuracy: 100.00%
# Epoch [9/20], Loss: 0.0123, Validation Accuracy: 95.97%
# Epoch [9/20], Step [1000/1188], Loss: 0.0627, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.5244, Validation Accuracy: 96.04%
# Epoch [9/20], Step [1100/1188], Loss: 0.0080, Accuracy: 100.00%
# Epoch [9/20], Loss: 0.0291, Validation Accuracy: 95.93%
# Epoch [10/20], Step [100/1188], Loss: 0.1000, Accuracy: 96.88%
# Epoch [10/20], Loss: 0.0141, Validation Accuracy: 94.90%
# Epoch [10/20], Step [200/1188], Loss: 0.0218, Accuracy: 100.00%
# Epoch [10/20], Loss: 0.1721, Validation Accuracy: 96.48%
# Epoch [10/20], Step [300/1188], Loss: 0.1231, Accuracy: 96.88%
# Epoch [10/20], Loss: 0.0842, Validation Accuracy: 96.19%
# Epoch [10/20], Step [400/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [10/20], Loss: 0.1552, Validation Accuracy: 96.06%
# Epoch [10/20], Step [500/1188], Loss: 0.0176, Accuracy: 100.00%
# Epoch [10/20], Loss: 0.2799, Validation Accuracy: 95.64%
# Epoch [10/20], Step [600/1188], Loss: 0.0021, Accuracy: 100.00%
# Epoch [10/20], Loss: 0.4995, Validation Accuracy: 95.41%
# Epoch [10/20], Step [700/1188], Loss: 0.0258, Accuracy: 96.88%
# Epoch [10/20], Loss: 0.0787, Validation Accuracy: 95.80%
# Epoch [10/20], Step [800/1188], Loss: 0.0067, Accuracy: 100.00%
# Epoch [10/20], Loss: 0.2894, Validation Accuracy: 96.04%
# Epoch [10/20], Step [900/1188], Loss: 0.1245, Accuracy: 93.75%
# Epoch [10/20], Loss: 0.2957, Validation Accuracy: 96.45%
# Epoch [10/20], Step [1000/1188], Loss: 0.0200, Accuracy: 100.00%
# Epoch [10/20], Loss: 0.0703, Validation Accuracy: 96.37%
# Epoch [10/20], Step [1100/1188], Loss: 0.0177, Accuracy: 100.00%
# Epoch [10/20], Loss: 0.2791, Validation Accuracy: 95.89%
# Epoch [11/20], Step [100/1188], Loss: 0.0559, Accuracy: 96.88%
# Epoch [11/20], Loss: 0.2705, Validation Accuracy: 96.04%
# Epoch [11/20], Step [200/1188], Loss: 0.0091, Accuracy: 100.00%
# Epoch [11/20], Loss: 0.2761, Validation Accuracy: 95.95%
# Epoch [11/20], Step [300/1188], Loss: 0.0236, Accuracy: 96.88%
# Epoch [11/20], Loss: 0.2134, Validation Accuracy: 95.75%
# Epoch [11/20], Step [400/1188], Loss: 0.0289, Accuracy: 100.00%
# Epoch [11/20], Loss: 0.0361, Validation Accuracy: 96.10%
# Epoch [11/20], Step [500/1188], Loss: 0.0492, Accuracy: 96.88%
# Epoch [11/20], Loss: 0.1083, Validation Accuracy: 95.99%
# Epoch [11/20], Step [600/1188], Loss: 0.0443, Accuracy: 96.88%
# Epoch [11/20], Loss: 0.1291, Validation Accuracy: 96.00%
# Epoch [11/20], Step [700/1188], Loss: 0.0090, Accuracy: 100.00%
# Epoch [11/20], Loss: 0.0212, Validation Accuracy: 96.13%
# Epoch [11/20], Step [800/1188], Loss: 0.0298, Accuracy: 96.88%
# Epoch [11/20], Loss: 0.2029, Validation Accuracy: 95.84%
# Epoch [11/20], Step [900/1188], Loss: 0.0735, Accuracy: 93.75%
# Epoch [11/20], Loss: 0.2013, Validation Accuracy: 96.11%
# Epoch [11/20], Step [1000/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [11/20], Loss: 0.1633, Validation Accuracy: 96.35%
# Epoch [11/20], Step [1100/1188], Loss: 0.0052, Accuracy: 100.00%
# Epoch [11/20], Loss: 0.0349, Validation Accuracy: 96.11%
# Epoch [12/20], Step [100/1188], Loss: 0.0059, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.0845, Validation Accuracy: 96.34%
# Epoch [12/20], Step [200/1188], Loss: 0.0112, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.0335, Validation Accuracy: 96.39%
# Epoch [12/20], Step [300/1188], Loss: 0.1899, Accuracy: 96.88%
# Epoch [12/20], Loss: 0.1643, Validation Accuracy: 96.24%
# Epoch [12/20], Step [400/1188], Loss: 0.0002, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.3004, Validation Accuracy: 96.08%
# Epoch [12/20], Step [500/1188], Loss: 0.0095, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.1702, Validation Accuracy: 95.71%
# Epoch [12/20], Step [600/1188], Loss: 0.0085, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.0564, Validation Accuracy: 95.97%
# Epoch [12/20], Step [700/1188], Loss: 0.0002, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.2228, Validation Accuracy: 95.91%
# Epoch [12/20], Step [800/1188], Loss: 0.0178, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.1251, Validation Accuracy: 95.86%
# Epoch [12/20], Step [900/1188], Loss: 0.0096, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.1277, Validation Accuracy: 95.36%
# Epoch [12/20], Step [1000/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.3080, Validation Accuracy: 96.45%
# Epoch [12/20], Step [1100/1188], Loss: 0.0022, Accuracy: 100.00%
# Epoch [12/20], Loss: 0.2262, Validation Accuracy: 95.54%
# Epoch [13/20], Step [100/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [13/20], Loss: 0.2364, Validation Accuracy: 95.73%
# Epoch [13/20], Step [200/1188], Loss: 0.0158, Accuracy: 100.00%
# Epoch [13/20], Loss: 0.2170, Validation Accuracy: 95.93%
# Epoch [13/20], Step [300/1188], Loss: 0.0016, Accuracy: 100.00%
# Epoch [13/20], Loss: 0.3764, Validation Accuracy: 96.22%
# Epoch [13/20], Step [400/1188], Loss: 0.0087, Accuracy: 100.00%
# Epoch [13/20], Loss: 0.1186, Validation Accuracy: 96.21%
# Epoch [13/20], Step [500/1188], Loss: 0.1485, Accuracy: 96.88%
# Epoch [13/20], Loss: 0.5102, Validation Accuracy: 96.28%
# Epoch [13/20], Step [600/1188], Loss: 0.0035, Accuracy: 100.00%
# Epoch [13/20], Loss: 0.2608, Validation Accuracy: 95.51%
# Epoch [13/20], Step [700/1188], Loss: 0.0111, Accuracy: 100.00%
# Epoch [13/20], Loss: 0.1205, Validation Accuracy: 96.45%
# Epoch [13/20], Step [800/1188], Loss: 0.0022, Accuracy: 100.00%
# Epoch [13/20], Loss: 0.0123, Validation Accuracy: 95.16%
# Epoch [13/20], Step [900/1188], Loss: 0.1246, Accuracy: 96.88%
# Epoch [13/20], Loss: 0.1406, Validation Accuracy: 96.06%
# Epoch [13/20], Step [1000/1188], Loss: 0.0013, Accuracy: 100.00%
# Epoch [13/20], Loss: 0.2078, Validation Accuracy: 96.15%
# Epoch [13/20], Step [1100/1188], Loss: 0.1421, Accuracy: 96.88%
# Epoch [13/20], Loss: 0.1495, Validation Accuracy: 96.35%
# Epoch [14/20], Step [100/1188], Loss: 0.0047, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.0390, Validation Accuracy: 95.78%
# Epoch [14/20], Step [200/1188], Loss: 0.0017, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.0826, Validation Accuracy: 96.32%
# Epoch [14/20], Step [300/1188], Loss: 0.0007, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.0814, Validation Accuracy: 96.39%
# Epoch [14/20], Step [400/1188], Loss: 0.0003, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.1513, Validation Accuracy: 95.21%
# Epoch [14/20], Step [500/1188], Loss: 0.1637, Accuracy: 93.75%
# Epoch [14/20], Loss: 0.2280, Validation Accuracy: 95.65%
# Epoch [14/20], Step [600/1188], Loss: 0.1584, Accuracy: 96.88%
# Epoch [14/20], Loss: 0.0601, Validation Accuracy: 96.17%
# Epoch [14/20], Step [700/1188], Loss: 0.0039, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.2369, Validation Accuracy: 96.67%
# Epoch [14/20], Step [800/1188], Loss: 0.0245, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.0272, Validation Accuracy: 96.67%
# Epoch [14/20], Step [900/1188], Loss: 0.0305, Accuracy: 96.88%
# Epoch [14/20], Loss: 0.3097, Validation Accuracy: 96.22%
# Epoch [14/20], Step [1000/1188], Loss: 0.0037, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.6014, Validation Accuracy: 96.24%
# Epoch [14/20], Step [1100/1188], Loss: 0.0032, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.0450, Validation Accuracy: 96.35%
# Epoch [15/20], Step [100/1188], Loss: 0.0046, Accuracy: 100.00%
# Epoch [15/20], Loss: 0.1255, Validation Accuracy: 96.67%
# Epoch [15/20], Step [200/1188], Loss: 0.0043, Accuracy: 100.00%
# Epoch [15/20], Loss: 0.1089, Validation Accuracy: 96.37%
# Epoch [15/20], Step [300/1188], Loss: 0.0022, Accuracy: 100.00%
# Epoch [15/20], Loss: 0.5309, Validation Accuracy: 96.81%
# Epoch [15/20], Step [400/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [15/20], Loss: 0.3455, Validation Accuracy: 96.52%
# Epoch [15/20], Step [500/1188], Loss: 0.0007, Accuracy: 100.00%
# Epoch [15/20], Loss: 0.1227, Validation Accuracy: 96.15%
# Epoch [15/20], Step [600/1188], Loss: 0.0019, Accuracy: 100.00%
# Epoch [15/20], Loss: 0.2018, Validation Accuracy: 96.50%
# Epoch [15/20], Step [700/1188], Loss: 0.0743, Accuracy: 96.88%
# Epoch [15/20], Loss: 0.1092, Validation Accuracy: 96.11%
# Epoch [15/20], Step [800/1188], Loss: 0.0457, Accuracy: 96.88%
# Epoch [15/20], Loss: 0.3467, Validation Accuracy: 95.89%
# Epoch [15/20], Step [900/1188], Loss: 0.1248, Accuracy: 96.88%
# Epoch [15/20], Loss: 0.0212, Validation Accuracy: 96.37%
# Epoch [15/20], Step [1000/1188], Loss: 0.0225, Accuracy: 96.88%
# Epoch [15/20], Loss: 0.1579, Validation Accuracy: 96.65%
# Epoch [15/20], Step [1100/1188], Loss: 0.0013, Accuracy: 100.00%
# Epoch [15/20], Loss: 0.1748, Validation Accuracy: 96.74%
# Epoch [16/20], Step [100/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [16/20], Loss: 0.1650, Validation Accuracy: 96.50%
# Epoch [16/20], Step [200/1188], Loss: 0.0024, Accuracy: 100.00%
# Epoch [16/20], Loss: 0.0426, Validation Accuracy: 96.11%
# Epoch [16/20], Step [300/1188], Loss: 0.0848, Accuracy: 96.88%
# Epoch [16/20], Loss: 0.2329, Validation Accuracy: 96.57%
# Epoch [16/20], Step [400/1188], Loss: 0.0724, Accuracy: 93.75%
# Epoch [16/20], Loss: 0.2878, Validation Accuracy: 96.74%
# Epoch [16/20], Step [500/1188], Loss: 0.0339, Accuracy: 96.88%
# Epoch [16/20], Loss: 0.0111, Validation Accuracy: 96.70%
# Epoch [16/20], Step [600/1188], Loss: 0.0010, Accuracy: 100.00%
# Epoch [16/20], Loss: 0.5367, Validation Accuracy: 96.59%
# Epoch [16/20], Step [700/1188], Loss: 0.0024, Accuracy: 100.00%
# Epoch [16/20], Loss: 0.0403, Validation Accuracy: 96.54%
# Epoch [16/20], Step [800/1188], Loss: 0.1394, Accuracy: 96.88%
# Epoch [16/20], Loss: 0.1203, Validation Accuracy: 96.61%
# Epoch [16/20], Step [900/1188], Loss: 0.0219, Accuracy: 100.00%
# Epoch [16/20], Loss: 0.3404, Validation Accuracy: 96.19%
# Epoch [16/20], Step [1000/1188], Loss: 0.0008, Accuracy: 100.00%
# Epoch [16/20], Loss: 0.3749, Validation Accuracy: 96.26%
# Epoch [16/20], Step [1100/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [16/20], Loss: 0.6905, Validation Accuracy: 95.99%
# Epoch [17/20], Step [100/1188], Loss: 0.1890, Accuracy: 96.88%
# Epoch [17/20], Loss: 0.1434, Validation Accuracy: 96.46%
# Epoch [17/20], Step [200/1188], Loss: 0.0004, Accuracy: 100.00%
# Epoch [17/20], Loss: 0.0318, Validation Accuracy: 96.43%
# Epoch [17/20], Step [300/1188], Loss: 0.0025, Accuracy: 100.00%
# Epoch [17/20], Loss: 0.1614, Validation Accuracy: 96.76%
# Epoch [17/20], Step [400/1188], Loss: 0.0001, Accuracy: 100.00%
# Epoch [17/20], Loss: 0.0428, Validation Accuracy: 96.21%
# Epoch [17/20], Step [500/1188], Loss: 0.0017, Accuracy: 100.00%
# Epoch [17/20], Loss: 0.1692, Validation Accuracy: 96.69%
# Epoch [17/20], Step [600/1188], Loss: 0.0037, Accuracy: 100.00%
# Epoch [17/20], Loss: 0.5426, Validation Accuracy: 95.86%
# Epoch [17/20], Step [700/1188], Loss: 0.1060, Accuracy: 96.88%
# Epoch [17/20], Loss: 0.0978, Validation Accuracy: 96.41%
# Epoch [17/20], Step [800/1188], Loss: 0.0003, Accuracy: 100.00%
# Epoch [17/20], Loss: 0.2661, Validation Accuracy: 96.52%
# Epoch [17/20], Step [900/1188], Loss: 0.0021, Accuracy: 100.00%
# Epoch [17/20], Loss: 0.1109, Validation Accuracy: 96.41%
# Epoch [17/20], Step [1000/1188], Loss: 0.0828, Accuracy: 96.88%
# Epoch [17/20], Loss: 0.0458, Validation Accuracy: 96.59%
# Epoch [17/20], Step [1100/1188], Loss: 0.0216, Accuracy: 100.00%
# Epoch [17/20], Loss: 0.2145, Validation Accuracy: 96.63%
# Epoch [18/20], Step [100/1188], Loss: 0.0012, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.0364, Validation Accuracy: 96.56%
# Epoch [18/20], Step [200/1188], Loss: 0.1355, Accuracy: 96.88%
# Epoch [18/20], Loss: 0.0572, Validation Accuracy: 96.34%
# Epoch [18/20], Step [300/1188], Loss: 0.0041, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.0850, Validation Accuracy: 96.37%
# Epoch [18/20], Step [400/1188], Loss: 0.0003, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.0085, Validation Accuracy: 96.48%
# Epoch [18/20], Step [500/1188], Loss: 0.0249, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.0535, Validation Accuracy: 96.43%
# Epoch [18/20], Step [600/1188], Loss: 0.0001, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.0030, Validation Accuracy: 96.19%
# Epoch [18/20], Step [700/1188], Loss: 0.0019, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.1502, Validation Accuracy: 96.26%
# Epoch [18/20], Step [800/1188], Loss: 0.0830, Accuracy: 96.88%
# Epoch [18/20], Loss: 0.0080, Validation Accuracy: 96.65%
# Epoch [18/20], Step [900/1188], Loss: 0.0003, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.3447, Validation Accuracy: 96.13%
# Epoch [18/20], Step [1000/1188], Loss: 0.0240, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.2566, Validation Accuracy: 96.35%
# Epoch [18/20], Step [1100/1188], Loss: 0.0011, Accuracy: 100.00%
# Epoch [18/20], Loss: 0.2422, Validation Accuracy: 96.48%
# Epoch [19/20], Step [100/1188], Loss: 0.0005, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.0017, Validation Accuracy: 96.74%
# Epoch [19/20], Step [200/1188], Loss: 0.0198, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.0180, Validation Accuracy: 96.56%
# Epoch [19/20], Step [300/1188], Loss: 0.0118, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.3204, Validation Accuracy: 96.30%
# Epoch [19/20], Step [400/1188], Loss: 0.0005, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.2593, Validation Accuracy: 96.63%
# Epoch [19/20], Step [500/1188], Loss: 0.0063, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.4161, Validation Accuracy: 96.28%
# Epoch [19/20], Step [600/1188], Loss: 0.0017, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.0223, Validation Accuracy: 95.80%
# Epoch [19/20], Step [700/1188], Loss: 0.0001, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.2031, Validation Accuracy: 96.37%
# Epoch [19/20], Step [800/1188], Loss: 0.0021, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.1143, Validation Accuracy: 96.17%
# Epoch [19/20], Step [900/1188], Loss: 0.0057, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.0957, Validation Accuracy: 95.65%
# Epoch [19/20], Step [1000/1188], Loss: 0.0001, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.0768, Validation Accuracy: 96.04%
# Epoch [19/20], Step [1100/1188], Loss: 0.0003, Accuracy: 100.00%
# Epoch [19/20], Loss: 0.0999, Validation Accuracy: 96.28%
# Epoch [20/20], Step [100/1188], Loss: 0.0000, Accuracy: 100.00%
# Epoch [20/20], Loss: 0.1897, Validation Accuracy: 96.65%
# Epoch [20/20], Step [200/1188], Loss: 0.0015, Accuracy: 100.00%
# Epoch [20/20], Loss: 0.0825, Validation Accuracy: 96.50%
# Epoch [20/20], Step [300/1188], Loss: 0.0576, Accuracy: 96.88%
# Epoch [20/20], Loss: 0.0792, Validation Accuracy: 96.69%
# Epoch [20/20], Step [400/1188], Loss: 0.0631, Accuracy: 96.88%
# Epoch [20/20], Loss: 0.0115, Validation Accuracy: 96.43%
# Epoch [20/20], Step [500/1188], Loss: 0.0005, Accuracy: 100.00%
# Epoch [20/20], Loss: 0.3117, Validation Accuracy: 96.59%
# Epoch [20/20], Step [600/1188], Loss: 0.0009, Accuracy: 100.00%
# Epoch [20/20], Loss: 0.4224, Validation Accuracy: 95.99%
# Epoch [20/20], Step [700/1188], Loss: 0.0234, Accuracy: 96.88%
# Epoch [20/20], Loss: 0.1156, Validation Accuracy: 96.04%
# Epoch [20/20], Step [800/1188], Loss: 0.0001, Accuracy: 100.00%
# Epoch [20/20], Loss: 0.0887, Validation Accuracy: 96.76%
# Epoch [20/20], Step [900/1188], Loss: 0.1262, Accuracy: 96.88%
# Epoch [20/20], Loss: 0.0039, Validation Accuracy: 96.41%
# Epoch [20/20], Step [1000/1188], Loss: 0.0005, Accuracy: 100.00%
# Epoch [20/20], Loss: 0.0901, Validation Accuracy: 96.24%
# Epoch [20/20], Step [1100/1188], Loss: 0.0016, Accuracy: 100.00%
# Epoch [20/20], Loss: 0.9265, Validation Accuracy: 96.11%
# ######## Training Finished in 6393.67444729805 seconds ###########

# %%
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('steps')
    plt.plot(accuracy_train, label="Train Accuracy")
    plt.plot(accuracy_validation, label="Validation Accuracy")
    plt.legend(loc="lower right")
    plt.show()

# %%
    plt.title('model Loss')
    plt.ylabel('loss')
    plt.xlabel('steps')
    plt.plot(loss_train, label="Train Loss")
    plt.plot(loss_validation, label="Validation Loss")
    plt.legend(loc="lower left")
    plt.show()
