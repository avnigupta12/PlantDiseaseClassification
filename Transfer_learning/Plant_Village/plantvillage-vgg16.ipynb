# %%
import os                       # for working with files
import numpy as np              # for numerical computationss
import pandas as pd             # for working with dataframes
import torch                    # Pytorch module 
import matplotlib.pyplot as plt # for plotting informations on graph and images using tensors
import torch.nn as nn           # for creating  neural networks
from torch.utils.data import DataLoader, random_split # for dataloaders 
from PIL import Image           # for checking images
import torch.nn.functional as F # for functions for calculating loss
from torchvision import models
import torchvision.transforms as transforms   # for transforming images into tensors 
from torchvision.utils import make_grid       # for data checking
import torchvision
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader, random_split
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
from torch.optim import lr_scheduler
from torchvision import datasets, models, transforms
from torchvision.datasets import ImageFolder  # for working with classes and images
from tqdm import tqdm
import time
from torchvision.io import read_image

# %%
data_dir = "../input/original-dataset/Original dataset"
diseases = os.listdir(data_dir)

# %%
# printing the disease names
print(diseases)
print("Total disease classes are: {}".format(len(diseases)))
# Out:
# ['Tomato___Late_blight', 'Tomato___healthy', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Potato___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Early_blight', 'Tomato___Septoria_leaf_spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Strawberry___Leaf_scorch', 'Peach___healthy', 'Apple___Apple_scab', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Bacterial_spot', 'Apple___Black_rot', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Peach___Bacterial_spot', 'Apple___Cedar_apple_rust', 'Tomato___Target_Spot', 'Pepper,_bell___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Potato___Late_blight', 'Tomato___Tomato_mosaic_virus', 'Strawberry___healthy', 'Apple___healthy', 'Grape___Black_rot', 'Potato___Early_blight', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Common_rust_', 'Grape___Esca_(Black_Measles)', 'Raspberry___healthy', 'Tomato___Leaf_Mold', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___healthy']
# Total disease classes are: 38

# %%
plants = []
NumberOfDiseases = 0
for plant in diseases:
    if plant.split('_')[0] not in plants:
        plants.append(plant.split('_')[0])
    if plant.split('_')[1] != 'healthy':
        NumberOfDiseases += 1

# %%
# Unique plants in the dataset
print("Number of plants: {}".format(len(plants)))
print(f"Unique Plants are: ")
for idx, plant in enumerate(plants):
  print(str(idx + 1) + '. ' + plant)
# Out:
# Number of plants: 14
# Unique Plants are:
# 1. Tomato
# 2. Grape
# 3. Orange
# 4. Soybean
# 5. Squash
# 6. Potato
# 7. Corn
# 8. Strawberry
# 9. Peach
# 10. Apple
# 11. Blueberry
# 12. Cherry
# 13. Pepper,
# 14. Raspberry

# %%
# number of unique diseases
print("Total number of diseases: {}".format(NumberOfDiseases))
# Out:
# Total number of diseases: 38

# %%
# Number of images for each disease
disease_class_size = {}
for disease in diseases:
    disease_class_size[disease] = len(os.listdir(data_dir + '/' + disease))

img_per_class = pd.DataFrame(disease_class_size.values(), index=disease_class_size.keys(), columns=["no. of images"])

# %%
# plotting number of images available for each disease
index = [n for n in range(38)]
plt.figure(figsize=(20, 5))
plt.bar(index, [n for n in disease_class_size.values()], width=0.3)
plt.xlabel('Plants/Diseases', fontsize=10)
plt.ylabel('No of images available', fontsize=10)
plt.xticks(index, diseases, fontsize=5, rotation=90)
plt.title('Images per each class of plant disease')
# Out:
# Text(0.5, 1.0, 'Images per each class of plant disease')

# %%
## Split Train, Test and Validation ##

def get_files_from_folder(path):
    files = os.listdir(path)
    return np.asarray(files)

get_files_from_folder(data_dir)

def load_data(path, validation_split, test_split, batch_size):
    transform_dict = {
        "src": transforms.Compose([
            transforms.RandomResizedCrop(224),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.225, 0.225, 0.225])
        ])
    }
    
    dataset = ImageFolder(root=path, transform=transform_dict["src"])
    
    dataset_size = len(dataset)
    validation_size = int(validation_split * dataset_size)
    test_size = int(test_split * dataset_size)
    train_size = dataset_size - (test_size + validation_size)

    # TODO: Split classes into equal sizes?!
    train_dataset, validation_dataset, test_dataset = random_split(dataset, [train_size, validation_size, test_size])
    
    return train_dataset, validation_dataset, test_dataset

# %%
train_dataset, validation_dataset, test_dataset = load_data(data_dir, 0.1, 0.2, 200)

# %%
img, label = train_dataset[0]
print(img.shape, label)
# Out:
# torch.Size([3, 224, 224]) 24

# %%
# for checking some images from training dataset
def show_image(image, label):
    # print("Label :" + train_dataset.classes[label] + "(" + str(label) + ")")
    plt.imshow(image.permute(1, 2, 0))

# %%
show_image(*train_dataset[21])

# %%
# setting the batch size
batch_size = 32

# Load data to DataLoaders for training, validation and test
train_dataloader = DataLoader(train_dataset, batch_size, shuffle=True, num_workers=2, pin_memory=True)
validation_dataloader = DataLoader(validation_dataset, batch_size, num_workers=2, pin_memory=True)
test_dataloader = DataLoader(test_dataset, batch_size, num_workers=2, pin_memory=True)

# %%
# helper function to show a batch of training instances
def show_batch(data):
    for images, labels in data:
        fig, ax = plt.subplots(figsize=(30, 30))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images, nrow=8).permute(1, 2, 0))
        break

# %%
show_batch(train_dataloader)

# %%
# for calculating the accuracy
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))


# base class for the model
class ImageClassificationBase(nn.Module):
    
    def training_step(self, batch):
        images, labels = batch
        out = self(images)                  # Generate predictions
        loss = F.cross_entropy(out, labels) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        images, labels = batch
        out = self(images)                   # Generate prediction
        loss = F.cross_entropy(out, labels)  # Calculate loss
        acc = accuracy(out, labels)          # Calculate accuracy
        return {"val_loss": loss.detach(), "val_accuracy": acc}
    
    def validation_epoch_end(self, outputs):
        batch_losses = [x["val_loss"] for x in outputs]
        batch_accuracy = [x["val_accuracy"] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()       # Combine loss  
        epoch_accuracy = torch.stack(batch_accuracy).mean()
        return {"val_loss": epoch_loss, "val_accuracy": epoch_accuracy} # Combine accuracies
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], last_lr: {:.5f}, train_loss: {:.4f}, val_loss: {:.4f}, val_acc: {:.4f}".format(
            epoch, result['lrs'][-1], result['train_loss'], result['val_loss'], result['val_accuracy']))

# %%
model_vgg16 = models.vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
for param in model_vgg16.parameters():
    param.requires_grad = False

num_ftrs = model_vgg16.classifier[6].in_features
model_vgg16.classifier[6] = nn.Linear(num_ftrs, out_features=len(train_dataset.dataset.classes))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Device: {}".format(device))
model_vgg16.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_vgg16.classifier[6].parameters(), lr=0.001)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)
# Out:
# Device: cuda:0

# %%
accuracy_validation = []
accuracy_train = []
loss_validation = []
loss_train = []

num_epochs = 20
total_steps = len(train_dataloader)
t1 = time.time()

for epoch in range(num_epochs):
    for i, data in enumerate(train_dataloader):
        images, labels = data[0].to(device), data[1].to(device)
        # Forward pass
        outputs = model_vgg16(images)
        loss = criterion(outputs, labels)
        # Backprop and optimisation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # Train accuracy
        total = labels.size(0)
        _,predicted = torch.max(outputs.data, 1)
        correct = (predicted == labels).sum().item()
        if (i + 1) % 100 == 0:
            accuracy = ((correct / total) * 100)
            accuracy_train.append(accuracy)
            loss_train.append(loss.item())
            
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}, Accuracy: {:.2f}%'
                .format(epoch + 1, num_epochs, i + 1, total_steps, loss.item(), accuracy))
            
            model_vgg16.eval()
            with torch.no_grad():
                correct_validation_labels = 0
                total_validation_labels = 0

                for validation_data in validation_dataloader:
                    validation_images, validation_labels = validation_data[0].to(device), validation_data[1].to(device)
                    predicted_outputs = model_vgg16(validation_images)

                    _, validation_prediction = torch.max(predicted_outputs.data, 1)
                    total_validation_labels += validation_labels.size(0)
                    correct_validation_labels += (validation_prediction == validation_labels).sum().item()
                # print("Correct-> ", correct_validation_labels)
                # print("Total-> ", total_validation_labels)
                # print(correct_validation_labels/total_validation_labels)
                val_loss = criterion(predicted_outputs, validation_labels)
                
                val_accuracy = ((correct_validation_labels / total_validation_labels) * 100)
                
                accuracy_validation.append(val_accuracy)
                loss_validation.append(val_loss.item())
            
                print('Epoch [{}/{}], Loss: {:.4f}, Validation Accuracy: {:.2f}%'
                      .format(epoch + 1, num_epochs, val_loss.item(), val_accuracy))
     
print("######## Training Finished in {} seconds ###########".format(time.time()-t1))
# Out:
# Epoch [1/20], Step [100/1188], Loss: 1.4816, Accuracy: 62.50%
# Epoch [1/20], Loss: 0.7944, Validation Accuracy: 69.52%
# Epoch [1/20], Step [200/1188], Loss: 1.1979, Accuracy: 59.38%
# Epoch [1/20], Loss: 0.9395, Validation Accuracy: 73.76%
# Epoch [1/20], Step [300/1188], Loss: 0.7397, Accuracy: 75.00%
# Epoch [1/20], Loss: 0.6823, Validation Accuracy: 77.64%
# Epoch [1/20], Step [400/1188], Loss: 0.8603, Accuracy: 75.00%
# Epoch [1/20], Loss: 0.6203, Validation Accuracy: 79.19%
# Epoch [1/20], Step [500/1188], Loss: 0.3795, Accuracy: 90.62%
# Epoch [1/20], Loss: 0.4966, Validation Accuracy: 80.55%
# Epoch [1/20], Step [600/1188], Loss: 0.5175, Accuracy: 87.50%
# Epoch [1/20], Loss: 0.4007, Validation Accuracy: 81.77%
# Epoch [1/20], Step [700/1188], Loss: 0.4957, Accuracy: 84.38%
# Epoch [1/20], Loss: 0.5173, Validation Accuracy: 80.83%
# Epoch [1/20], Step [800/1188], Loss: 0.6408, Accuracy: 84.38%
# Epoch [1/20], Loss: 0.1813, Validation Accuracy: 81.40%
# Epoch [1/20], Step [900/1188], Loss: 0.5734, Accuracy: 81.25%
# Epoch [1/20], Loss: 0.5377, Validation Accuracy: 83.33%
# Epoch [1/20], Step [1000/1188], Loss: 0.5029, Accuracy: 84.38%
# Epoch [1/20], Loss: 0.6149, Validation Accuracy: 83.66%
# Epoch [1/20], Step [1100/1188], Loss: 0.6425, Accuracy: 81.25%
# Epoch [1/20], Loss: 0.3916, Validation Accuracy: 84.20%
# Epoch [2/20], Step [100/1188], Loss: 0.7721, Accuracy: 71.88%
# Epoch [2/20], Loss: 0.1425, Validation Accuracy: 83.89%
# Epoch [2/20], Step [200/1188], Loss: 0.5396, Accuracy: 87.50%
# Epoch [2/20], Loss: 0.3255, Validation Accuracy: 84.90%
# Epoch [2/20], Step [300/1188], Loss: 0.5802, Accuracy: 81.25%
# Epoch [2/20], Loss: 0.2525, Validation Accuracy: 85.56%
# Epoch [2/20], Step [400/1188], Loss: 0.3766, Accuracy: 81.25%
# Epoch [2/20], Loss: 0.4867, Validation Accuracy: 84.94%
# Epoch [2/20], Step [500/1188], Loss: 0.1786, Accuracy: 96.88%
# Epoch [2/20], Loss: 0.4381, Validation Accuracy: 84.42%
# Epoch [2/20], Step [600/1188], Loss: 0.7366, Accuracy: 81.25%
# Epoch [2/20], Loss: 0.4732, Validation Accuracy: 84.29%
# Epoch [2/20], Step [700/1188], Loss: 0.4882, Accuracy: 84.38%
# Epoch [2/20], Loss: 0.5433, Validation Accuracy: 86.10%
# Epoch [2/20], Step [800/1188], Loss: 0.9605, Accuracy: 71.88%
# Epoch [2/20], Loss: 0.4239, Validation Accuracy: 85.01%
# Epoch [2/20], Step [900/1188], Loss: 0.4411, Accuracy: 81.25%
# Epoch [2/20], Loss: 0.3555, Validation Accuracy: 85.34%
# Epoch [2/20], Step [1000/1188], Loss: 0.4041, Accuracy: 90.62%
# Epoch [2/20], Loss: 0.3285, Validation Accuracy: 87.15%
# Epoch [2/20], Step [1100/1188], Loss: 0.3807, Accuracy: 84.38%
# Epoch [2/20], Loss: 0.2545, Validation Accuracy: 87.26%
# Epoch [3/20], Step [100/1188], Loss: 0.6111, Accuracy: 81.25%
# Epoch [3/20], Loss: 0.4587, Validation Accuracy: 86.74%
# Epoch [3/20], Step [200/1188], Loss: 0.6518, Accuracy: 78.12%
# Epoch [3/20], Loss: 0.3326, Validation Accuracy: 85.71%
# Epoch [3/20], Step [300/1188], Loss: 0.3979, Accuracy: 84.38%
# Epoch [3/20], Loss: 0.4827, Validation Accuracy: 87.26%
# Epoch [3/20], Step [400/1188], Loss: 0.2599, Accuracy: 90.62%
# Epoch [3/20], Loss: 0.1393, Validation Accuracy: 85.84%
# Epoch [3/20], Step [500/1188], Loss: 0.4849, Accuracy: 87.50%
# Epoch [3/20], Loss: 0.2982, Validation Accuracy: 86.50%
# Epoch [3/20], Step [600/1188], Loss: 0.2369, Accuracy: 93.75%
# Epoch [3/20], Loss: 0.1724, Validation Accuracy: 87.07%
# Epoch [3/20], Step [700/1188], Loss: 0.5925, Accuracy: 78.12%
# Epoch [3/20], Loss: 0.2557, Validation Accuracy: 86.43%
# Epoch [3/20], Step [800/1188], Loss: 0.5199, Accuracy: 87.50%
# Epoch [3/20], Loss: 0.5392, Validation Accuracy: 87.03%
# Epoch [3/20], Step [900/1188], Loss: 0.3010, Accuracy: 84.38%
# Epoch [3/20], Loss: 0.8351, Validation Accuracy: 86.48%
# Epoch [3/20], Step [1000/1188], Loss: 0.4062, Accuracy: 87.50%
# Epoch [3/20], Loss: 0.2609, Validation Accuracy: 86.83%
# Epoch [3/20], Step [1100/1188], Loss: 0.2961, Accuracy: 93.75%
# Epoch [3/20], Loss: 0.1312, Validation Accuracy: 87.18%
# Epoch [4/20], Step [100/1188], Loss: 0.1478, Accuracy: 93.75%
# Epoch [4/20], Loss: 0.4120, Validation Accuracy: 87.29%
# Epoch [4/20], Step [200/1188], Loss: 0.3196, Accuracy: 90.62%
# Epoch [4/20], Loss: 0.3092, Validation Accuracy: 86.91%
# Epoch [4/20], Step [300/1188], Loss: 0.8834, Accuracy: 71.88%
# Epoch [4/20], Loss: 0.3935, Validation Accuracy: 87.42%
# Epoch [4/20], Step [400/1188], Loss: 0.6121, Accuracy: 84.38%
# Epoch [4/20], Loss: 0.1546, Validation Accuracy: 87.44%
# Epoch [4/20], Step [500/1188], Loss: 0.3038, Accuracy: 87.50%
# Epoch [4/20], Loss: 0.1564, Validation Accuracy: 87.70%
# Epoch [4/20], Step [600/1188], Loss: 0.1703, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.1274, Validation Accuracy: 87.09%
# Epoch [4/20], Step [700/1188], Loss: 0.0954, Accuracy: 96.88%
# Epoch [4/20], Loss: 0.2242, Validation Accuracy: 87.13%
# Epoch [4/20], Step [800/1188], Loss: 0.4355, Accuracy: 87.50%
# Epoch [4/20], Loss: 0.3162, Validation Accuracy: 88.16%
# Epoch [4/20], Step [900/1188], Loss: 0.3724, Accuracy: 90.62%
# Epoch [4/20], Loss: 0.2218, Validation Accuracy: 86.37%
# Epoch [4/20], Step [1000/1188], Loss: 0.3680, Accuracy: 87.50%
# Epoch [4/20], Loss: 0.2638, Validation Accuracy: 88.10%
# Epoch [4/20], Step [1100/1188], Loss: 0.2320, Accuracy: 90.62%
# Epoch [4/20], Loss: 0.4864, Validation Accuracy: 86.72%
# Epoch [5/20], Step [100/1188], Loss: 0.1283, Accuracy: 93.75%
# Epoch [5/20], Loss: 0.1772, Validation Accuracy: 86.85%
# Epoch [5/20], Step [200/1188], Loss: 0.3629, Accuracy: 87.50%
# Epoch [5/20], Loss: 0.3090, Validation Accuracy: 86.69%
# Epoch [5/20], Step [300/1188], Loss: 0.2316, Accuracy: 93.75%
# Epoch [5/20], Loss: 0.4882, Validation Accuracy: 87.48%
# Epoch [5/20], Step [400/1188], Loss: 0.3073, Accuracy: 84.38%
# Epoch [5/20], Loss: 0.3945, Validation Accuracy: 87.79%
# Epoch [5/20], Step [500/1188], Loss: 0.3611, Accuracy: 87.50%
# Epoch [5/20], Loss: 0.3232, Validation Accuracy: 87.86%
# Epoch [5/20], Step [600/1188], Loss: 0.4560, Accuracy: 87.50%
# Epoch [5/20], Loss: 0.5411, Validation Accuracy: 89.30%
# Epoch [5/20], Step [700/1188], Loss: 0.2854, Accuracy: 93.75%
# Epoch [5/20], Loss: 0.2513, Validation Accuracy: 87.68%
# Epoch [5/20], Step [800/1188], Loss: 0.3550, Accuracy: 87.50%
# Epoch [5/20], Loss: 0.4073, Validation Accuracy: 87.07%
# Epoch [5/20], Step [900/1188], Loss: 0.1731, Accuracy: 93.75%
# Epoch [5/20], Loss: 0.1068, Validation Accuracy: 88.16%
# Epoch [5/20], Step [1000/1188], Loss: 0.5879, Accuracy: 81.25%
# Epoch [5/20], Loss: 0.2966, Validation Accuracy: 87.97%
# Epoch [5/20], Step [1100/1188], Loss: 0.3523, Accuracy: 84.38%
# Epoch [5/20], Loss: 0.2887, Validation Accuracy: 87.37%
# Epoch [6/20], Step [100/1188], Loss: 0.1886, Accuracy: 96.88%
# Epoch [6/20], Loss: 0.2615, Validation Accuracy: 88.38%
# Epoch [6/20], Step [200/1188], Loss: 0.4599, Accuracy: 87.50%
# Epoch [6/20], Loss: 0.1215, Validation Accuracy: 89.21%
# Epoch [6/20], Step [300/1188], Loss: 0.2221, Accuracy: 90.62%
# Epoch [6/20], Loss: 0.5674, Validation Accuracy: 88.23%
# Epoch [6/20], Step [400/1188], Loss: 0.2099, Accuracy: 96.88%
# Epoch [6/20], Loss: 0.1225, Validation Accuracy: 88.71%
# Epoch [6/20], Step [500/1188], Loss: 0.2373, Accuracy: 90.62%
# Epoch [6/20], Loss: 0.4068, Validation Accuracy: 88.20%
# Epoch [6/20], Step [600/1188], Loss: 0.1939, Accuracy: 96.88%
# Epoch [6/20], Loss: 0.5033, Validation Accuracy: 87.73%
# Epoch [6/20], Step [700/1188], Loss: 0.7421, Accuracy: 84.38%
# Epoch [6/20], Loss: 0.4523, Validation Accuracy: 89.12%
# Epoch [6/20], Step [800/1188], Loss: 0.3435, Accuracy: 81.25%
# Epoch [6/20], Loss: 0.2235, Validation Accuracy: 88.73%
# Epoch [6/20], Step [900/1188], Loss: 0.5239, Accuracy: 78.12%
# Epoch [6/20], Loss: 0.2797, Validation Accuracy: 87.55%
# Epoch [6/20], Step [1000/1188], Loss: 0.3138, Accuracy: 84.38%
# Epoch [6/20], Loss: 0.1050, Validation Accuracy: 88.80%
# Epoch [6/20], Step [1100/1188], Loss: 0.8063, Accuracy: 75.00%
# Epoch [6/20], Loss: 0.1254, Validation Accuracy: 88.05%
# Epoch [7/20], Step [100/1188], Loss: 0.5583, Accuracy: 78.12%
# Epoch [7/20], Loss: 0.4456, Validation Accuracy: 88.32%
# Epoch [7/20], Step [200/1188], Loss: 0.5161, Accuracy: 84.38%
# Epoch [7/20], Loss: 0.1298, Validation Accuracy: 88.69%
# Epoch [7/20], Step [300/1188], Loss: 0.1575, Accuracy: 93.75%
# Epoch [7/20], Loss: 0.2966, Validation Accuracy: 88.27%
# Epoch [7/20], Step [400/1188], Loss: 0.1704, Accuracy: 93.75%
# Epoch [7/20], Loss: 0.1654, Validation Accuracy: 88.16%
# Epoch [7/20], Step [500/1188], Loss: 0.5317, Accuracy: 84.38%
# Epoch [7/20], Loss: 0.1697, Validation Accuracy: 88.36%
# Epoch [7/20], Step [600/1188], Loss: 0.8342, Accuracy: 78.12%
# Epoch [7/20], Loss: 0.3197, Validation Accuracy: 87.72%
# Epoch [7/20], Step [700/1188], Loss: 0.2396, Accuracy: 96.88%
# Epoch [7/20], Loss: 0.1993, Validation Accuracy: 87.88%
# Epoch [7/20], Step [800/1188], Loss: 0.4197, Accuracy: 90.62%
# Epoch [7/20], Loss: 0.1292, Validation Accuracy: 89.02%
# Epoch [7/20], Step [900/1188], Loss: 0.3426, Accuracy: 87.50%
# Epoch [7/20], Loss: 0.1116, Validation Accuracy: 89.02%
# Epoch [7/20], Step [1000/1188], Loss: 0.4424, Accuracy: 84.38%
# Epoch [7/20], Loss: 0.2118, Validation Accuracy: 89.74%
# Epoch [7/20], Step [1100/1188], Loss: 0.2840, Accuracy: 87.50%
# Epoch [7/20], Loss: 0.3024, Validation Accuracy: 88.23%
# Epoch [8/20], Step [100/1188], Loss: 0.2990, Accuracy: 93.75%
# Epoch [8/20], Loss: 0.0843, Validation Accuracy: 88.97%
# Epoch [8/20], Step [200/1188], Loss: 0.1326, Accuracy: 93.75%
# Epoch [8/20], Loss: 0.6857, Validation Accuracy: 88.14%
# Epoch [8/20], Step [300/1188], Loss: 0.3567, Accuracy: 87.50%
# Epoch [8/20], Loss: 0.2028, Validation Accuracy: 89.15%
# Epoch [8/20], Step [400/1188], Loss: 0.3230, Accuracy: 93.75%
# Epoch [8/20], Loss: 0.1055, Validation Accuracy: 88.64%
# Epoch [8/20], Step [500/1188], Loss: 0.7013, Accuracy: 81.25%
# Epoch [8/20], Loss: 0.7393, Validation Accuracy: 87.77%
# Epoch [8/20], Step [600/1188], Loss: 0.3614, Accuracy: 81.25%
# Epoch [8/20], Loss: 0.1363, Validation Accuracy: 88.84%
# Epoch [8/20], Step [700/1188], Loss: 0.0815, Accuracy: 100.00%
# Epoch [8/20], Loss: 0.5671, Validation Accuracy: 87.88%
# Epoch [8/20], Step [800/1188], Loss: 0.3196, Accuracy: 96.88%
# Epoch [8/20], Loss: 0.3116, Validation Accuracy: 88.93%
# Epoch [8/20], Step [900/1188], Loss: 0.3952, Accuracy: 87.50%
# Epoch [8/20], Loss: 0.0821, Validation Accuracy: 88.80%
# Epoch [8/20], Step [1000/1188], Loss: 0.2137, Accuracy: 87.50%
# Epoch [8/20], Loss: 0.2509, Validation Accuracy: 89.08%
# Epoch [8/20], Step [1100/1188], Loss: 0.2106, Accuracy: 90.62%
# Epoch [8/20], Loss: 0.3174, Validation Accuracy: 89.58%
# Epoch [9/20], Step [100/1188], Loss: 0.3637, Accuracy: 81.25%
# Epoch [9/20], Loss: 0.3814, Validation Accuracy: 88.49%
# Epoch [9/20], Step [200/1188], Loss: 0.2384, Accuracy: 90.62%
# Epoch [9/20], Loss: 0.4146, Validation Accuracy: 88.69%
# Epoch [9/20], Step [300/1188], Loss: 0.1948, Accuracy: 90.62%
# Epoch [9/20], Loss: 0.2694, Validation Accuracy: 90.11%
# Epoch [9/20], Step [400/1188], Loss: 0.1690, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.2156, Validation Accuracy: 88.49%
# Epoch [9/20], Step [500/1188], Loss: 0.1446, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.2751, Validation Accuracy: 88.60%
# Epoch [9/20], Step [600/1188], Loss: 0.3774, Accuracy: 90.62%
# Epoch [9/20], Loss: 0.4752, Validation Accuracy: 88.62%
# Epoch [9/20], Step [700/1188], Loss: 0.5804, Accuracy: 84.38%
# Epoch [9/20], Loss: 0.4719, Validation Accuracy: 89.13%
# Epoch [9/20], Step [800/1188], Loss: 0.2208, Accuracy: 93.75%
# Epoch [9/20], Loss: 0.0893, Validation Accuracy: 88.27%
# Epoch [9/20], Step [900/1188], Loss: 0.3933, Accuracy: 81.25%
# Epoch [9/20], Loss: 0.0727, Validation Accuracy: 89.37%
# Epoch [9/20], Step [1000/1188], Loss: 0.1794, Accuracy: 96.88%
# Epoch [9/20], Loss: 0.3837, Validation Accuracy: 88.80%
# Epoch [9/20], Step [1100/1188], Loss: 0.4632, Accuracy: 87.50%
# Epoch [9/20], Loss: 0.3349, Validation Accuracy: 88.80%
# Epoch [10/20], Step [100/1188], Loss: 0.0818, Accuracy: 96.88%
# Epoch [10/20], Loss: 0.0591, Validation Accuracy: 89.45%
# Epoch [10/20], Step [200/1188], Loss: 0.3998, Accuracy: 90.62%
# Epoch [10/20], Loss: 0.4324, Validation Accuracy: 89.67%
# Epoch [10/20], Step [300/1188], Loss: 0.2286, Accuracy: 87.50%
# Epoch [10/20], Loss: 0.0867, Validation Accuracy: 88.55%
# Epoch [10/20], Step [400/1188], Loss: 0.1607, Accuracy: 96.88%
# Epoch [10/20], Loss: 0.2496, Validation Accuracy: 89.02%
# Epoch [10/20], Step [500/1188], Loss: 0.4325, Accuracy: 87.50%
# Epoch [10/20], Loss: 0.2262, Validation Accuracy: 88.42%
# Epoch [10/20], Step [600/1188], Loss: 0.2149, Accuracy: 93.75%
# Epoch [10/20], Loss: 0.2453, Validation Accuracy: 89.30%
# Epoch [10/20], Step [700/1188], Loss: 0.1368, Accuracy: 96.88%
# Epoch [10/20], Loss: 0.4962, Validation Accuracy: 89.54%
# Epoch [10/20], Step [800/1188], Loss: 0.2147, Accuracy: 90.62%
# Epoch [10/20], Loss: 0.5054, Validation Accuracy: 89.23%
# Epoch [10/20], Step [900/1188], Loss: 0.1482, Accuracy: 96.88%
# Epoch [10/20], Loss: 0.1418, Validation Accuracy: 89.28%
# Epoch [10/20], Step [1000/1188], Loss: 0.4148, Accuracy: 81.25%
# Epoch [10/20], Loss: 0.2806, Validation Accuracy: 89.36%
# Epoch [10/20], Step [1100/1188], Loss: 0.4489, Accuracy: 87.50%
# Epoch [10/20], Loss: 0.2517, Validation Accuracy: 89.45%
# Epoch [11/20], Step [100/1188], Loss: 0.3966, Accuracy: 90.62%
# Epoch [11/20], Loss: 0.0982, Validation Accuracy: 89.19%
# Epoch [11/20], Step [200/1188], Loss: 0.6228, Accuracy: 78.12%
# Epoch [11/20], Loss: 0.4585, Validation Accuracy: 89.58%
# Epoch [11/20], Step [300/1188], Loss: 0.3019, Accuracy: 87.50%
# Epoch [11/20], Loss: 0.5063, Validation Accuracy: 88.93%
# Epoch [11/20], Step [400/1188], Loss: 0.2865, Accuracy: 93.75%
# Epoch [11/20], Loss: 0.0798, Validation Accuracy: 89.19%
# Epoch [11/20], Step [500/1188], Loss: 0.2123, Accuracy: 93.75%
# Epoch [11/20], Loss: 0.1178, Validation Accuracy: 89.08%
# Epoch [11/20], Step [600/1188], Loss: 0.2245, Accuracy: 93.75%
# Epoch [11/20], Loss: 0.1591, Validation Accuracy: 88.38%
# Epoch [11/20], Step [700/1188], Loss: 0.1923, Accuracy: 90.62%
# Epoch [11/20], Loss: 0.0784, Validation Accuracy: 89.94%
# Epoch [11/20], Step [800/1188], Loss: 0.5082, Accuracy: 90.62%
# Epoch [11/20], Loss: 0.2802, Validation Accuracy: 89.52%
# Epoch [11/20], Step [900/1188], Loss: 0.1652, Accuracy: 93.75%
# Epoch [11/20], Loss: 0.1454, Validation Accuracy: 88.40%
# Epoch [11/20], Step [1000/1188], Loss: 0.9728, Accuracy: 71.88%
# Epoch [11/20], Loss: 0.4067, Validation Accuracy: 89.82%
# Epoch [11/20], Step [1100/1188], Loss: 0.2603, Accuracy: 90.62%
# Epoch [11/20], Loss: 0.3826, Validation Accuracy: 90.37%
# Epoch [12/20], Step [100/1188], Loss: 0.2618, Accuracy: 90.62%
# Epoch [12/20], Loss: 0.5992, Validation Accuracy: 89.61%
# Epoch [12/20], Step [200/1188], Loss: 0.1757, Accuracy: 93.75%
# Epoch [12/20], Loss: 0.6548, Validation Accuracy: 88.40%
# Epoch [12/20], Step [300/1188], Loss: 0.3118, Accuracy: 90.62%
# Epoch [12/20], Loss: 0.1778, Validation Accuracy: 88.21%
# Epoch [12/20], Step [400/1188], Loss: 0.3337, Accuracy: 84.38%
# Epoch [12/20], Loss: 0.2629, Validation Accuracy: 88.66%
# Epoch [12/20], Step [500/1188], Loss: 0.3566, Accuracy: 87.50%
# Epoch [12/20], Loss: 0.2912, Validation Accuracy: 88.88%
# Epoch [12/20], Step [600/1188], Loss: 0.4450, Accuracy: 81.25%
# Epoch [12/20], Loss: 0.6973, Validation Accuracy: 88.77%
# Epoch [12/20], Step [700/1188], Loss: 0.8026, Accuracy: 81.25%
# Epoch [12/20], Loss: 0.2169, Validation Accuracy: 89.89%
# Epoch [12/20], Step [800/1188], Loss: 0.2797, Accuracy: 93.75%
# Epoch [12/20], Loss: 0.2391, Validation Accuracy: 88.69%
# Epoch [12/20], Step [900/1188], Loss: 0.1594, Accuracy: 96.88%
# Epoch [12/20], Loss: 0.3311, Validation Accuracy: 89.21%
# Epoch [12/20], Step [1000/1188], Loss: 0.9549, Accuracy: 78.12%
# Epoch [12/20], Loss: 0.5722, Validation Accuracy: 88.60%
# Epoch [12/20], Step [1100/1188], Loss: 0.2330, Accuracy: 87.50%
# Epoch [12/20], Loss: 0.2046, Validation Accuracy: 88.40%
# Epoch [13/20], Step [100/1188], Loss: 0.3180, Accuracy: 87.50%
# Epoch [13/20], Loss: 0.3216, Validation Accuracy: 90.06%
# Epoch [13/20], Step [200/1188], Loss: 0.2985, Accuracy: 87.50%
# Epoch [13/20], Loss: 0.3229, Validation Accuracy: 89.80%
# Epoch [13/20], Step [300/1188], Loss: 0.3742, Accuracy: 81.25%
# Epoch [13/20], Loss: 0.1518, Validation Accuracy: 89.87%
# Epoch [13/20], Step [400/1188], Loss: 0.1456, Accuracy: 96.88%
# Epoch [13/20], Loss: 0.0912, Validation Accuracy: 88.91%
# Epoch [13/20], Step [500/1188], Loss: 0.2578, Accuracy: 90.62%
# Epoch [13/20], Loss: 0.5310, Validation Accuracy: 89.36%
# Epoch [13/20], Step [600/1188], Loss: 0.1161, Accuracy: 96.88%
# Epoch [13/20], Loss: 0.0538, Validation Accuracy: 89.12%
# Epoch [13/20], Step [700/1188], Loss: 0.3880, Accuracy: 87.50%
# Epoch [13/20], Loss: 0.4215, Validation Accuracy: 89.23%
# Epoch [13/20], Step [800/1188], Loss: 0.3083, Accuracy: 84.38%
# Epoch [13/20], Loss: 0.3098, Validation Accuracy: 89.36%
# Epoch [13/20], Step [900/1188], Loss: 0.2525, Accuracy: 87.50%
# Epoch [13/20], Loss: 0.3542, Validation Accuracy: 88.12%
# Epoch [13/20], Step [1000/1188], Loss: 0.2773, Accuracy: 90.62%
# Epoch [13/20], Loss: 0.2556, Validation Accuracy: 87.83%
# Epoch [13/20], Step [1100/1188], Loss: 0.3756, Accuracy: 90.62%
# Epoch [13/20], Loss: 0.1583, Validation Accuracy: 90.41%
# Epoch [14/20], Step [100/1188], Loss: 0.4030, Accuracy: 90.62%
# Epoch [14/20], Loss: 0.0932, Validation Accuracy: 89.72%
# Epoch [14/20], Step [200/1188], Loss: 0.2293, Accuracy: 90.62%
# Epoch [14/20], Loss: 0.2173, Validation Accuracy: 89.19%
# Epoch [14/20], Step [300/1188], Loss: 0.1437, Accuracy: 96.88%
# Epoch [14/20], Loss: 0.3139, Validation Accuracy: 88.49%
# Epoch [14/20], Step [400/1188], Loss: 0.0373, Accuracy: 100.00%
# Epoch [14/20], Loss: 0.2191, Validation Accuracy: 89.36%
# Epoch [14/20], Step [500/1188], Loss: 0.2702, Accuracy: 90.62%
# Epoch [14/20], Loss: 0.1405, Validation Accuracy: 89.43%
# Epoch [14/20], Step [600/1188], Loss: 0.2043, Accuracy: 93.75%
# Epoch [14/20], Loss: 0.1400, Validation Accuracy: 89.65%
# Epoch [14/20], Step [700/1188], Loss: 0.1269, Accuracy: 90.62%
# Epoch [14/20], Loss: 0.1028, Validation Accuracy: 89.06%
# Epoch [14/20], Step [800/1188], Loss: 0.6097, Accuracy: 84.38%
# Epoch [14/20], Loss: 0.0948, Validation Accuracy: 88.95%
# Epoch [14/20], Step [900/1188], Loss: 0.3320, Accuracy: 84.38%
# Epoch [14/20], Loss: 0.1910, Validation Accuracy: 90.17%
# Epoch [14/20], Step [1000/1188], Loss: 0.2574, Accuracy: 93.75%
# Epoch [14/20], Loss: 0.1505, Validation Accuracy: 90.52%
# Epoch [14/20], Step [1100/1188], Loss: 0.2825, Accuracy: 90.62%
# Epoch [14/20], Loss: 0.3525, Validation Accuracy: 88.84%
# Epoch [15/20], Step [100/1188], Loss: 0.2695, Accuracy: 84.38%
# Epoch [15/20], Loss: 0.1370, Validation Accuracy: 89.10%
# Epoch [15/20], Step [200/1188], Loss: 0.6151, Accuracy: 75.00%
# Epoch [15/20], Loss: 0.3342, Validation Accuracy: 89.17%
# Epoch [15/20], Step [300/1188], Loss: 0.2781, Accuracy: 90.62%
# Epoch [15/20], Loss: 0.3564, Validation Accuracy: 90.20%
# Epoch [15/20], Step [400/1188], Loss: 0.3530, Accuracy: 96.88%
# Epoch [15/20], Loss: 0.1409, Validation Accuracy: 89.72%
# Epoch [15/20], Step [500/1188], Loss: 0.3967, Accuracy: 87.50%
# Epoch [15/20], Loss: 0.0765, Validation Accuracy: 90.72%
# Epoch [15/20], Step [600/1188], Loss: 0.1362, Accuracy: 96.88%
# Epoch [15/20], Loss: 0.3167, Validation Accuracy: 90.39%
# Epoch [15/20], Step [700/1188], Loss: 0.2567, Accuracy: 90.62%
# Epoch [15/20], Loss: 0.6766, Validation Accuracy: 89.96%
# Epoch [15/20], Step [800/1188], Loss: 0.4141, Accuracy: 87.50%
# Epoch [15/20], Loss: 0.1532, Validation Accuracy: 90.29%
# Epoch [15/20], Step [900/1188], Loss: 0.3628, Accuracy: 90.62%
# Epoch [15/20], Loss: 0.0902, Validation Accuracy: 89.45%
# Epoch [15/20], Step [1000/1188], Loss: 0.5663, Accuracy: 84.38%
# Epoch [15/20], Loss: 0.5945, Validation Accuracy: 90.07%
# Epoch [15/20], Step [1100/1188], Loss: 0.7132, Accuracy: 78.12%
# Epoch [15/20], Loss: 0.1142, Validation Accuracy: 89.96%
# Epoch [16/20], Step [100/1188], Loss: 0.3997, Accuracy: 87.50%
# Epoch [16/20], Loss: 0.3314, Validation Accuracy: 88.84%
# Epoch [16/20], Step [200/1188], Loss: 0.3139, Accuracy: 87.50%
# Epoch [16/20], Loss: 0.1560, Validation Accuracy: 89.78%
# Epoch [16/20], Step [300/1188], Loss: 0.0544, Accuracy: 100.00%
# Epoch [16/20], Loss: 0.1234, Validation Accuracy: 89.96%
# Epoch [16/20], Step [400/1188], Loss: 0.2110, Accuracy: 90.62%
# Epoch [16/20], Loss: 0.2561, Validation Accuracy: 89.76%
# Epoch [16/20], Step [500/1188], Loss: 0.5686, Accuracy: 81.25%
# Epoch [16/20], Loss: 0.4720, Validation Accuracy: 90.07%
# Epoch [16/20], Step [600/1188], Loss: 0.2677, Accuracy: 84.38%
# Epoch [16/20], Loss: 0.1383, Validation Accuracy: 90.31%
# Epoch [16/20], Step [700/1188], Loss: 0.3349, Accuracy: 87.50%
# Epoch [16/20], Loss: 0.0982, Validation Accuracy: 89.91%
# Epoch [16/20], Step [800/1188], Loss: 0.1044, Accuracy: 93.75%
# Epoch [16/20], Loss: 0.2714, Validation Accuracy: 89.15%
# Epoch [16/20], Step [900/1188], Loss: 0.2591, Accuracy: 93.75%
# Epoch [16/20], Loss: 0.0250, Validation Accuracy: 89.15%
# Epoch [16/20], Step [1000/1188], Loss: 0.1885, Accuracy: 93.75%
# Epoch [16/20], Loss: 0.5517, Validation Accuracy: 89.12%
# Epoch [16/20], Step [1100/1188], Loss: 0.0691, Accuracy: 96.88%
# Epoch [16/20], Loss: 0.0836, Validation Accuracy: 89.59%
# Epoch [17/20], Step [100/1188], Loss: 0.4093, Accuracy: 90.62%
# Epoch [17/20], Loss: 0.2878, Validation Accuracy: 89.13%
# Epoch [17/20], Step [200/1188], Loss: 0.1516, Accuracy: 96.88%
# Epoch [17/20], Loss: 0.1079, Validation Accuracy: 88.80%
# Epoch [17/20], Step [300/1188], Loss: 0.7337, Accuracy: 81.25%
# Epoch [17/20], Loss: 0.0750, Validation Accuracy: 88.82%
# Epoch [17/20], Step [400/1188], Loss: 0.4406, Accuracy: 90.62%
# Epoch [17/20], Loss: 0.2197, Validation Accuracy: 89.87%
# Epoch [17/20], Step [500/1188], Loss: 0.4792, Accuracy: 81.25%
# Epoch [17/20], Loss: 0.1354, Validation Accuracy: 89.93%
# Epoch [17/20], Step [600/1188], Loss: 0.2105, Accuracy: 96.88%
# Epoch [17/20], Loss: 0.3796, Validation Accuracy: 89.65%
# Epoch [17/20], Step [700/1188], Loss: 0.0764, Accuracy: 96.88%
# Epoch [17/20], Loss: 0.2168, Validation Accuracy: 90.28%
# Epoch [17/20], Step [800/1188], Loss: 0.1691, Accuracy: 90.62%
# Epoch [17/20], Loss: 0.2246, Validation Accuracy: 89.89%
# Epoch [17/20], Step [900/1188], Loss: 0.1233, Accuracy: 93.75%
# Epoch [17/20], Loss: 0.1438, Validation Accuracy: 89.24%
# Epoch [17/20], Step [1000/1188], Loss: 0.1492, Accuracy: 96.88%
# Epoch [17/20], Loss: 0.2894, Validation Accuracy: 90.81%
# Epoch [17/20], Step [1100/1188], Loss: 0.4738, Accuracy: 87.50%
# Epoch [17/20], Loss: 0.1066, Validation Accuracy: 89.65%
# Epoch [18/20], Step [100/1188], Loss: 0.0473, Accuracy: 96.88%
# Epoch [18/20], Loss: 0.1402, Validation Accuracy: 90.44%
# Epoch [18/20], Step [200/1188], Loss: 0.1596, Accuracy: 93.75%
# Epoch [18/20], Loss: 0.0323, Validation Accuracy: 89.58%
# Epoch [18/20], Step [300/1188], Loss: 0.0991, Accuracy: 96.88%
# Epoch [18/20], Loss: 0.2311, Validation Accuracy: 89.78%
# Epoch [18/20], Step [400/1188], Loss: 0.2074, Accuracy: 90.62%
# Epoch [18/20], Loss: 0.0943, Validation Accuracy: 90.24%
# Epoch [18/20], Step [500/1188], Loss: 0.2907, Accuracy: 93.75%
# Epoch [18/20], Loss: 0.3415, Validation Accuracy: 90.24%
# Epoch [18/20], Step [600/1188], Loss: 0.4201, Accuracy: 84.38%
# Epoch [18/20], Loss: 0.4411, Validation Accuracy: 89.80%
# Epoch [18/20], Step [700/1188], Loss: 0.1192, Accuracy: 96.88%
# Epoch [18/20], Loss: 0.2168, Validation Accuracy: 89.87%
# Epoch [18/20], Step [800/1188], Loss: 0.4899, Accuracy: 78.12%
# Epoch [18/20], Loss: 0.5447, Validation Accuracy: 90.33%
# Epoch [18/20], Step [900/1188], Loss: 0.3181, Accuracy: 90.62%
# Epoch [18/20], Loss: 0.1559, Validation Accuracy: 90.35%
# Epoch [18/20], Step [1000/1188], Loss: 0.2169, Accuracy: 93.75%
# Epoch [18/20], Loss: 0.2731, Validation Accuracy: 89.93%
# Epoch [18/20], Step [1100/1188], Loss: 0.1542, Accuracy: 93.75%
# Epoch [18/20], Loss: 0.2828, Validation Accuracy: 89.85%
# Epoch [19/20], Step [100/1188], Loss: 0.2938, Accuracy: 93.75%
# Epoch [19/20], Loss: 0.4300, Validation Accuracy: 89.12%
# Epoch [19/20], Step [200/1188], Loss: 0.0859, Accuracy: 96.88%
# Epoch [19/20], Loss: 0.3704, Validation Accuracy: 89.74%
# Epoch [19/20], Step [300/1188], Loss: 0.5618, Accuracy: 84.38%
# Epoch [19/20], Loss: 0.1191, Validation Accuracy: 88.49%
# Epoch [19/20], Step [400/1188], Loss: 0.1308, Accuracy: 96.88%
# Epoch [19/20], Loss: 0.1108, Validation Accuracy: 88.34%
# Epoch [19/20], Step [500/1188], Loss: 0.2534, Accuracy: 90.62%
# Epoch [19/20], Loss: 0.0234, Validation Accuracy: 90.53%
# Epoch [19/20], Step [600/1188], Loss: 0.0691, Accuracy: 96.88%
# Epoch [19/20], Loss: 0.1410, Validation Accuracy: 89.87%
# Epoch [19/20], Step [700/1188], Loss: 0.1281, Accuracy: 93.75%
# Epoch [19/20], Loss: 0.1944, Validation Accuracy: 90.44%
# Epoch [19/20], Step [800/1188], Loss: 0.8437, Accuracy: 81.25%
# Epoch [19/20], Loss: 0.6590, Validation Accuracy: 89.23%
# Epoch [19/20], Step [900/1188], Loss: 0.3144, Accuracy: 87.50%
# Epoch [19/20], Loss: 0.0730, Validation Accuracy: 90.13%
# Epoch [19/20], Step [1000/1188], Loss: 0.2425, Accuracy: 90.62%
# Epoch [19/20], Loss: 0.1924, Validation Accuracy: 89.50%
# Epoch [19/20], Step [1100/1188], Loss: 0.1389, Accuracy: 93.75%
# Epoch [19/20], Loss: 0.0978, Validation Accuracy: 89.98%
# Epoch [20/20], Step [100/1188], Loss: 0.0248, Accuracy: 100.00%
# Epoch [20/20], Loss: 0.3680, Validation Accuracy: 90.41%
# Epoch [20/20], Step [200/1188], Loss: 0.2767, Accuracy: 87.50%
# Epoch [20/20], Loss: 0.1201, Validation Accuracy: 89.96%
# Epoch [20/20], Step [300/1188], Loss: 0.2276, Accuracy: 93.75%
# Epoch [20/20], Loss: 0.3665, Validation Accuracy: 89.54%
# Epoch [20/20], Step [400/1188], Loss: 0.1477, Accuracy: 93.75%
# Epoch [20/20], Loss: 0.1075, Validation Accuracy: 89.45%
# Epoch [20/20], Step [500/1188], Loss: 0.2931, Accuracy: 93.75%
# Epoch [20/20], Loss: 0.1805, Validation Accuracy: 89.78%
# Epoch [20/20], Step [600/1188], Loss: 0.2045, Accuracy: 90.62%
# Epoch [20/20], Loss: 0.1373, Validation Accuracy: 91.07%
# Epoch [20/20], Step [700/1188], Loss: 0.6554, Accuracy: 81.25%
# Epoch [20/20], Loss: 0.5284, Validation Accuracy: 89.59%
# Epoch [20/20], Step [800/1188], Loss: 0.2142, Accuracy: 90.62%
# Epoch [20/20], Loss: 0.4758, Validation Accuracy: 90.55%
# Epoch [20/20], Step [900/1188], Loss: 0.6150, Accuracy: 78.12%
# Epoch [20/20], Loss: 0.4946, Validation Accuracy: 90.09%
# Epoch [20/20], Step [1000/1188], Loss: 0.4115, Accuracy: 87.50%
# Epoch [20/20], Loss: 0.1311, Validation Accuracy: 90.02%
# Epoch [20/20], Step [1100/1188], Loss: 0.1825, Accuracy: 93.75%
# Epoch [20/20], Loss: 0.4990, Validation Accuracy: 90.18%
# ######## Training Finished in 8146.589730262756 seconds ###########

# %%
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('steps')
plt.plot(accuracy_train, label="Train Accuracy")
plt.plot(accuracy_validation, label="Validation Accuracy")
plt.legend(loc="lower right")
plt.show()

# %%
####### plot the the training accuracies here #########
num_epochs = 20

epochs = [i for i in range(num_epochs)]
plt.figure()
plt.xlabel('epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy plot')
plt.plot(accuracy_train, label="Train Accuracy")
plt.plot(accuracy_validation, label="Validation Accuracy")
plt.legend()
plt.show()

# %%
test_dataset

# %%
def predict_image(img, model):
    """Converts image to array and return the predicted class
        with highest probability"""
    # Convert to a batch of 1
    xb = to_device(img.unsqueeze(0), device)
    # Get predictions from model
    yb = model(xb)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label

    return train_dataset.dataset.classes[preds[0].item()]

# %%
# predicting first image
img, label = test_dataset[22]
plt.imshow(img.permute(1, 2, 0))
print('Predicted:', predict_image(img, model))
